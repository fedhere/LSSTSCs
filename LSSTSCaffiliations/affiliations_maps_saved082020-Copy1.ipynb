# %%
import pandas as pd
import numpy as np
# Out:
# /Users/fbb/anaconda3/lib/python3.7/site-packages/pandas/compat/_optional.py:138: UserWarning: Pandas requires version '2.7.0' or newer of 'numexpr' (version '2.6.9' currently installed).
#   warnings.warn(msg, UserWarning)

# %%
# !pip install -U pandas
# Out:
# Requirement already satisfied: pandas in /Users/fbb/anaconda3/lib/python3.7/site-packages (1.3.1)
# Requirement already satisfied: pytz>=2017.3 in /Users/fbb/anaconda3/lib/python3.7/site-packages (from pandas) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/fbb/anaconda3/lib/python3.7/site-packages (from pandas) (2.8.0)
# Requirement already satisfied: numpy>=1.17.3 in /Users/fbb/anaconda3/lib/python3.7/site-packages (from pandas) (1.21.0)
# Requirement already satisfied: six>=1.5 in /Users/fbb/anaconda3/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas) (1.12.0)

# %%
pd.__version__
# Out:
# '1.3.1'

# %%
np.__version__
# Out:
# '1.21.0'

# %%
import pylab as pl
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import geopandas as gpd
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-6-a62d01c1d62e> in <module>
# ----> 1 import geopandas as gpd
#
# ~/anaconda3/lib/python3.7/site-packages/geopandas/__init__.py in <module>
# ----> 1 from geopandas.geoseries import GeoSeries
#       2 from geopandas.geodataframe import GeoDataFrame
#       3
#       4 from geopandas.io.file import read_file
#       5 from geopandas.io.sql import read_postgis
#
# ~/anaconda3/lib/python3.7/site-packages/geopandas/geoseries.py in <module>
#      10
#      11 from geopandas.plotting import plot_series
# ---> 12 from geopandas.base import GeoPandasBase, _series_unary_op, _CoordinateIndexer
#      13
#      14
#
# ~/anaconda3/lib/python3.7/site-packages/geopandas/base.py in <module>
#       4 import pandas as pd
#       5 from pandas import Series, DataFrame, MultiIndex
# ----> 6 from pandas.core.indexing import _NDFrameIndexer
#       7 from shapely.geometry import box, MultiPoint, MultiLineString, MultiPolygon
#       8 from shapely.ops import cascaded_union, unary_union
#
# ImportError: cannot import name '_NDFrameIndexer' from 'pandas.core.indexing' (/Users/fbb/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py)

# %%
df_ = pd.read_csv("contactdbexportsavedaugust2021.csv")#"SC-List.csv")

# %%
df_.columns
# Out:
# Index(['First Name', 'Last Name', 'Email', 'Telephone', 'Company',
#        'Contact Category', 'Role', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12'],
#       dtype='object')

# %%
df_.head()
# Out:
#   First Name   Last Name                          Email     Telephone  \
# 0     Ghaleb     Abdulla              abdulla1@llnl.gov  925-423-5947
# 1    Abdurro  Abdurro'uf  abdurrouf@asiaa.sinica.edu.tw           NaN
# 2        NaN       Abell          paul.a.abell@nasa.gov  281-483-0293
# 3        NaN      Afghan              ucasqaf@ucl.ac.uk           NaN
# 4        NaN        Agol      agol@astro.washington.edu           NaN
#
#                                   Company Contact Category    Role  \
# 0  Lawrence Livermore National Laboratory       Transients  Member
# 1                                     NaN         Galaxies  Member
# 2               NASA Johnson Space Center     Solar System  Member
# 3               University College London     Solar System  Member
# 4                University of Washington   Strong Lensing  Member
#
#    Unnamed: 7  Unnamed: 8  Unnamed: 9  Unnamed: 10  Unnamed: 11  Unnamed: 12
# 0         NaN         NaN         NaN          NaN          NaN          NaN
# 1         NaN         NaN         NaN          NaN          NaN          NaN
# 2         NaN         NaN         NaN          NaN          NaN          NaN
# 3         NaN         NaN         NaN          NaN          NaN          NaN
# 4         NaN         NaN         NaN          NaN          NaN          NaN

# %%
df_["Contact Category"].unique()
# Out:
# array(['Transients', 'Galaxies', 'Solar System', 'Strong Lensing', 'DESC',
#        'AGN', 'Stars', ' Milky Way and Local Volume',
#        'Informatics and Statistics', 'DESC ', 'Supernovae',
#        ' Milky Way and Local Volume ', 'Galaxies ', 'Transients '],
#       dtype=object)

# %%
df_["Contact Category"] =\
    df_["Contact Category"].apply(lambda x:x.strip())

df_.loc[df_["Contact Category"] == 'Stars', "Contact Category"] = 'Stars, Milky Way, and Local Volume'
df_.loc[df_["Contact Category"] == 
             'Milky Way and Local Volume', "Contact Category"] = 'Stars, Milky Way, and Local Volume'

df_ = df_[~(
        (df_["Contact Category"] == 'Weak Lensing') | 
             (df_["Contact Category"] == 'Supernovae'))]
df_.head()
# Out:
#   First Name   Last Name                          Email     Telephone  \
# 0     Ghaleb     Abdulla              abdulla1@llnl.gov  925-423-5947
# 1    Abdurro  Abdurro'uf  abdurrouf@asiaa.sinica.edu.tw           NaN
# 2        NaN       Abell          paul.a.abell@nasa.gov  281-483-0293
# 3        NaN      Afghan              ucasqaf@ucl.ac.uk           NaN
# 4        NaN        Agol      agol@astro.washington.edu           NaN
#
#                                   Company Contact Category    Role  \
# 0  Lawrence Livermore National Laboratory       Transients  Member
# 1                                     NaN         Galaxies  Member
# 2               NASA Johnson Space Center     Solar System  Member
# 3               University College London     Solar System  Member
# 4                University of Washington   Strong Lensing  Member
#
#    Unnamed: 7  Unnamed: 8  Unnamed: 9  Unnamed: 10  Unnamed: 11  Unnamed: 12
# 0         NaN         NaN         NaN          NaN          NaN          NaN
# 1         NaN         NaN         NaN          NaN          NaN          NaN
# 2         NaN         NaN         NaN          NaN          NaN          NaN
# 3         NaN         NaN         NaN          NaN          NaN          NaN
# 4         NaN         NaN         NaN          NaN          NaN          NaN

# %%
df_["SC"] = df_["Contact Category"].apply(lambda x : 
                                         x.strip().lstrip())
# Out:
# /Users/fbb/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_[["Email", "SC"]].drop_duplicates().groupby("SC").count()
# Out:
#                                     Email
# SC
# AGN                                    90
# DESC                                  177
# Galaxies                              189
# Informatics and Statistics             90
# Solar System                          129
# Stars, Milky Way, and Local Volume    266
# Strong Lensing                         68
# Transients                            217

# %%
df.
# Out:
#   File "<ipython-input-17-38e9e33c87a8>", line 1
#     df.
#        ^
# SyntaxError: invalid syntax

# %%
df_[["Email", "SC"]].drop_duplicates().groupby("SC").count().reset_index()#.plot(kind="bar")
# Out:
#                                    SC  Email
# 0                                 AGN     90
# 1                                DESC    177
# 2                            Galaxies    189
# 3          Informatics and Statistics     90
# 4                        Solar System    129
# 5  Stars, Milky Way, and Local Volume    266
# 6                      Strong Lensing     68
# 7                          Transients    217

# %%
df_.iloc[:,0] = df_.iloc[:,1]
# Out:
# /Users/fbb/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)

# %%
df_
# Out:
#       First Name   Last Name                          Email     Telephone  \
# 0        Abdulla     Abdulla              abdulla1@llnl.gov  925-423-5947
# 1     Abdurro'uf  Abdurro'uf  abdurrouf@asiaa.sinica.edu.tw           NaN
# 2          Abell       Abell          paul.a.abell@nasa.gov  281-483-0293
# 3         Afghan      Afghan              ucasqaf@ucl.ac.uk           NaN
# 4           Agol        Agol      agol@astro.washington.edu           NaN
# ...          ...         ...                            ...           ...
# 1332        Zhu         Zhu               gbzhao@nao.cas.cn           NaN
# 1333     Zoccali     Zoccali             sfzastro@gmail.com           NaN
# 1334     Zolotov     Zolotov          mzoccali@astro.puc.cl           NaN
# 1335         Zou         Zou           adizolotov@gmail.com           NaN
# 1336       Zuntz       Zuntz                  fuz64@psu.edu           NaN
#
#                                      Company  \
# 0     Lawrence Livermore National Laboratory
# 1                                        NaN
# 2                  NASA Johnson Space Center
# 3                  University College London
# 4                   University of Washington
# ...                                      ...
# 1332                                     NaN
# 1333                                     NaN
# 1334                                     NaN
# 1335                                     NaN
# 1336                                     NaN
#
#                         Contact Category    Role  Unnamed: 7  Unnamed: 8  \
# 0                             Transients  Member         NaN         NaN
# 1                               Galaxies  Member         NaN         NaN
# 2                           Solar System  Member         NaN         NaN
# 3                           Solar System  Member         NaN         NaN
# 4                         Strong Lensing  Member         NaN         NaN
# ...                                  ...     ...         ...         ...
# 1332  Stars, Milky Way, and Local Volume  Member         NaN         NaN
# 1333                        Solar System  Member         NaN         NaN
# 1334                        Solar System  Member         NaN         NaN
# 1335  Stars, Milky Way, and Local Volume  Member         NaN         NaN
# 1336  Stars, Milky Way, and Local Volume  Member         NaN         NaN
#
#       Unnamed: 9  Unnamed: 10  Unnamed: 11  Unnamed: 12  \
# 0            NaN          NaN          NaN          NaN
# 1            NaN          NaN          NaN          NaN
# 2            NaN          NaN          NaN          NaN
# 3            NaN          NaN          NaN          NaN
# 4            NaN          NaN          NaN          NaN
# ...          ...          ...          ...          ...
# 1332         NaN          NaN          NaN          NaN
# 1333         NaN          NaN          NaN          NaN
# 1334         NaN          NaN          NaN          NaN
# 1335         NaN          NaN          NaN          NaN
# 1336         NaN          NaN          NaN          NaN
#
#                                       SC
# 0                             Transients
# 1                               Galaxies
# 2                           Solar System
# 3                           Solar System
# 4                         Strong Lensing
# ...                                  ...
# 1332  Stars, Milky Way, and Local Volume
# 1333                        Solar System
# 1334                        Solar System
# 1335  Stars, Milky Way, and Local Volume
# 1336  Stars, Milky Way, and Local Volume
#
# [1290 rows x 14 columns]

# %%
df_['First'] = df_['First Name']
df_['Last'] = df_['Last Name']
df_["firstlast"] = df_['First']  + df_['Last']
df_.firstlast.unique().size
# Out:
# /Users/fbb/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /Users/fbb/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/fbb/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# 1009

# %%
newnames = {"DESC":"Dark Energy (DESC)",
           "Milky Way and Local Volume":"Stars, Milky Way, Local Volume",
           "Statistics and Informatics":"Informatics and Statistics",
           "Transients": "Transients and Variable Stars"}

# %%
tmp = df_[["Email", "SC"]].drop_duplicates().groupby("SC").count().rename(newnames)
tmp
# Out:
#                                     Email
# SC
# AGN                                    90
# Dark Energy (DESC)                    177
# Galaxies                              189
# Informatics and Statistics             90
# Solar System                          129
# Stars, Milky Way, and Local Volume    266
# Strong Lensing                         68
# Transients and Variable Stars         217

# %%
ax = tmp.plot(kind="bar", legend=False, figsize=(10,8), fontsize=20, rot=90, 
              )

ax.set_yticks([])
#ax.set_xticks(ax.g)
for p in ax.patches:
    b = p.get_bbox()
    val = "{:d}".format(int(b.y1 + b.y0))
    ax.annotate(val, ((b.x0 + b.x1)/2 + -0.15, b.y1 + -15), rotation=90, 
                color="w", fontsize=20)
ax.set_xlabel("")
pl.savefig("SCbars.png")

# %%
sccounts = pd.DataFrame.from_dict(
    {"AGN": 107,
    "Dark Energy (DESC, full)": 230,
     "Galaxies": 240,
   "Informatics and Statistics": 72,
      "Solar System": 152,
   "Stars, Milk Way, and Local Volume": 180,
     "Strong Lensing": 80,
  "Transients and Variable Stars": 346, }, orient="index")

ax = sccounts.plot(kind="bar", legend=False, figsize=(10,8), fontsize=20, rot=90, 
              )

ax.set_yticks([])
#ax.set_xticks(ax.g)
for p in ax.patches:
    b = p.get_bbox()
    val = "{:d}".format(int(b.y1 + b.y0))
    ax.annotate(val, ((b.x0 + b.x1)/2 - 0.13, b.y1 + -17), rotation=90, color="w", fontsize=20)
ax.set_xlabel("")
pl.savefig("SCbars.png")

# %%
sccounts0 = pd.DataFrame.from_dict(
    {"AGN": 49,
    "Dark Energy (DESC)": 220,
     "Galaxies": 156,
   "Informatics and Statistics": 72,
      "Solar System": 120,
   "Stars, Milk Way, and Local Volume": 180,
     "Strong Lensing": 52,
  "Transients and Variable Stars": 280, }, orient="index")
allmembers = np.sum(np.array(list(sccounts0.values)))

ax = sccounts0.plot(kind="bar", legend=False, figsize=(10,8), fontsize=20, rot=90, alpha=0.5)
ax.set_yticks([])
#ax.set_xticks(ax.g)
for p in ax.patches:
    b = p.get_bbox()
    val = "{:d}".format(int(b.y1 + b.y0))
    ax.annotate(val, ((b.x0 + b.x1)/2 - 0.13, b.y1 + -17), rotation=90, color="w", fontsize=20)
ax.set_xlabel("")

sccounts = pd.DataFrame.from_dict(
    {"AGN": 62,
    "Dark Energy (DESC)": 160,
     "Galaxies": 128,
   "Informatics and Statistics": 75,
      "Solar System": 107,
   "Stars, Milk Way, and Local Volume": 180,
     "Strong Lensing": 52,
  "Transients and Variable Stars": 222, }, orient="index")
sccounts.plot(kind="bar", legend=False, figsize=(10,8), fontsize=20, rot=90, 
              ax=ax)

pl.savefig("SCbars.png")
allmembers + 900
# Out:
# 2029

# %%
tvsdf = pd.read_csv("LSST_TVS_subgroups - Sheet1.csv")[
    ["last name","first name","affiliation","email"]].rename(
    {"first name":"First Name",
    "last name":"Last Name",
    "email":"Email",
    "affiliation":"Company"}, axis=1)
tvsdf["SC"] = ["TVS"] * len(tvsdf)
tvsmerged = pd.concat([tvsdf,df_[["First Name",
    "Last Name",
    "Email",
    "SC"]]]).drop_duplicates()
tvsmerged1 = tvsmerged[~(tvsmerged.SC == "Transients")]
tvsmerged1.shape, tvsmerged.shape
# Out:
# /Users/fbb/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   # This is added back by InteractiveShellApp.init_path()
# ((1010, 5), (1204, 5))

# %%
tvsmerged1["SC"] = tvsmerged1["SC"].map(lambda x: x.replace("TVS", 
                                "Transients and Variable Stars"))
# Out:
# /Users/fbb/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %% [raw]
# pd.set_option('display.max_rows', 1000)
# tmp = tvsmerged[(tvsmerged["SC"] == "TVS") +
#           (tvsmerged["SC"] == "Transients")].drop_duplicates(
#     subset=["First Name", "Last Name"])
# tmp = tmp.drop_duplicates(
#     subset=["Email"])
# tmp[tmp["SC"] == "TVS"].shape, tmp[tmp["SC"] == "Transients"].shape,
#
# #tvsdf.shape

# %% [raw]
# tmp[tmp["SC"] == "Transients"]
# for f in tmp[tmp.duplicated(subset="Last Name")]["Last Name"].values:
#     print (tmp[tmp["Last Name"] == f])

# %%
desc = pd.read_csv("DESCcontactList.csv")
desc
desc["First Name"] = desc.Name.map(lambda x: x.split()[0])
desc["Last Name"] = desc.Name.map(lambda x: ' '.join(x.split()[1:]))
desc["SC"] = ["DESC"] * len(desc)
desc["Email"] = [""] * len(desc)
desc["Company"] = [""] * len(desc)
desc = desc[["First Name","Last Name","SC", "Email", "Company"]]
desc
# Out:
#       First Name       Last Name    SC Email Company
# 0         Michel          Aguena  DESC
# 1           Greg        Aldering  DESC
# 2         Steven           Allen  DESC
# 3          Husni     Almoubayyed  DESC
# 4          David          Alonso  DESC
# 5           Reza          Ansari  DESC
# 6         Pierre       Antilogus  DESC
# 7         Pierre          Astier  DESC
# 8           Eric         Aubourg  DESC
# 9        Camille        Avestruz  DESC
# 10         Humna            Awan  DESC
# 11    Christophe         Balland  DESC
# 12       Deborah            Bard  DESC
# 13      Aurelien          Barrau  DESC
# 14         James        Bartlett  DESC
# 15       Michael          Baumer  DESC
# 16        Rachel            Bean  DESC
# 17         Keith         Bechtol  DESC
# 18        Andrew          Becker  DESC
# 19       Matthew          Becker  DESC
# 20          Marc         Betoule  DESC
# 21         Rahul          Biswas  DESC
# 22     Guillaume           Blanc  DESC
# 23      Jonathan          Blazek  DESC
# 24     Sebastien         Bongard  DESC
# 25        Anders        Borgland  DESC
# 26         James           Bosch  DESC
# 27     Dominique        Boutigny  DESC
# 28        Andrew        Bradshaw  DESC
# 29         Sarah          Bridle  DESC
# ..           ...             ...   ...   ...     ...
# 185        Glenn       Sembroski  DESC
# 186    Christian          Setzer  DESC
# 187         Erin         Sheldon  DESC
# 188          Ian         Shipsey  DESC
# 189      Melanie           Simet  DESC
# 190         Anze          Slosar  DESC
# 191        David         Spergel  DESC
# 192      Michael         Strauss  DESC
# 193  Christopher          Stubbs  DESC
# 194         Mark        Sullivan  DESC
# 195      Tommaso            Treu  DESC
# 196       Tilman        Troester  DESC
# 197      Michael          Troxel  DESC
# 198       Dmitri       Tsybychev  DESC
# 199         Tony           Tyson  DESC
# 200      Antonio      Villarreal  DESC
# 201         Anja  von der Linden  DESC
# 202       Michal         Vrastil  DESC
# 203        Chris          Walter  DESC
# 204          Yun            Wang  DESC
# 205       Daniel      Weatherill  DESC
# 206         Risa        Wechsler  DESC
# 207        Torre          Wenaus  DESC
# 208      Matthew         Wiesner  DESC
# 209      Michael      Wood-Vasey  DESC
# 210        Peter         Yoachim  DESC
# 211       Andrew         Zentner  DESC
# 212           Hu            Zhan  DESC
# 213      Gong-Bo            Zhao  DESC
# 214          Joe           Zuntz  DESC
#
# [215 rows x 5 columns]

# %%
df_.head()
# Out:
#        First Name Last Name                      Email     Telephone  \
# 0          Ghaleb   Abdulla          abdulla1@llnl.gov  925-423-5947
# 1  Paul Alexander     Abell      paul.a.abell@nasa.gov  281-483-0293
# 2            Eric      Agol  agol@astro.washington.edu           NaN
# 3            Eric      Agol  agol@astro.washington.edu           NaN
# 4          Michel    Aguena           aguena@if.usp.br           NaN
#
#                                   Company Contact Category       Role  \
# 0  Lawrence Livermore National Laboratory       Transients     Member
# 1               NASA Johnson Space Center     Solar System     Member
# 2                University of Washington       Transients     Member
# 3                University of Washington   Strong Lensing  Affiliate
# 4                                     NaN             DESC     Member
#
#    Unnamed: 7  Unnamed: 8  Unnamed: 9  Unnamed: 10  Unnamed: 11  Unnamed: 12  \
# 0         NaN         NaN         NaN          NaN          NaN          NaN
# 1         NaN         NaN         NaN          NaN          NaN          NaN
# 2         NaN         NaN         NaN          NaN          NaN          NaN
# 3         NaN         NaN         NaN          NaN          NaN          NaN
# 4         NaN         NaN         NaN          NaN          NaN          NaN
#
#                SC           First     Last            firstlast
# 0      Transients          Ghaleb  Abdulla        GhalebAbdulla
# 1    Solar System  Paul Alexander    Abell  Paul AlexanderAbell
# 2      Transients            Eric     Agol             EricAgol
# 3  Strong Lensing            Eric     Agol             EricAgol
# 4            DESC          Michel   Aguena         MichelAguena

# %%
for i,f in enumerate(zip(desc["Last Name"].values,desc["First Name"].values)):
    tmp = (tvsmerged1[(tvsmerged1["First Name"] == f[1]) * 
          (tvsmerged1["Last Name"] == f[0])])
    if len(tmp)>0:
        desc.iloc[i]["Company"] = tmp["Company"].values[0] 
        desc.iloc[i]["Email"] = tmp["Email"].values[0]
# Out:
# /Users/fbb/anaconda3/lib/python3.7/site-packages/pandas/core/computation/expressions.py:183: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   .format(op=op_str, alt_op=unsupported[op_str]))

# %%
df_ = pd.concat([tvsmerged1[~(tvsmerged1.SC == "DESC")], desc])
df_
# Out:
# /Users/fbb/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
#                                                Company  \
# 0                             University of Washington
# 1                                                  NaN
# 2                             University of Washington
# 3                                              Caltech
# 4                     University of the Virgin Islands
# 5              INAF - Osservatorio Astronomico di Roma
# 6                                           LCOGT/UCSB
# 7                                University of Arizona
# 8                              Las Cumbres Observatory
# 9                              Northwestern University
# 10   INAF - Osservatorio Astrofisico di Torino / SN...
# 11                                                 NaN
# 12                       University of Texas at Austin
# 13                       University of Washington/LSST
# 14         Harvard Smithsonian Center for Astrophysics
# 15                    Liverpool John Moores University
# 16                 University of Maryland College Park
# 17                                 New York University
# 18             Stockholm University/Oskar Klein Centre
# 19                   University of California Berkeley
# 20                            University of Portsmouth
# 21          INAF - Osservatorio Astronomico di Palermo
# 22   University of Rome Tor Vergata -- INAF Rome as...
# 23                                               LCOGT
# 24            INAF - Osservatorio Astronomico di Brera
# 25      INAF - Osservatorio Astronomico di Capodimonte
# 26                       Pennsylvania State University
# 27                           University of Nova Gorica
# 28             INAF - Osservatorio Astronomico di Rome
# 29                                               LCOGT
# ..                                                 ...
# 185                                                NaN
# 186
# 187                                                NaN
# 188                                                NaN
# 189                                                NaN
# 190
# 191                                                NaN
# 192                                         Princeton
# 193                                                NaN
# 194                          University of Southampton
# 195                                                NaN
# 196
# 197                                                NaN
# 198                                                NaN
# 199                                                NaN
# 200                                                NaN
# 201
# 202
# 203                                                NaN
# 204                                                NaN
# 205
# 206                                                NaN
# 207                                                NaN
# 208                                                NaN
# 209                           University of Pittsburgh
# 210                                                NaN
# 211                                                NaN
# 212                                                NaN
# 213
# 214                                                NaN
#
#                                   Email    First Name       Last Name  \
# 0             agol@astro.washington.edu          Eric            Agol
# 1               javier.alonso@uantof.cl        Javier   Alonso-Garcia
# 2         anderson@astro.washington.edu         Scott        Anderson
# 3                  andreoni@caltech.edu          Igor        Andreoni
# 4            antonino.cucchiara@uvi.edu     Cucchiara        Antonino
# 5             simone.antoniucci@inaf.it        Simone      Antoniucci
# 6                      arcavi@gmail.com          Iair          Arcavi
# 7                darnett@as.arizona.edu         David          Arnett
# 8                 etibachelet@gmail.com       Etienne        Bachelet
# 9    adriano.baldeschi@northwestern.edu       Adriano       Baldeschi
# 10           barbara.balmaverde@inaf.it       Barbara      Balmaverde
# 11                   acbecker@gmail.com        Andrew          Becker
# 12                      bell@mps.mpg.de        Keaton            Bell
# 13                       ecbellm@uw.edu          Eric           Bellm
# 14              eberger@cfa.harvard.edu           Edo          Berger
# 15               D.F.Bersier@ljmu.ac.uk         David         Bersier
# 16                     abhatta5@umd.edu        Aparna    Bhattacharya
# 17                         fb55@nyu.edu      Federica          Bianco
# 18                   rbiswas4@gmail.com         Rahul          Biswas
# 19            jbloom@astro.berkeley.edu          Josh           Bloom
# 20                bob.nichol@port.ac.uk        Nichol             Bob
# 21               rosaria.bonito@inaf.it       Rosaria          Bonito
# 22                   bono@roma2.infn.it      Giuseppe            Bono
# 23                  tboroson@lco.global          Todd         Boroson
# 24        francesco.borsa@brera.inaf.it     Francesco           Borsa
# 25             maria.botticella@inaf.it  Maria Teresa      Botticella
# 26                   wnbrandt@gmail.com          Niel          Brandt
# 27                 katja.bricman@ung.si         Katja         Bricman
# 28                 enzo.brocato@inaf.it          Enzo         Brocato
# 29                    tbrown@lco.global           Tim           Brown
# ..                                  ...           ...             ...
# 185                 sembrosk@purdue.edu         Glenn       Sembroski
# 186                                         Christian          Setzer
# 187              erin.sheldon@gmail.com          Erin         Sheldon
# 188        ian.shipsey@physics.ox.ac.uk           Ian         Shipsey
# 189               msimet@andrew.cmu.edu       Melanie           Simet
# 190                                              Anze          Slosar
# 191             dns@astro.princeton.edu         David         Spergel
# 192         strauss@astro.princeton.edu       Michael         Strauss
# 193                stubbs@g.harvard.edu   Christopher          Stubbs
# 194              m.sullivan@soton.ac.uk          Mark        Sullivan
# 195                   tt@astro.ucla.edu       Tommaso            Treu
# 196                                            Tilman        Troester
# 197                 troxel@utdallas.edu       Michael          Troxel
# 198    tsybych@sbhep.physics.sunysb.edu        Dmitri       Tsybychev
# 199           tyson@physics.ucdavis.edu          Tony           Tyson
# 200                      asv13@pitt.edu       Antonio      Villarreal
# 201                                              Anja  von der Linden
# 202                                            Michal         Vrastil
# 203               chris.walter@duke.edu         Chris          Walter
# 204                     wang@nhn.ou.edu           Yun            Wang
# 205                                            Daniel      Weatherill
# 206              rwechsler@stanford.edu          Risa        Wechsler
# 207                    wenaus@gmail.com         Torre          Wenaus
# 208              matthewwiesner@aol.com       Matthew         Wiesner
# 209                       wmwv@pitt.edu       Michael      Wood-Vasey
# 210                      yoachim@uw.edu         Peter         Yoachim
# 211                    zentner@pitt.edu        Andrew         Zentner
# 212                   zhanhu@nao.cas.cn            Hu            Zhan
# 213                                           Gong-Bo            Zhao
# 214             joezuntz@googlemail.com           Joe           Zuntz
#
#                                 SC
# 0    Transients and Variable Stars
# 1    Transients and Variable Stars
# 2    Transients and Variable Stars
# 3    Transients and Variable Stars
# 4    Transients and Variable Stars
# 5    Transients and Variable Stars
# 6    Transients and Variable Stars
# 7    Transients and Variable Stars
# 8    Transients and Variable Stars
# 9    Transients and Variable Stars
# 10   Transients and Variable Stars
# 11   Transients and Variable Stars
# 12   Transients and Variable Stars
# 13   Transients and Variable Stars
# 14   Transients and Variable Stars
# 15   Transients and Variable Stars
# 16   Transients and Variable Stars
# 17   Transients and Variable Stars
# 18   Transients and Variable Stars
# 19   Transients and Variable Stars
# 20   Transients and Variable Stars
# 21   Transients and Variable Stars
# 22   Transients and Variable Stars
# 23   Transients and Variable Stars
# 24   Transients and Variable Stars
# 25   Transients and Variable Stars
# 26   Transients and Variable Stars
# 27   Transients and Variable Stars
# 28   Transients and Variable Stars
# 29   Transients and Variable Stars
# ..                             ...
# 185                           DESC
# 186                           DESC
# 187                           DESC
# 188                           DESC
# 189                           DESC
# 190                           DESC
# 191                           DESC
# 192                           DESC
# 193                           DESC
# 194                           DESC
# 195                           DESC
# 196                           DESC
# 197                           DESC
# 198                           DESC
# 199                           DESC
# 200                           DESC
# 201                           DESC
# 202                           DESC
# 203                           DESC
# 204                           DESC
# 205                           DESC
# 206                           DESC
# 207                           DESC
# 208                           DESC
# 209                           DESC
# 210                           DESC
# 211                           DESC
# 212                           DESC
# 213                           DESC
# 214                           DESC
#
# [1056 rows x 5 columns]

# %%
#tvsdesvmerged = tvsmerged1.merge(desc, on=[
#    "First Name","Last Name"], how="right").drop_duplicates()
#tvsdesvmerged.drop("")

# %%
df_.Company.unique()
# Out:
# array(['University of Washington', nan, 'Caltech',
#        'University of the Virgin Islands',
#        'INAF - Osservatorio Astronomico di Roma', 'LCOGT/UCSB',
#        'University of Arizona', 'Las Cumbres Observatory',
#        'Northwestern University',
#        'INAF - Osservatorio Astrofisico di Torino / SNS-Scuola Normale',
#        'University of Texas at Austin', 'University of Washington/LSST',
#        'Harvard Smithsonian Center for Astrophysics',
#        'Liverpool John Moores University',
#        'University of Maryland College Park', 'New York University',
#        'Stockholm University/Oskar Klein Centre',
#        'University of California Berkeley', 'University of Portsmouth',
#        'INAF - Osservatorio Astronomico di Palermo',
#        'University of Rome Tor Vergata -- INAF Rome astronomical Observatory',
#        'LCOGT', 'INAF - Osservatorio Astronomico di Brera',
#        'INAF - Osservatorio Astronomico di Capodimonte',
#        'Pennsylvania State University', 'University of Nova Gorica',
#        'INAF - Osservatorio Astronomico di Rome',
#        'Texas A&M / Mitchell Institute for Fundamental Physics and Astronomy',
#        'South African Astronomical Observatory',
#        'Universidad Andres Bello, Chile',
#        'INAF - Osservatorio Astronomico di Padova',
#        'INAF - Osservatorio astronomico di Brera',
#        'INAF - Osservatorio Astrofisico di Torino', 'PUC-Chile',
#        'Istituto Nazionale di Astrofisica (INAF)', 'NASA GSFC',
#        'Michigan State University', 'Ohio State University',
#        'Universidad Diego Portales', 'Pisa University',
#        'Louisiana State University',
#        'National Institute for Astrophysics - INAF Osservatorio Astronomico Bologna',
#        'LUPM (IN2P3/CNRS, France)', 'LSST / Consultant',
#        'Western Washington University', 'Carnegie Observatories',
#        'University of Pennsylvania', 'Lawrence Livermore National Lab ',
#        'University of Central Lancashire',
#        'INAF-Osservatorio Astronomioo di Roma',
#        'University of Chicago/KICP', 'University of Auckland',
#        'High Altitude Observatory at the National Center for Atmospheric Research',
#        'SOAR/NOAO',
#        'INAF - Osservatorio Astronomico Roma / ASI Science Data Center',
#        'University College London', 'Penn State University',
#        'CMM-UChile / MAS', 'Steward Observatory', 'Universidad de Chile',
#        'Monash University', 'University of Southampton',
#        'INAF  Osservatorio Astronomico Bologna',
#        'Northwestern University / CIERA / The Adler Planetarium',
#        'University of Maryland', 'Stanford University',
#        'University of Washington/LSST ',
#        'Harvard-Smithsonian Center for Astrophysics', 'AURA/LSST',
#        'Argonne National Lab', 'Columbia University',
#        'Villanova University', 'Rice', 'AAVSO',
#        'San Diego State University',
#        'University of Cape Town/South African Astronomical Observatory',
#        'University of Delaware', 'Los Alamos National Laboratory',
#        'NASA Ames Research Center',
#        'NCSA and Astronomy Department, University of Illinois at Urbana-Chamapign',
#        'Zentrum für Astronomie der Universität Heidelberg',
#        "Queen's University Belfast",
#        'Fisk University/ Vanderbilt University',
#        'Astronomical Observatory Belgrade', 'Rutgers University',
#        'LSSTPO', 'SUNY Oswego', 'University of Wisconsin Milwaukee',
#        'Carnegie Institution for Science', 'University of Manchester',
#        'Lehigh University', 'Carnegie Mellon University', 'NOAO',
#        'Space Telescope Science Institute', 'Vanderbilt',
#        'Texas A&M University',
#        'University of Roma Tor Vergata - INAF OAR',
#        'University of the Free State', 'University of Roma Tre',
#        'OAR Osservatorio Astronomico di Roma',
#        'INAF - Osservatorio Astronomico di Roma / ASDC',
#        'INAF-OAR, SSDC-ASI', 'Universidad de Chile, DAS, CMM',
#        'INAF - OATS ', 'IN2P3 CNRS', 'Universidad de Concepcion',
#        'JPL/Caltech', 'Gemini Observatory',
#        'Linear Accelerator Laboratory', 'Rider University',
#        'INAF - Osservatorio Astronomico di Capodimonte,',
#        'National Center for Supercomputing Applications',
#        'Northwestern University and the Center for Interdisciplinary Research and Exploration in Astrophysics (CIERA)',
#        'SETI Institute / NASA Ames',
#        'National Institute for Astrophysics INAF - Osservatorio Astronomico di Bologna',
#        'NOAO/University of Arizona', 'University of Exeter',
#        'Graduate Institution of Astronomy, National Central University',
#        'University of Edinburgh', 'University of Colorado',
#        'LBL/UC Berkeley', 'Florida Institute of Technology',
#        'Dept. of Astronomy, University of Wisconsin and INAF-Padova, Italy',
#        'Rochester Institute of Technology',
#        'CIERA / Northwestern University', 'LeHigh/Vanderbilt',
#        'University of Nova Gorica, Center for Astrophysics and Cosmology',
#        'Caltech/NExSci', 'INAF-Osservatorio Astronomico di Palermo',
#        'PUC, Chile', 'INAF', 'The University of Auckland',
#        'SETI Institute', 'Arizona State University',
#        "Dipartimento di Scienza e di Alte Tecnologie - Università degli Studi dell'Insubria",
#        'Universidad La Serena',
#        'Kavli Institute for Particle Astrophysics and Cosmology',
#        'Harvard University/University of Cambridge',
#        'Università degli Studi di Milano Bicocca',
#        'Columbia University, LSST Corporation', 'Princeton ',
#        'MTA CSFK, Konkoly Observatory', 'University of Leicester',
#        'University of California Irvine', 'Heidelberg University',
#        'University of California Davis', 'George Washington University',
#        'NYU', 'INAF - Observatory of Rome', 'Harvard University',
#        'Armagh Observatory and Planetarium', 'Adler Planetarium',
#        'Royal Observatory Edinburgh', 'University of Pittsburgh',
#        'MIT Lincoln Laboratory',
#        'Warsaw University Astronomical Observatory', ''], dtype=object)

# %%
df_state = pd.read_csv("statets.csv", sep="\t", header=None)

# %%
df_state.head()
# Out:
#     0           1            2                  3
# 0  AL     Alabama   Montgomery  December 14, 1819
# 1  AK      Alaska       Juneau    January 3, 1959
# 2  AZ     Arizona      Phoenix  February 14, 1912
# 3  AR    Arkansas  Little Rock      June 15, 1836
# 4  CA  California   Sacramento  September 9, 1850

# %%
df_state.append({0:"DC", 1:"DC"},  ignore_index=True )
# Out:
#      0               1               2                  3
# 0   AL         Alabama      Montgomery  December 14, 1819
# 1   AK          Alaska          Juneau    January 3, 1959
# 2   AZ         Arizona         Phoenix  February 14, 1912
# 3   AR        Arkansas     Little Rock      June 15, 1836
# 4   CA      California      Sacramento  September 9, 1850
# 5   CO        Colorado          Denver     August 1, 1876
# 6   CT     Connecticut        Hartford    January 9, 1788
# 7   DE        Delaware           Dover   December 7, 1787
# 8   FL         Florida     Tallahassee      March 3, 1845
# 9   GA         Georgia         Atlanta    January 2, 1788
# 10  HI          Hawaii        Honolulu    August 21, 1959
# 11  ID           Idaho           Boise       July 3, 1890
# 12  IL        Illinois     Springfield   December 3, 1818
# 13  IN         Indiana    Indianapolis  December 11, 1816
# 14  IA            Iowa      Des Moines  December 28, 1846
# 15  KS          Kansas          Topeka   January 29, 1861
# 16  KY        Kentucky       Frankfort       June 1, 1792
# 17  LA       Louisiana     Baton Rouge     April 30, 1812
# 18  ME           Maine         Augusta     March 15, 1820
# 19  MD        Maryland       Annapolis     April 28, 1788
# 20  MA   Massachusetts          Boston   February 6, 1788
# 21  MI        Michigan         Lansing   January 26, 1837
# 22  MN       Minnesota      Saint Paul       May 11, 1858
# 23  MS     Mississippi         Jackson  December 10, 1817
# 24  MO        Missouri  Jefferson City    August 10, 1821
# 25  MT         Montana          Helena   November 8, 1889
# 26  NE        Nebraska         Lincoln      March 1, 1867
# 27  NV          Nevada     Carson City   October 31, 1864
# 28  NH   New Hampshire         Concord      June 21, 1788
# 29  NJ      New Jersey         Trenton  December 18, 1787
# 30  NM      New Mexico        Santa Fe    January 6, 1912
# 31  NY        New York          Albany      July 26, 1788
# 32  NC  North Carolina         Raleigh  November 21, 1789
# 33  ND    North Dakota        Bismarck   November 2, 1889
# 34  OH            Ohio        Columbus      March 1, 1803
# 35  OK        Oklahoma   Oklahoma City  November 16, 1907
# 36  OR          Oregon           Salem  February 14, 1859
# 37  PA    Pennsylvania      Harrisburg  December 12, 1787
# 38  RI    Rhode Island      Providence       May 19, 1790
# 39  SC  South Carolina        Columbia       May 23, 1788
# 40  SD    South Dakota          Pierre   November 2, 1889
# 41  TN       Tennessee       Nashville       June 1, 1796
# 42  TX           Texas          Austin  December 29, 1845
# 43  UT            Utah  Salt Lake City    January 4, 1896
# 44  VT         Vermont      Montpelier      March 4, 1791
# 45  VA        Virginia        Richmond      June 25, 1788
# 46  WA      Washington         Olympia  November 11, 1889
# 47  WV   West Virginia      Charleston      June 20, 1863
# 48  WI       Wisconsin         Madison       May 29, 1848
# 49  WY         Wyoming        Cheyenne      July 10, 1890
# 50  DC              DC             NaN                NaN

# %%
df_['state'] = df_.Company.apply(lambda x: x if isinstance(x, float)  else x.replace("University of ", ""))
#for state in df_state:

# %%
df_.state.unique()
# Out:
# array(['Washington', nan, 'Caltech', 'the Virgin Islands',
#        'INAF - Osservatorio Astronomico di Roma', 'LCOGT/UCSB', 'Arizona',
#        'Las Cumbres Observatory', 'Northwestern University',
#        'INAF - Osservatorio Astrofisico di Torino / SNS-Scuola Normale',
#        'Texas at Austin', 'Washington/LSST',
#        'Harvard Smithsonian Center for Astrophysics',
#        'Liverpool John Moores University', 'Maryland College Park',
#        'New York University', 'Stockholm University/Oskar Klein Centre',
#        'California Berkeley', 'Portsmouth',
#        'INAF - Osservatorio Astronomico di Palermo',
#        'Rome Tor Vergata -- INAF Rome astronomical Observatory', 'LCOGT',
#        'INAF - Osservatorio Astronomico di Brera',
#        'INAF - Osservatorio Astronomico di Capodimonte',
#        'Pennsylvania State University', 'Nova Gorica',
#        'INAF - Osservatorio Astronomico di Rome',
#        'Texas A&M / Mitchell Institute for Fundamental Physics and Astronomy',
#        'South African Astronomical Observatory',
#        'Universidad Andres Bello, Chile',
#        'INAF - Osservatorio Astronomico di Padova',
#        'INAF - Osservatorio astronomico di Brera',
#        'INAF - Osservatorio Astrofisico di Torino', 'PUC-Chile',
#        'Istituto Nazionale di Astrofisica (INAF)', 'NASA GSFC',
#        'Michigan State University', 'Ohio State University',
#        'Universidad Diego Portales', 'Pisa University',
#        'Louisiana State University',
#        'National Institute for Astrophysics - INAF Osservatorio Astronomico Bologna',
#        'LUPM (IN2P3/CNRS, France)', 'LSST / Consultant',
#        'Western Washington University', 'Carnegie Observatories',
#        'Pennsylvania', 'Lawrence Livermore National Lab ',
#        'Central Lancashire', 'INAF-Osservatorio Astronomioo di Roma',
#        'Chicago/KICP', 'Auckland',
#        'High Altitude Observatory at the National Center for Atmospheric Research',
#        'SOAR/NOAO',
#        'INAF - Osservatorio Astronomico Roma / ASI Science Data Center',
#        'University College London', 'Penn State University',
#        'CMM-UChile / MAS', 'Steward Observatory', 'Universidad de Chile',
#        'Monash University', 'Southampton',
#        'INAF  Osservatorio Astronomico Bologna',
#        'Northwestern University / CIERA / The Adler Planetarium',
#        'Maryland', 'Stanford University', 'Washington/LSST ',
#        'Harvard-Smithsonian Center for Astrophysics', 'AURA/LSST',
#        'Argonne National Lab', 'Columbia University',
#        'Villanova University', 'Rice', 'AAVSO',
#        'San Diego State University',
#        'Cape Town/South African Astronomical Observatory', 'Delaware',
#        'Los Alamos National Laboratory', 'NASA Ames Research Center',
#        'NCSA and Astronomy Department, Illinois at Urbana-Chamapign',
#        'Zentrum für Astronomie der Universität Heidelberg',
#        "Queen's University Belfast",
#        'Fisk University/ Vanderbilt University',
#        'Astronomical Observatory Belgrade', 'Rutgers University',
#        'LSSTPO', 'SUNY Oswego', 'Wisconsin Milwaukee',
#        'Carnegie Institution for Science', 'Manchester',
#        'Lehigh University', 'Carnegie Mellon University', 'NOAO',
#        'Space Telescope Science Institute', 'Vanderbilt',
#        'Texas A&M University', 'Roma Tor Vergata - INAF OAR',
#        'the Free State', 'Roma Tre',
#        'OAR Osservatorio Astronomico di Roma',
#        'INAF - Osservatorio Astronomico di Roma / ASDC',
#        'INAF-OAR, SSDC-ASI', 'Universidad de Chile, DAS, CMM',
#        'INAF - OATS ', 'IN2P3 CNRS', 'Universidad de Concepcion',
#        'JPL/Caltech', 'Gemini Observatory',
#        'Linear Accelerator Laboratory', 'Rider University',
#        'INAF - Osservatorio Astronomico di Capodimonte,',
#        'National Center for Supercomputing Applications',
#        'Northwestern University and the Center for Interdisciplinary Research and Exploration in Astrophysics (CIERA)',
#        'SETI Institute / NASA Ames',
#        'National Institute for Astrophysics INAF - Osservatorio Astronomico di Bologna',
#        'NOAO/Arizona', 'Exeter',
#        'Graduate Institution of Astronomy, National Central University',
#        'Edinburgh', 'Colorado', 'LBL/UC Berkeley',
#        'Florida Institute of Technology',
#        'Dept. of Astronomy, Wisconsin and INAF-Padova, Italy',
#        'Rochester Institute of Technology',
#        'CIERA / Northwestern University', 'LeHigh/Vanderbilt',
#        'Nova Gorica, Center for Astrophysics and Cosmology',
#        'Caltech/NExSci', 'INAF-Osservatorio Astronomico di Palermo',
#        'PUC, Chile', 'INAF', 'The Auckland', 'SETI Institute',
#        'Arizona State University',
#        "Dipartimento di Scienza e di Alte Tecnologie - Università degli Studi dell'Insubria",
#        'Universidad La Serena',
#        'Kavli Institute for Particle Astrophysics and Cosmology',
#        'Harvard University/Cambridge',
#        'Università degli Studi di Milano Bicocca',
#        'Columbia University, LSST Corporation', 'Princeton ',
#        'MTA CSFK, Konkoly Observatory', 'Leicester', 'California Irvine',
#        'Heidelberg University', 'California Davis',
#        'George Washington University', 'NYU',
#        'INAF - Observatory of Rome', 'Harvard University',
#        'Armagh Observatory and Planetarium', 'Adler Planetarium',
#        'Royal Observatory Edinburgh', 'Pittsburgh',
#        'MIT Lincoln Laboratory',
#        'Warsaw University Astronomical Observatory', ''], dtype=object)

# %%
statesdic = {"IAC": "Spain", "Arizona":"Arizona",'Lawrence Livermore National Laboratory': 'California',
       'NASA Johnson Space Center': 'California', 
'Washington':"Washington", 'Columbia University': 'New York',
       'UC Berkeley/LBNL': 'California', 
       'KIPAC Kavli Institute for Particle Astrophysics and Cosmology': 'California', 
       'Oxford':"UK", 'Universidad de Antofagasta':"Chile", ' California Davis': 'California',
       'Universidad Andres Bello':"Chile",
       'Laboratoire de Le Accelerateur Lineaire (LAL)':'France', 'LPNHE':'France',
       'INAF-Osservatorio Astronomico di Roma':"Italy",
       'Universidad Diego Portales':"Chile", 'LCOGT & UC Santa Barbara':"California",
       'Jet Propulsion Lab':"California", 'IPAC Caltech':"California",
       'Lawrence Berkeley National Laboratory':"California", 'APC':"France", ' Chicago':"Illinois",
       'Laboratory for Atmosphere and Space Physics':"Colorado",
       'Colorado at Boulder':"Colorado", 'Pennsylvania State University':"Pennsylvania",
       'Yale University':"Connecticut", 'LPNHE/IN2P3':"France", 'Georgia Institute of Technology':"Georgia",
       'INAF-Osservatorio Astrofisico di Torino & SNS-Scuola Normale':"Italy",
       'Observat\xc3\xb3rio Nacional/BGP-LSST/LIneA':"Chile",
       'Queens University Belfast':"Ireland",
       'Universidad de La Serena':"Chile", 'Universidad de Atacama':"Chile",
       'SLAC Nationatl Acceleratory Laboratory':"California", 'LPSC':"Colorado",
       'Universidad Metropolitana de Ciencias de la Educacion  (UMCE)':"Chile",
       'Pontifilecia Universidad Catolica de Chile':"Chile", ' California Irvine':'California',
       'Booz Allen Hamilton':"DC", 'Pontifica Universidad Catolica de Chile':"Chile",
       'Stanford Univerisity':'California', 'SUNY-SB':"New York", 'Cornell University':"Illinois",
       'Stanford University':'California', 'SLAC National Accelerator Laboratory':'California',
       'Michigan State University':"Michigan", ' Texas at Austin':"Texas", ' Michigan':"Michigan",
       'INAF':"Italy", '  Cambridge':"UK",
       'Harvard Smithsonian Center for Astrophysics':"Massachusetts", ' Pennsylvania':"Pennsylvania",
       'Argonne National Laboratory':"Illinois", 'Liverpool John Moores University':"UK",
       'New York University':"New York", 
       'INAF-Osservatorio Astronomico di Trieste':"Italy", 'Laboratoire de l':"France", 
             "Auburn": "Alabama",
            "B612 Astroid Institute/Washington": "Washington",
            "George Mason University":"Virginia","Rider University":"New Jersey"}

# %%
df_['state1'] = df_.state.map(statesdic)

# %%
df_[['Email', 'state', 'state1']]
# Out:
#                                   Email  \
# 0             agol@astro.washington.edu
# 1               javier.alonso@uantof.cl
# 2         anderson@astro.washington.edu
# 3                  andreoni@caltech.edu
# 4            antonino.cucchiara@uvi.edu
# 5             simone.antoniucci@inaf.it
# 6                      arcavi@gmail.com
# 7                darnett@as.arizona.edu
# 8                 etibachelet@gmail.com
# 9    adriano.baldeschi@northwestern.edu
# 10           barbara.balmaverde@inaf.it
# 11                   acbecker@gmail.com
# 12                      bell@mps.mpg.de
# 13                       ecbellm@uw.edu
# 14              eberger@cfa.harvard.edu
# 15               D.F.Bersier@ljmu.ac.uk
# 16                     abhatta5@umd.edu
# 17                         fb55@nyu.edu
# 18                   rbiswas4@gmail.com
# 19            jbloom@astro.berkeley.edu
# 20                bob.nichol@port.ac.uk
# 21               rosaria.bonito@inaf.it
# 22                   bono@roma2.infn.it
# 23                  tboroson@lco.global
# 24        francesco.borsa@brera.inaf.it
# 25             maria.botticella@inaf.it
# 26                   wnbrandt@gmail.com
# 27                 katja.bricman@ung.si
# 28                 enzo.brocato@inaf.it
# 29                    tbrown@lco.global
# ..                                  ...
# 185                 sembrosk@purdue.edu
# 186
# 187              erin.sheldon@gmail.com
# 188        ian.shipsey@physics.ox.ac.uk
# 189               msimet@andrew.cmu.edu
# 190
# 191             dns@astro.princeton.edu
# 192         strauss@astro.princeton.edu
# 193                stubbs@g.harvard.edu
# 194              m.sullivan@soton.ac.uk
# 195                   tt@astro.ucla.edu
# 196
# 197                 troxel@utdallas.edu
# 198    tsybych@sbhep.physics.sunysb.edu
# 199           tyson@physics.ucdavis.edu
# 200                      asv13@pitt.edu
# 201
# 202
# 203               chris.walter@duke.edu
# 204                     wang@nhn.ou.edu
# 205
# 206              rwechsler@stanford.edu
# 207                    wenaus@gmail.com
# 208              matthewwiesner@aol.com
# 209                       wmwv@pitt.edu
# 210                      yoachim@uw.edu
# 211                    zentner@pitt.edu
# 212                   zhanhu@nao.cas.cn
# 213
# 214             joezuntz@googlemail.com
#
#                                                  state         state1
# 0                                           Washington     Washington
# 1                                                  NaN            NaN
# 2                                           Washington     Washington
# 3                                              Caltech            NaN
# 4                                   the Virgin Islands            NaN
# 5              INAF - Osservatorio Astronomico di Roma            NaN
# 6                                           LCOGT/UCSB            NaN
# 7                                              Arizona        Arizona
# 8                              Las Cumbres Observatory            NaN
# 9                              Northwestern University            NaN
# 10   INAF - Osservatorio Astrofisico di Torino / SN...            NaN
# 11                                                 NaN            NaN
# 12                                     Texas at Austin            NaN
# 13                                     Washington/LSST            NaN
# 14         Harvard Smithsonian Center for Astrophysics  Massachusetts
# 15                    Liverpool John Moores University             UK
# 16                               Maryland College Park            NaN
# 17                                 New York University       New York
# 18             Stockholm University/Oskar Klein Centre            NaN
# 19                                 California Berkeley            NaN
# 20                                          Portsmouth            NaN
# 21          INAF - Osservatorio Astronomico di Palermo            NaN
# 22   Rome Tor Vergata -- INAF Rome astronomical Obs...            NaN
# 23                                               LCOGT            NaN
# 24            INAF - Osservatorio Astronomico di Brera            NaN
# 25      INAF - Osservatorio Astronomico di Capodimonte            NaN
# 26                       Pennsylvania State University   Pennsylvania
# 27                                         Nova Gorica            NaN
# 28             INAF - Osservatorio Astronomico di Rome            NaN
# 29                                               LCOGT            NaN
# ..                                                 ...            ...
# 185                                                NaN            NaN
# 186                                                               NaN
# 187                                                NaN            NaN
# 188                                                NaN            NaN
# 189                                                NaN            NaN
# 190                                                               NaN
# 191                                                NaN            NaN
# 192                                         Princeton             NaN
# 193                                                NaN            NaN
# 194                                        Southampton            NaN
# 195                                                NaN            NaN
# 196                                                               NaN
# 197                                                NaN            NaN
# 198                                                NaN            NaN
# 199                                                NaN            NaN
# 200                                                NaN            NaN
# 201                                                               NaN
# 202                                                               NaN
# 203                                                NaN            NaN
# 204                                                NaN            NaN
# 205                                                               NaN
# 206                                                NaN            NaN
# 207                                                NaN            NaN
# 208                                                NaN            NaN
# 209                                         Pittsburgh            NaN
# 210                                                NaN            NaN
# 211                                                NaN            NaN
# 212                                                NaN            NaN
# 213                                                               NaN
# 214                                                NaN            NaN
#
# [1056 rows x 3 columns]

# %%
df_["Email"].str.contains("@").sum(), df_["Email"].shape
# Out:
# (998, (1056,))

# %%
emcountry={"it":"Italy", "fr":"France", "uk":"UK", "au":"Australia", "br":"Brasil", "cl":"Chile", 
           "nz":"New Zealand","fi":"Finland", "cz":"Czech Republic", "dk":"Damnark","de":"Germany",
          "jp":"Japan", "ca":"Canada", "cn":"China", "dk": "Danmark"}

def statebyEmailEnd(email):
    if not isinstance(email, float):
        if email.split('.')[-1].strip() in emcountry.keys():
            return (emcountry[email.split('.')[-1].strip()])
        else:     return np.nan
    else: return np.nan

# %%
df_['state2'] = df_.Email.apply(statebyEmailEnd)

# %%
df_[['Email', 'state1', 'state2']]
# Out:
#                                   Email         state1   state2
# 0             agol@astro.washington.edu     Washington      NaN
# 1               javier.alonso@uantof.cl            NaN    Chile
# 2         anderson@astro.washington.edu     Washington      NaN
# 3                  andreoni@caltech.edu            NaN      NaN
# 4            antonino.cucchiara@uvi.edu            NaN      NaN
# 5             simone.antoniucci@inaf.it            NaN    Italy
# 6                      arcavi@gmail.com            NaN      NaN
# 7                darnett@as.arizona.edu        Arizona      NaN
# 8                 etibachelet@gmail.com            NaN      NaN
# 9    adriano.baldeschi@northwestern.edu            NaN      NaN
# 10           barbara.balmaverde@inaf.it            NaN    Italy
# 11                   acbecker@gmail.com            NaN      NaN
# 12                      bell@mps.mpg.de            NaN  Germany
# 13                       ecbellm@uw.edu            NaN      NaN
# 14              eberger@cfa.harvard.edu  Massachusetts      NaN
# 15               D.F.Bersier@ljmu.ac.uk             UK       UK
# 16                     abhatta5@umd.edu            NaN      NaN
# 17                         fb55@nyu.edu       New York      NaN
# 18                   rbiswas4@gmail.com            NaN      NaN
# 19            jbloom@astro.berkeley.edu            NaN      NaN
# 20                bob.nichol@port.ac.uk            NaN       UK
# 21               rosaria.bonito@inaf.it            NaN    Italy
# 22                   bono@roma2.infn.it            NaN    Italy
# 23                  tboroson@lco.global            NaN      NaN
# 24        francesco.borsa@brera.inaf.it            NaN    Italy
# 25             maria.botticella@inaf.it            NaN    Italy
# 26                   wnbrandt@gmail.com   Pennsylvania      NaN
# 27                 katja.bricman@ung.si            NaN      NaN
# 28                 enzo.brocato@inaf.it            NaN    Italy
# 29                    tbrown@lco.global            NaN      NaN
# ..                                  ...            ...      ...
# 185                 sembrosk@purdue.edu            NaN      NaN
# 186                                                NaN      NaN
# 187              erin.sheldon@gmail.com            NaN      NaN
# 188        ian.shipsey@physics.ox.ac.uk            NaN       UK
# 189               msimet@andrew.cmu.edu            NaN      NaN
# 190                                                NaN      NaN
# 191             dns@astro.princeton.edu            NaN      NaN
# 192         strauss@astro.princeton.edu            NaN      NaN
# 193                stubbs@g.harvard.edu            NaN      NaN
# 194              m.sullivan@soton.ac.uk            NaN       UK
# 195                   tt@astro.ucla.edu            NaN      NaN
# 196                                                NaN      NaN
# 197                 troxel@utdallas.edu            NaN      NaN
# 198    tsybych@sbhep.physics.sunysb.edu            NaN      NaN
# 199           tyson@physics.ucdavis.edu            NaN      NaN
# 200                      asv13@pitt.edu            NaN      NaN
# 201                                                NaN      NaN
# 202                                                NaN      NaN
# 203               chris.walter@duke.edu            NaN      NaN
# 204                     wang@nhn.ou.edu            NaN      NaN
# 205                                                NaN      NaN
# 206              rwechsler@stanford.edu            NaN      NaN
# 207                    wenaus@gmail.com            NaN      NaN
# 208              matthewwiesner@aol.com            NaN      NaN
# 209                       wmwv@pitt.edu            NaN      NaN
# 210                      yoachim@uw.edu            NaN      NaN
# 211                    zentner@pitt.edu            NaN      NaN
# 212                   zhanhu@nao.cas.cn            NaN    China
# 213                                                NaN      NaN
# 214             joezuntz@googlemail.com            NaN      NaN
#
# [1056 rows x 3 columns]

# %%
df_[(((df_[['state1']].isnull()).values) * ((df_[['state2']].isnull()).values)).flatten()]
# Out:
#                                                Company  \
# 3                                              Caltech
# 4                     University of the Virgin Islands
# 6                                           LCOGT/UCSB
# 8                              Las Cumbres Observatory
# 9                              Northwestern University
# 11                                                 NaN
# 13                       University of Washington/LSST
# 16                 University of Maryland College Park
# 18             Stockholm University/Oskar Klein Centre
# 19                   University of California Berkeley
# 23                                               LCOGT
# 27                           University of Nova Gorica
# 29                                               LCOGT
# 30   Texas A&M / Mitchell Institute for Fundamental...
# 31              South African Astronomical Observatory
# 37            Istituto Nazionale di Astrofisica (INAF)
# 38                                           NASA GSFC
# 40                               Ohio State University
# 41                                             Caltech
# 44                          Louisiana State University
# 47                                   LSST / Consultant
# 48                             Northwestern University
# 50                       Western Washington University
# 51                              Carnegie Observatories
# 54                          University of Pennsylvania
# 57                    Lawrence Livermore National Lab
# 58                    University of Central Lancashire
# 59               INAF-Osservatorio Astronomioo di Roma
# 61                          University of Chicago/KICP
# 64                              Carnegie Observatories
# ..                                                 ...
# 182                                                NaN
# 183
# 184                                                NaN
# 185                                                NaN
# 186
# 187                                                NaN
# 189                                                NaN
# 190
# 191                                                NaN
# 192                                         Princeton
# 193                                                NaN
# 195                                                NaN
# 196
# 197                                                NaN
# 198                                                NaN
# 199                                                NaN
# 200                                                NaN
# 201
# 202
# 203                                                NaN
# 204                                                NaN
# 205
# 206                                                NaN
# 207                                                NaN
# 208                                                NaN
# 209                           University of Pittsburgh
# 210                                                NaN
# 211                                                NaN
# 213
# 214                                                NaN
#
#                                   Email   First Name       Last Name  \
# 3                  andreoni@caltech.edu         Igor        Andreoni
# 4            antonino.cucchiara@uvi.edu    Cucchiara        Antonino
# 6                      arcavi@gmail.com         Iair          Arcavi
# 8                 etibachelet@gmail.com      Etienne        Bachelet
# 9    adriano.baldeschi@northwestern.edu      Adriano       Baldeschi
# 11                   acbecker@gmail.com       Andrew          Becker
# 13                       ecbellm@uw.edu         Eric           Bellm
# 16                     abhatta5@umd.edu       Aparna    Bhattacharya
# 18                   rbiswas4@gmail.com        Rahul          Biswas
# 19            jbloom@astro.berkeley.edu         Josh           Bloom
# 23                  tboroson@lco.global         Todd         Boroson
# 27                 katja.bricman@ung.si        Katja         Bricman
# 29                    tbrown@lco.global          Tim           Brown
# 30              pbrown@physics.tamu.edu     Peter J.           Brown
# 31                    dibnob@saao.ac.za        David         Buckley
# 37            stefano.cavuoti@gmail.com      Stefano         Cavuoti
# 38                  brad.cenko@nasa.gov   S. Bradley           Cenko
# 40                    chornock@ohio.edu         Ryan        Chornock
# 41              ciardi@ipac.caltech.edu        David          Ciardi
# 44         gclayton@fenway.phys.lsu.edu     Geoffrey         Clayton
# 47                       kcook@noao.edu          Kem            Cook
# 48           deanne.coppejans@gmail.com       Deanne       Coppejans
# 50                  kevin.covey@wwu.edu        Kevin           Covey
# 51   pcowperthwaite@carnegiescience.edu       Philip   Cowperthwaite
# 54               cdandrea@sas.upenn.edu        Chris        D'Andrea
# 57                  willdawson@llnl.gov      William          Dawson
# 58               vpdebattista@gmail.com       Victor      Debattista
# 59                   dicrisci@gmail.com     Marcella   Di Criscienzo
# 61                 zdoctor@uchicago.edu       Zoheyr          Doctor
# 64           mdrout@carnegiescience.edu        Maria           Drout
# ..                                  ...          ...             ...
# 182                schneider42@llnl.gov      Michael       Schneider
# 183                                           Daniel         Scolnic
# 184                useljak@berkeley.edu         Uros          Seljak
# 185                 sembrosk@purdue.edu        Glenn       Sembroski
# 186                                        Christian          Setzer
# 187              erin.sheldon@gmail.com         Erin         Sheldon
# 189               msimet@andrew.cmu.edu      Melanie           Simet
# 190                                             Anze          Slosar
# 191             dns@astro.princeton.edu        David         Spergel
# 192         strauss@astro.princeton.edu      Michael         Strauss
# 193                stubbs@g.harvard.edu  Christopher          Stubbs
# 195                   tt@astro.ucla.edu      Tommaso            Treu
# 196                                           Tilman        Troester
# 197                 troxel@utdallas.edu      Michael          Troxel
# 198    tsybych@sbhep.physics.sunysb.edu       Dmitri       Tsybychev
# 199           tyson@physics.ucdavis.edu         Tony           Tyson
# 200                      asv13@pitt.edu      Antonio      Villarreal
# 201                                             Anja  von der Linden
# 202                                           Michal         Vrastil
# 203               chris.walter@duke.edu        Chris          Walter
# 204                     wang@nhn.ou.edu          Yun            Wang
# 205                                           Daniel      Weatherill
# 206              rwechsler@stanford.edu         Risa        Wechsler
# 207                    wenaus@gmail.com        Torre          Wenaus
# 208              matthewwiesner@aol.com      Matthew         Wiesner
# 209                       wmwv@pitt.edu      Michael      Wood-Vasey
# 210                      yoachim@uw.edu        Peter         Yoachim
# 211                    zentner@pitt.edu       Andrew         Zentner
# 213                                          Gong-Bo            Zhao
# 214             joezuntz@googlemail.com          Joe           Zuntz
#
#                                 SC  \
# 3    Transients and Variable Stars
# 4    Transients and Variable Stars
# 6    Transients and Variable Stars
# 8    Transients and Variable Stars
# 9    Transients and Variable Stars
# 11   Transients and Variable Stars
# 13   Transients and Variable Stars
# 16   Transients and Variable Stars
# 18   Transients and Variable Stars
# 19   Transients and Variable Stars
# 23   Transients and Variable Stars
# 27   Transients and Variable Stars
# 29   Transients and Variable Stars
# 30   Transients and Variable Stars
# 31   Transients and Variable Stars
# 37   Transients and Variable Stars
# 38   Transients and Variable Stars
# 40   Transients and Variable Stars
# 41   Transients and Variable Stars
# 44   Transients and Variable Stars
# 47   Transients and Variable Stars
# 48   Transients and Variable Stars
# 50   Transients and Variable Stars
# 51   Transients and Variable Stars
# 54   Transients and Variable Stars
# 57   Transients and Variable Stars
# 58   Transients and Variable Stars
# 59   Transients and Variable Stars
# 61   Transients and Variable Stars
# 64   Transients and Variable Stars
# ..                             ...
# 182                           DESC
# 183                           DESC
# 184                           DESC
# 185                           DESC
# 186                           DESC
# 187                           DESC
# 189                           DESC
# 190                           DESC
# 191                           DESC
# 192                           DESC
# 193                           DESC
# 195                           DESC
# 196                           DESC
# 197                           DESC
# 198                           DESC
# 199                           DESC
# 200                           DESC
# 201                           DESC
# 202                           DESC
# 203                           DESC
# 204                           DESC
# 205                           DESC
# 206                           DESC
# 207                           DESC
# 208                           DESC
# 209                           DESC
# 210                           DESC
# 211                           DESC
# 213                           DESC
# 214                           DESC
#
#                                                  state state1 state2
# 3                                              Caltech    NaN    NaN
# 4                                   the Virgin Islands    NaN    NaN
# 6                                           LCOGT/UCSB    NaN    NaN
# 8                              Las Cumbres Observatory    NaN    NaN
# 9                              Northwestern University    NaN    NaN
# 11                                                 NaN    NaN    NaN
# 13                                     Washington/LSST    NaN    NaN
# 16                               Maryland College Park    NaN    NaN
# 18             Stockholm University/Oskar Klein Centre    NaN    NaN
# 19                                 California Berkeley    NaN    NaN
# 23                                               LCOGT    NaN    NaN
# 27                                         Nova Gorica    NaN    NaN
# 29                                               LCOGT    NaN    NaN
# 30   Texas A&M / Mitchell Institute for Fundamental...    NaN    NaN
# 31              South African Astronomical Observatory    NaN    NaN
# 37            Istituto Nazionale di Astrofisica (INAF)    NaN    NaN
# 38                                           NASA GSFC    NaN    NaN
# 40                               Ohio State University    NaN    NaN
# 41                                             Caltech    NaN    NaN
# 44                          Louisiana State University    NaN    NaN
# 47                                   LSST / Consultant    NaN    NaN
# 48                             Northwestern University    NaN    NaN
# 50                       Western Washington University    NaN    NaN
# 51                              Carnegie Observatories    NaN    NaN
# 54                                        Pennsylvania    NaN    NaN
# 57                    Lawrence Livermore National Lab     NaN    NaN
# 58                                  Central Lancashire    NaN    NaN
# 59               INAF-Osservatorio Astronomioo di Roma    NaN    NaN
# 61                                        Chicago/KICP    NaN    NaN
# 64                              Carnegie Observatories    NaN    NaN
# ..                                                 ...    ...    ...
# 182                                                NaN    NaN    NaN
# 183                                                       NaN    NaN
# 184                                                NaN    NaN    NaN
# 185                                                NaN    NaN    NaN
# 186                                                       NaN    NaN
# 187                                                NaN    NaN    NaN
# 189                                                NaN    NaN    NaN
# 190                                                       NaN    NaN
# 191                                                NaN    NaN    NaN
# 192                                         Princeton     NaN    NaN
# 193                                                NaN    NaN    NaN
# 195                                                NaN    NaN    NaN
# 196                                                       NaN    NaN
# 197                                                NaN    NaN    NaN
# 198                                                NaN    NaN    NaN
# 199                                                NaN    NaN    NaN
# 200                                                NaN    NaN    NaN
# 201                                                       NaN    NaN
# 202                                                       NaN    NaN
# 203                                                NaN    NaN    NaN
# 204                                                NaN    NaN    NaN
# 205                                                       NaN    NaN
# 206                                                NaN    NaN    NaN
# 207                                                NaN    NaN    NaN
# 208                                                NaN    NaN    NaN
# 209                                         Pittsburgh    NaN    NaN
# 210                                                NaN    NaN    NaN
# 211                                                NaN    NaN    NaN
# 213                                                       NaN    NaN
# 214                                                NaN    NaN    NaN
#
# [732 rows x 8 columns]

# %%
df_['state3'] = [s[0] if not isinstance(s[0], float) else s[1] for s in zip(df_['state1'], df_['state2'])]

# %%
pd.Series([em if  isinstance(em, float) else '.'.join(em.split("@")[-1].split('.')[-2:])
 for em in df_['Email'][np.array([isinstance(v, float) 
                                 for v in df_.state3.values ])].values ]).unique()
# Out:
# array(['caltech.edu', 'uvi.edu', 'gmail.com', 'northwestern.edu',
#        'uw.edu', 'umd.edu', 'berkeley.edu', 'lco.global', 'ung.si',
#        'tamu.edu', 'ac.za', 'nasa.gov', 'ohio.edu', 'lsu.edu', 'noao.edu',
#        'wwu.edu', 'carnegiescience.edu', 'upenn.edu', 'llnl.gov',
#        'uchicago.edu', 'ucar.edu', 'psu.edu', 'monash.edu', 'harvard.edu',
#        'lsst.org', 'anl.gov', 'rice.edu', 'aavso.org', 'sdsu.edu',
#        'udel.edu', 'illinois.edu', 'aob.rs', 'rutgers.edu',
#        'washington.edu', 'oswego.edu', 'uwm.edu', 'villanova.edu',
#        'cmu.edu', 'stsci.edu', 'gemini.edu', 'edu.tw', 'uva.nl',
#        'lbl.gov', 'fit.edu', 'wisc.edu', 'ligo.org', 'ohio-state.edu',
#        'lehigh.edu', 'seti.org', 'asu.edu', 'stanford.edu',
#        'columbia.edu', 'vanderbilt.edu', 'princeton.edu', 'konkoly.hu',
#        'gwu.edu', 'nyu.edu', 'pitt.edu', 'mit.edu', 'edu.pl',
#        'akhlaghi.org', 'ucdavis.edu', 'arizona.edu', 'aubourg.net',
#        'yale.edu', 'gmu.edu', 'msu.edu', 'lcogt.net', 'uwyo.edu',
#        'swri.edu', 'uci.edu', 'ucsd.edu', 'cofc.edu', 'cornell.edu',
#        'nrao.edu', 'umich.edu', 'nku.edu', 'brown.edu', 'hawaii.edu',
#        'fnal.gov', 'navy.mil', 'utexas.edu', 'utdallas.edu', 'gatech.edu',
#        'osu.edu', 'adlerplanetarium.org', 'att.net', 'hws.edu', 'gsu.edu',
#        'umkc.edu', 'jarvis.net', 'h-bar.com', 'virginia.edu', 'rit.edu',
#        'ou.edu', 'iac.es', 'ac.rs', 'albany.edu', 'mac.com', 'usna.edu',
#        'haverford.edu', 'icrar.org', 'nau.edu', 'lowell.edu', 'psi.edu',
#        'jhu.edu', 'bnl.gov', 'gmail.com ', 'stonybrook.edu', 'purdue.edu',
#        'normalesup.org', 'columbusstate.edu', 'byu.edu', 'usra.edu',
#        'ucr.edu', 'ucsc.edu', 'ucolick.org', 'indiana.edu', 'ufl.edu',
#        'ucf.edu', 'unl.edu', 'oberlin.edu', 'mtu.edu', 'apsu.edu',
#        'gov.pl', 'ucsb.edu', 'dartmouth.edu', 'ucla.edu', 'nau.edu ',
#        'sunysb.edu', 'stvincent.edu', 'duke.edu', 'umass.edu', 'bu.edu',
#        'aol.com', 'Duke.edu', 'lanl.gov', 'drexel.edu', 'case.edu',
#        'googlemail.com', ''], dtype=object)

# %%
df_.state2.unique(), df_.state3.unique()
# Out:
# (array([nan, 'Chile', 'Italy', 'Germany', 'UK', 'France', 'New Zealand',
#         'Canada', 'Brasil', 'China', 'Australia', 'Czech Republic',
#         'Finland', 'Danmark'], dtype=object),
#  array(['Washington', 'Chile', nan, 'Italy', 'Arizona', 'Germany',
#         'Massachusetts', 'UK', 'New York', 'Pennsylvania', 'Michigan',
#         'France', 'New Zealand', 'California', 'New Jersey', 'Canada',
#         'Brasil', 'China', 'Australia', 'Czech Republic', 'Finland',
#         'Danmark'], dtype=object))

# %%
stateByEmail = {'ucdavis.edu':"California", 
 'uchicago.edu': "Illinois",
 'psu.edu': "Pennsylvania",
 'stanford.edu':"California",
       'umich.edu': "Michigan",
 'harvard.edu': "Massachusetts",
 'upenn.edu': "Pennsylvania",  
 'osu.edu':"Ohio",
       'berkeley.edu':"California", 
 'noao.edu':"Arizona", 
 'umd.edu':"Maryland", 
 'lcogt.net':"California", 
 'princeton.edu':"New Jersey",
       'asu.edu':"Arizona", 
 'nasa.gov':np.nan, 
 'sarahbridle.net':np.nan, 
 'ttu.edu':"Texas", 
 'uwyo.edu':"Wyoming",
       'tamu.edu':"Texas", 
 'caltech.edu':"California", 
 'illinois.edu':"Illinois", 
 'jhu.edu':"Maryland", 
 'uci.edu':"California",
       'ucsd.edu':"California", 
 'lsst.org':"Washington", 
 'yale.edu':"Connecticut", 
 'cofc.edu':"South Carolina", 
 'uw.edu':"Washington", 
 'cas.cn':np.nan,
       'purdue.edu':"Indiana", 
 'cornell.edu':"Illinois", 
 'arizona.edu':"Arizona", 
 'bnl.gov':"California", 
 'nrao.edu':np.nan,
       'ohio.edu':"Ohio", 
 'wayne.edu':"Michigan", 
 'lsu.edu':"Louisiana", 
 'washington.edu':"Washington", 
 'wwu.edu':"Washington",
       'amherst.edu':"Massachusetts", 
 'columbia.edu':"New York", 
 'uvi.edu':"Virginia", 
 'dawsonresearch.com':"California",
       'aip.de':"Germany", 
 'nku.edu':"Kentucky", 
 'llnl.gov':"California", 
 'brown.edu':"Rhode Island", 
 'hawaii.edu':"Hawaii",
       'me.com':np.nan, 
 'ucsb.edu':"California", 
 'fnal.gov':"Illinois", 
 'carnegiescience.edu':"California",
       'northwestern.edu':"Illinois", 
 'stsci.edu':"DC", 
 'navy.mil':"DC",
 'utexas.edu':"Texas", 
       'cmu.edu':"Pennsylvania", 
 'lanl.gov':"California", 
 'nd.edu':"Delaware", 
 'rutgers.edu':"New Jersey", 
 'ou.edu':"Oklahoma",
       'udel.edu':"Delaware", 
 'ung.si':"Slovenia", 
 'gatech.edu':"Georgia", 
 'ucolick.org':"California", 
 'anl.gov':"Illinois",
       'villanova.edu':"Pennsylvania", 
 'colorado.edu':"Colorado", 
 'adlerplanetarium.org':"Illinois",
       'haverford.edu':"Pennsylvania", 
 'att.net':np.nan, 
 'rice.edu':"Texas", 
 'hws.edu':"Hawaii", 
 'aavso.org':np.nan,
       'gsu.edu':"Georgia", 
 'umkc.edu':"Missouri", 
 'bell-labs.com':"California", 
 'psi.edu':"Pennsylvania",
       'uni-heidelberg.de':"Germany", 
 'utdallas.edu':"Texas", 
 'utah.edu':"Utah", 
 'jarvis.net':np.nan,
       'h-bar.com':np.nan, 
 'aob.rs':np.nan, 
 'virginia.edu':"Virginia", 
 'oswego.edu':"New York", 
 'uwm.edu':"Masachussets",
       'lbl.gov':"California", 
 'iac.es':"Spain", 
 'ac.rs':"Serbia", 
 'albany.edu':"New York", 
 'mac.com':np.nan, 
'usna.edu':"Maryland",
       'yahoo.com':np.nan, 
 'see.com':np.nan, 
 'ufl.edu':"Florida", 
 'icrar.org':"Austraalia", 
 'gemini.edu':"Chile",
       'nau.edu':"Arizona", 
 'lowell.edu':"Masachussets", 
 'pitt.edu':"Pennsylvania", 
 'gmail.com ':np.nan, 
 'fit.edu':"Florida",
       'longwood.edu':"Virginia", 
 'lehigh.edu':"Pennsylvania", 
 'normalesup.org':"France",
       'missouristate.edu':"Missouri", 
 'columbusstate.edu':"Ohio", 
 'byu.edu':"Utah", 
 'mpg.de':"Germany",
       'usra.edu':"Maryland", 
 'ucr.edu':"California", 
 'ucla.edu':"California", 
 'drexel.edu':"Pennsylvania", 'ucsc.edu':"California",
       'jhuapl.edu':"Maryland", 
 'umn.edu':"Minnesota", 
 'indiana.edu':"Indiana", 
 'ucf.edu':"Florida", 
 'unl.edu':"Nebraska",
       'sdsu.edu':"California", 
 'mtu.edu':"Michigan", 
 'unt.edu':"Texas", 
 'ciw.edu':"California", 
 'apsu.edu':"Tennessee", 
 'uc.edu':"California",
       'gov.pl':"Poland", 
 'lynchburg.edu':"Virginia", 
 'ornl.gov':"Tennessee", 
 'vanderbilt.edu':"Tennessee", 
 'swri.edu':"Colorado",
       'msu.edu':"Massachusetts", 
 'lco.global':"California", 
 'ipmu.jp':"Japan", 
 'dartmouth.edu':"New Hampshire", 
 'nau.edu ':"Arizona",
  'nau.edu':"Arizona",
       'sunysb.edu':"New York", 
 'ubc.ca':"California", 
 'stvincent.edu':"Pennsylvania", 
 'uh.edu':"Texas", 
 'duke.edu':"North Carolina",
                'uiuc.edu':"Illinois",
 'umass.edu':"Massachusetts", 
 'bu.edu':"Massachusetts", 
 'aol.com':np.nan, 
 'Duke.edu':"North Carolina", 
 'nyu.edu':"New York",
 'jpl.nasa.gov':"California", 
 'nao.cas.cn':"China", 
 'aoc.nrao.edu':"Arizona", 
  'seti.org':"California", 
'unm.edu':"New Mexico", 
 'mit.edu': "Massachusetts",
'b612foundation.org':"Washington", 
'aob.rs':"Serbia", 
'astro.rit.edu':"New York", 'nrao.edu':"Arizona",
'gmu.edu':"Virginia",
'mnsu.edu':"Minnesota", 
'oberlin.edu':"Ohio", 
'konkoly.hu':"Hungary", 
'usf.edu':"Florida",
'case.edu':"Ohio"}
     #  'case.edu'
    
def sttatetbyemailend(email):
    if isinstance(email, float): return np.nan
    else: 
        em = '.'.join(email.split("@")[-1].split('.')[-2:])
        if em in stateByEmail.keys():
            return stateByEmail[em]
        else: return np.nan
        
def statebydesc(fn, ln):
    return descmembers[(descmembers.loc["First Name"] == fn) * (descmembers.loc["Last Name"] == ln) ]["State"],\
        descmembers[(descmembers.loc["First Name"] == fn) * (descmembers.loc["Last Name"] == ln) ]["Cpuntry"]

# %%
df_['state4'] = df_.Email.apply(sttatetbyemailend)

# %%
df_.state4.describe()
# Out:
# count            555
# unique            43
# top       California
# freq             137
# Name: state4, dtype: object

# %%
df_['country'] = [s[0] if not isinstance(s[0], float) else s[1] for s in zip(df_['state3'], df_['state4'])]

# %%
df_.country.describe()
# Out:
# count            847
# unique            53
# top       California
# freq             136
# Name: country, dtype: object

# %%
(((df_[['country']].isnull()).values)).flatten()
# Out:
# array([False, False, False, ..., False,  True,  True])

# %%
def getemail(x):
    if not x=='' :
        return x.split("@")[1] 
    else: return ''

    df_[(((df_[['state1']].isnull()).values) * ((df_[['state2']].isnull()).values) * 
     ((
         df_[['country']].isnull()).values)).flatten()].Email.apply(getemail()).unique()

# %%
df_.describe()
# Out:
#        Company Email First Name Last Name                                  SC  \
# count      308  1056       1056      1056                                1056
# unique     156   732        527       730                                   8
# top                       David   Strauss  Stars, Milky Way, and Local Volume
# freq        58    58         25         6                                 237
#
#        state         state1 state2 state3      state4     country
# count    308             37    291    324         555         847
# unique   156             11     13     21          43          53
# top           Massachusetts  Italy  Italy  California  California
# freq      58             10     82     82         137         136

# %%
df_.to_csv("mydb.csv")

# %%
df_ = pd.read_csv("mydb.csv")

# %%
df_.shape, df_.dropna(subset=["country"]).shape
# Out:
# ((1056, 12), (847, 12))

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /Users/fbb/anaconda3/lib/python3.7/site-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['f']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
countriesshp = gpd.GeoDataFrame.from_file("TM_WORLD_BORDERS_SIMPL-0.3.shp")
                                    
aax = countriesshp.plot()
statetsshp = gpd.GeoDataFrame.from_file("cb_2016_us_state_500k.shp")
statetsshp.plot(ax=ax, color='red')

# %%
statetsshp.head()
# Out:
#   STATEFP   STATENS     AFFGEOID GEOID STUSPS        NAME LSAD          ALAND  \
# 0      01  01779775  0400000US01    01     AL     Alabama   00   131173688951
# 1      02  01785533  0400000US02    02     AK      Alaska   00  1477946266785
# 2      04  01779777  0400000US04    04     AZ     Arizona   00   294198560125
# 3      05  00068085  0400000US05    05     AR    Arkansas   00   134771517596
# 4      06  01779778  0400000US06    06     CA  California   00   403501101370
#
#          AWATER                                           geometry
# 0    4593686489  (POLYGON ((-88.053375 30.506987, -88.051087999...
# 1  245390495931  (POLYGON ((-134.737262 58.261354, -134.73441 5...
# 2    1027346486  POLYGON ((-114.816294 32.508038, -114.814321 3...
# 3    2960191698  POLYGON ((-94.6178329666013 36.4994141203285, ...
# 4   20466718403  (POLYGON ((-118.604415 33.478552, -118.598783 ...

# %%
countriesshp["NAME"][["United" in cn for cn in  countriesshp["NAME"].values]]
# Out:
# 150    United States Minor Outlying Islands
# 204             United Republic of Tanzania
# 206                          United Kingdom
# 208                           United States
# 216            United States Virgin Islands
# 227                    United Arab Emirates
# Name: NAME, dtype: object

# %%
dfgroup = df_.drop_duplicates("Email").\
    groupby("country").count()[["Last Name"]].\
    rename(columns={"Last Name":"count"})

# %%
dfgroup.head()
# Out:
#             count
# country
# Arizona        37
# Austraalia      1
# Australia       5
# Brasil          7
# California     95

# %%
countriesshp.merge(dfgroup, right_index=True, left_on="NAME")["count"].describe()
# Out:
# count    16.00000
# mean     10.68750
# std      18.78907
# min       1.00000
# 25%       2.00000
# 50%       3.00000
# 75%       5.00000
# max      67.00000
# Name: count, dtype: float64

# %%
statetsshp.NAME
# Out:
# 0                                          Alabama
# 1                                           Alaska
# 2                                          Arizona
# 3                                         Arkansas
# 4                                       California
# 5                                         Colorado
# 6                                      Connecticut
# 7                                         Delaware
# 8                             District of Columbia
# 9                                          Georgia
# 10                                          Hawaii
# 11                                           Idaho
# 12                                        Illinois
# 13                                         Indiana
# 14                                            Iowa
# 15                                          Kansas
# 16                                        Maryland
# 17                                       Minnesota
# 18                                     Mississippi
# 19                                         Montana
# 20                                          Nevada
# 21                                      New Jersey
# 22                                      New Mexico
# 23                                    North Dakota
# 24                                        Oklahoma
# 25                                    Pennsylvania
# 26                                  South Carolina
# 27                                    South Dakota
# 28                                            Utah
# 29                                         Vermont
# 30                                   West Virginia
# 31                                         Wyoming
# 32                                  American Samoa
# 33                                     Puerto Rico
# 34                                         Florida
# 35                                        Kentucky
# 36                                       Louisiana
# 37                                           Maine
# 38                                   Massachusetts
# 39                                        Michigan
# 40                                        Missouri
# 41                                        Nebraska
# 42                                   New Hampshire
# 43                                        New York
# 44                                  North Carolina
# 45                                            Ohio
# 46                                          Oregon
# 47                                    Rhode Island
# 48                                       Tennessee
# 49                                           Texas
# 50                                        Virginia
# 51                                      Washington
# 52                                       Wisconsin
# 53                                            Guam
# 54    Commonwealth of the Northern Mariana Islands
# 55                    United States Virgin Islands
# Name: NAME, dtype: object

# %%
statetsshp.merge(dfgroup, right_index=True, left_on="NAME")["count"].describe()
# Out:
# count    32.000000
# mean     11.562500
# std      19.076987
# min       1.000000
# 25%       2.000000
# 50%       4.000000
# 75%       9.250000
# max      95.000000
# Name: count, dtype: float64

# %%
df_.country[[v  == "UK" for v in df_.country.values]] = "United Kingdom"
# Out:
# /Users/fbb/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_.country[[v  == "United Kingdom" for v in df_.country.values]]
df_.country[[v  == "DC" for v in df_.country.values]]
# Out:
# 126    DC
# 161    DC
# 186    DC
# 232    DC
# 412    DC
# 413    DC
# 473    DC
# 686    DC
# 983    DC
# Name: country, dtype: object

# %%
df_.country[[v  == "DC" for v in df_.country.values]] = "Maryland"
# Out:
# /Users/fbb/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
i0 = df_[df_["Last Name"] == "Lochner"].index#,#["state5"] = "South Africa"
i1 = df_[df_["Last Name"] == "Buckley"].index#["state5"] = "South Africa"
df_.set_value(i0, 'country', "South Africa")
df_.set_value(i1, 'country', "South Africa")
# Out:
# /Users/fbb/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/fbb/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   after removing the cwd from sys.path.
#       Unnamed: 0                                            Company  \
# 0              0                           University of Washington
# 1              1                                                NaN
# 2              2                           University of Washington
# 3              3                                            Caltech
# 4              4                   University of the Virgin Islands
# 5              5            INAF - Osservatorio Astronomico di Roma
# 6              6                                         LCOGT/UCSB
# 7              7                              University of Arizona
# 8              8                            Las Cumbres Observatory
# 9              9                            Northwestern University
# 10            10  INAF - Osservatorio Astrofisico di Torino / SN...
# 11            11                                                NaN
# 12            12                      University of Texas at Austin
# 13            13                      University of Washington/LSST
# 14            14        Harvard Smithsonian Center for Astrophysics
# 15            15                   Liverpool John Moores University
# 16            16                University of Maryland College Park
# 17            17                                New York University
# 18            18            Stockholm University/Oskar Klein Centre
# 19            19                  University of California Berkeley
# 20            20                           University of Portsmouth
# 21            21         INAF - Osservatorio Astronomico di Palermo
# 22            22  University of Rome Tor Vergata -- INAF Rome as...
# 23            23                                              LCOGT
# 24            24           INAF - Osservatorio Astronomico di Brera
# 25            25     INAF - Osservatorio Astronomico di Capodimonte
# 26            26                      Pennsylvania State University
# 27            27                          University of Nova Gorica
# 28            28            INAF - Osservatorio Astronomico di Rome
# 29            29                                              LCOGT
# ...          ...                                                ...
# 1026         185                                                NaN
# 1027         186                                                NaN
# 1028         187                                                NaN
# 1029         188                                                NaN
# 1030         189                                                NaN
# 1031         190                                                NaN
# 1032         191                                                NaN
# 1033         192                                         Princeton
# 1034         193                                                NaN
# 1035         194                          University of Southampton
# 1036         195                                                NaN
# 1037         196                                                NaN
# 1038         197                                                NaN
# 1039         198                                                NaN
# 1040         199                                                NaN
# 1041         200                                                NaN
# 1042         201                                                NaN
# 1043         202                                                NaN
# 1044         203                                                NaN
# 1045         204                                                NaN
# 1046         205                                                NaN
# 1047         206                                                NaN
# 1048         207                                                NaN
# 1049         208                                                NaN
# 1050         209                           University of Pittsburgh
# 1051         210                                                NaN
# 1052         211                                                NaN
# 1053         212                                                NaN
# 1054         213                                                NaN
# 1055         214                                                NaN
#
#                                    Email    First Name       Last Name  \
# 0              agol@astro.washington.edu          Eric            Agol
# 1                javier.alonso@uantof.cl        Javier   Alonso-Garcia
# 2          anderson@astro.washington.edu         Scott        Anderson
# 3                   andreoni@caltech.edu          Igor        Andreoni
# 4             antonino.cucchiara@uvi.edu     Cucchiara        Antonino
# 5              simone.antoniucci@inaf.it        Simone      Antoniucci
# 6                       arcavi@gmail.com          Iair          Arcavi
# 7                 darnett@as.arizona.edu         David          Arnett
# 8                  etibachelet@gmail.com       Etienne        Bachelet
# 9     adriano.baldeschi@northwestern.edu       Adriano       Baldeschi
# 10            barbara.balmaverde@inaf.it       Barbara      Balmaverde
# 11                    acbecker@gmail.com        Andrew          Becker
# 12                       bell@mps.mpg.de        Keaton            Bell
# 13                        ecbellm@uw.edu          Eric           Bellm
# 14               eberger@cfa.harvard.edu           Edo          Berger
# 15                D.F.Bersier@ljmu.ac.uk         David         Bersier
# 16                      abhatta5@umd.edu        Aparna    Bhattacharya
# 17                          fb55@nyu.edu      Federica          Bianco
# 18                    rbiswas4@gmail.com         Rahul          Biswas
# 19             jbloom@astro.berkeley.edu          Josh           Bloom
# 20                 bob.nichol@port.ac.uk        Nichol             Bob
# 21                rosaria.bonito@inaf.it       Rosaria          Bonito
# 22                    bono@roma2.infn.it      Giuseppe            Bono
# 23                   tboroson@lco.global          Todd         Boroson
# 24         francesco.borsa@brera.inaf.it     Francesco           Borsa
# 25              maria.botticella@inaf.it  Maria Teresa      Botticella
# 26                    wnbrandt@gmail.com          Niel          Brandt
# 27                  katja.bricman@ung.si         Katja         Bricman
# 28                  enzo.brocato@inaf.it          Enzo         Brocato
# 29                     tbrown@lco.global           Tim           Brown
# ...                                  ...           ...             ...
# 1026                 sembrosk@purdue.edu         Glenn       Sembroski
# 1027                                 NaN     Christian          Setzer
# 1028              erin.sheldon@gmail.com          Erin         Sheldon
# 1029        ian.shipsey@physics.ox.ac.uk           Ian         Shipsey
# 1030               msimet@andrew.cmu.edu       Melanie           Simet
# 1031                                 NaN          Anze          Slosar
# 1032             dns@astro.princeton.edu         David         Spergel
# 1033         strauss@astro.princeton.edu       Michael         Strauss
# 1034                stubbs@g.harvard.edu   Christopher          Stubbs
# 1035              m.sullivan@soton.ac.uk          Mark        Sullivan
# 1036                   tt@astro.ucla.edu       Tommaso            Treu
# 1037                                 NaN        Tilman        Troester
# 1038                 troxel@utdallas.edu       Michael          Troxel
# 1039    tsybych@sbhep.physics.sunysb.edu        Dmitri       Tsybychev
# 1040           tyson@physics.ucdavis.edu          Tony           Tyson
# 1041                      asv13@pitt.edu       Antonio      Villarreal
# 1042                                 NaN          Anja  von der Linden
# 1043                                 NaN        Michal         Vrastil
# 1044               chris.walter@duke.edu         Chris          Walter
# 1045                     wang@nhn.ou.edu           Yun            Wang
# 1046                                 NaN        Daniel      Weatherill
# 1047              rwechsler@stanford.edu          Risa        Wechsler
# 1048                    wenaus@gmail.com         Torre          Wenaus
# 1049              matthewwiesner@aol.com       Matthew         Wiesner
# 1050                       wmwv@pitt.edu       Michael      Wood-Vasey
# 1051                      yoachim@uw.edu         Peter         Yoachim
# 1052                    zentner@pitt.edu        Andrew         Zentner
# 1053                   zhanhu@nao.cas.cn            Hu            Zhan
# 1054                                 NaN       Gong-Bo            Zhao
# 1055             joezuntz@googlemail.com           Joe           Zuntz
#
#                                  SC  \
# 0     Transients and Variable Stars
# 1     Transients and Variable Stars
# 2     Transients and Variable Stars
# 3     Transients and Variable Stars
# 4     Transients and Variable Stars
# 5     Transients and Variable Stars
# 6     Transients and Variable Stars
# 7     Transients and Variable Stars
# 8     Transients and Variable Stars
# 9     Transients and Variable Stars
# 10    Transients and Variable Stars
# 11    Transients and Variable Stars
# 12    Transients and Variable Stars
# 13    Transients and Variable Stars
# 14    Transients and Variable Stars
# 15    Transients and Variable Stars
# 16    Transients and Variable Stars
# 17    Transients and Variable Stars
# 18    Transients and Variable Stars
# 19    Transients and Variable Stars
# 20    Transients and Variable Stars
# 21    Transients and Variable Stars
# 22    Transients and Variable Stars
# 23    Transients and Variable Stars
# 24    Transients and Variable Stars
# 25    Transients and Variable Stars
# 26    Transients and Variable Stars
# 27    Transients and Variable Stars
# 28    Transients and Variable Stars
# 29    Transients and Variable Stars
# ...                             ...
# 1026                           DESC
# 1027                           DESC
# 1028                           DESC
# 1029                           DESC
# 1030                           DESC
# 1031                           DESC
# 1032                           DESC
# 1033                           DESC
# 1034                           DESC
# 1035                           DESC
# 1036                           DESC
# 1037                           DESC
# 1038                           DESC
# 1039                           DESC
# 1040                           DESC
# 1041                           DESC
# 1042                           DESC
# 1043                           DESC
# 1044                           DESC
# 1045                           DESC
# 1046                           DESC
# 1047                           DESC
# 1048                           DESC
# 1049                           DESC
# 1050                           DESC
# 1051                           DESC
# 1052                           DESC
# 1053                           DESC
# 1054                           DESC
# 1055                           DESC
#
#                                                   state         state1  \
# 0                                            Washington     Washington
# 1                                                   NaN            NaN
# 2                                            Washington     Washington
# 3                                               Caltech            NaN
# 4                                    the Virgin Islands            NaN
# 5               INAF - Osservatorio Astronomico di Roma            NaN
# 6                                            LCOGT/UCSB            NaN
# 7                                               Arizona        Arizona
# 8                               Las Cumbres Observatory            NaN
# 9                               Northwestern University            NaN
# 10    INAF - Osservatorio Astrofisico di Torino / SN...            NaN
# 11                                                  NaN            NaN
# 12                                      Texas at Austin            NaN
# 13                                      Washington/LSST            NaN
# 14          Harvard Smithsonian Center for Astrophysics  Massachusetts
# 15                     Liverpool John Moores University             UK
# 16                                Maryland College Park            NaN
# 17                                  New York University       New York
# 18              Stockholm University/Oskar Klein Centre            NaN
# 19                                  California Berkeley            NaN
# 20                                           Portsmouth            NaN
# 21           INAF - Osservatorio Astronomico di Palermo            NaN
# 22    Rome Tor Vergata -- INAF Rome astronomical Obs...            NaN
# 23                                                LCOGT            NaN
# 24             INAF - Osservatorio Astronomico di Brera            NaN
# 25       INAF - Osservatorio Astronomico di Capodimonte            NaN
# 26                        Pennsylvania State University   Pennsylvania
# 27                                          Nova Gorica            NaN
# 28              INAF - Osservatorio Astronomico di Rome            NaN
# 29                                                LCOGT            NaN
# ...                                                 ...            ...
# 1026                                                NaN            NaN
# 1027                                                NaN            NaN
# 1028                                                NaN            NaN
# 1029                                                NaN            NaN
# 1030                                                NaN            NaN
# 1031                                                NaN            NaN
# 1032                                                NaN            NaN
# 1033                                         Princeton             NaN
# 1034                                                NaN            NaN
# 1035                                        Southampton            NaN
# 1036                                                NaN            NaN
# 1037                                                NaN            NaN
# 1038                                                NaN            NaN
# 1039                                                NaN            NaN
# 1040                                                NaN            NaN
# 1041                                                NaN            NaN
# 1042                                                NaN            NaN
# 1043                                                NaN            NaN
# 1044                                                NaN            NaN
# 1045                                                NaN            NaN
# 1046                                                NaN            NaN
# 1047                                                NaN            NaN
# 1048                                                NaN            NaN
# 1049                                                NaN            NaN
# 1050                                         Pittsburgh            NaN
# 1051                                                NaN            NaN
# 1052                                                NaN            NaN
# 1053                                                NaN            NaN
# 1054                                                NaN            NaN
# 1055                                                NaN            NaN
#
#        state2         state3          state4         country
# 0         NaN     Washington      Washington      Washington
# 1       Chile          Chile             NaN           Chile
# 2         NaN     Washington      Washington      Washington
# 3         NaN            NaN      California      California
# 4         NaN            NaN        Virginia        Virginia
# 5       Italy          Italy             NaN           Italy
# 6         NaN            NaN             NaN             NaN
# 7         NaN        Arizona         Arizona         Arizona
# 8         NaN            NaN             NaN             NaN
# 9         NaN            NaN        Illinois        Illinois
# 10      Italy          Italy             NaN           Italy
# 11        NaN            NaN             NaN             NaN
# 12    Germany        Germany         Germany         Germany
# 13        NaN            NaN      Washington      Washington
# 14        NaN  Massachusetts   Massachusetts   Massachusetts
# 15         UK             UK             NaN  United Kingdom
# 16        NaN            NaN        Maryland        Maryland
# 17        NaN       New York        New York        New York
# 18        NaN            NaN             NaN             NaN
# 19        NaN            NaN      California      California
# 20         UK             UK             NaN  United Kingdom
# 21      Italy          Italy             NaN           Italy
# 22      Italy          Italy             NaN           Italy
# 23        NaN            NaN      California      California
# 24      Italy          Italy             NaN           Italy
# 25      Italy          Italy             NaN           Italy
# 26        NaN   Pennsylvania             NaN    Pennsylvania
# 27        NaN            NaN        Slovenia        Slovenia
# 28      Italy          Italy             NaN           Italy
# 29        NaN            NaN      California      California
# ...       ...            ...             ...             ...
# 1026      NaN            NaN         Indiana         Indiana
# 1027      NaN            NaN             NaN             NaN
# 1028      NaN            NaN             NaN             NaN
# 1029       UK             UK             NaN  United Kingdom
# 1030      NaN            NaN    Pennsylvania    Pennsylvania
# 1031      NaN            NaN             NaN             NaN
# 1032      NaN            NaN      New Jersey      New Jersey
# 1033      NaN            NaN      New Jersey      New Jersey
# 1034      NaN            NaN   Massachusetts   Massachusetts
# 1035       UK             UK             NaN  United Kingdom
# 1036      NaN            NaN      California      California
# 1037      NaN            NaN             NaN             NaN
# 1038      NaN            NaN           Texas           Texas
# 1039      NaN            NaN        New York        New York
# 1040      NaN            NaN      California      California
# 1041      NaN            NaN    Pennsylvania    Pennsylvania
# 1042      NaN            NaN             NaN             NaN
# 1043      NaN            NaN             NaN             NaN
# 1044      NaN            NaN  North Carolina  North Carolina
# 1045      NaN            NaN        Oklahoma        Oklahoma
# 1046      NaN            NaN             NaN             NaN
# 1047      NaN            NaN      California      California
# 1048      NaN            NaN             NaN             NaN
# 1049      NaN            NaN             NaN             NaN
# 1050      NaN            NaN    Pennsylvania    Pennsylvania
# 1051      NaN            NaN      Washington      Washington
# 1052      NaN            NaN    Pennsylvania    Pennsylvania
# 1053    China          China             NaN           China
# 1054      NaN            NaN             NaN             NaN
# 1055      NaN            NaN             NaN             NaN
#
# [1056 rows x 12 columns]

# %%
df_.columns
# Out:
# Index(['Unnamed: 0', 'Company', 'Email', 'First Name', 'Last Name', 'SC',
#        'state', 'state1', 'state2', 'state3', 'state4', 'country'],
#       dtype='object')

# %%
df_[['Company', 'Email', 'First Name', 'Last Name', 'SC',
       'state']].to_csv("SCcontactDBmodifiedFBBAugust2020.csv", index=False)

# %%
df_.head()
# Out:
#    Unnamed: 0                           Company  \
# 0           0          University of Washington
# 1           1                               NaN
# 2           2          University of Washington
# 3           3                           Caltech
# 4           4  University of the Virgin Islands
#
#                            Email First Name      Last Name  \
# 0      agol@astro.washington.edu       Eric           Agol
# 1        javier.alonso@uantof.cl     Javier  Alonso-Garcia
# 2  anderson@astro.washington.edu      Scott       Anderson
# 3           andreoni@caltech.edu       Igor       Andreoni
# 4     antonino.cucchiara@uvi.edu  Cucchiara       Antonino
#
#                               SC               state      state1 state2  \
# 0  Transients and Variable Stars          Washington  Washington    NaN
# 1  Transients and Variable Stars                 NaN         NaN  Chile
# 2  Transients and Variable Stars          Washington  Washington    NaN
# 3  Transients and Variable Stars             Caltech         NaN    NaN
# 4  Transients and Variable Stars  the Virgin Islands         NaN    NaN
#
#        state3      state4     country
# 0  Washington  Washington  Washington
# 1       Chile         NaN       Chile
# 2  Washington  Washington  Washington
# 3         NaN  California  California
# 4         NaN    Virginia    Virginia

# %%
df_.country.unique()
# Out:
# array(['Washington', 'Chile', 'California', 'Virginia', 'Italy', nan,
#        'Arizona', 'Illinois', 'Germany', 'Massachusetts',
#        'United Kingdom', 'Maryland', 'New York', 'Pennsylvania',
#        'Slovenia', 'Texas', 'South Africa', 'Michigan', 'Ohio',
#        'Louisiana', 'France', 'New Zealand', 'Delaware', 'Serbia',
#        'New Jersey', 'Masachussets', 'Florida', 'Tennessee', 'Hungary',
#        'Connecticut', 'Canada', 'Brasil', 'Wyoming', 'Colorado',
#        'South Carolina', 'China', 'Kentucky', 'Australia', 'Rhode Island',
#        'Hawaii', 'Czech Republic', 'Georgia', 'Missouri', 'Finland',
#        'Oklahoma', 'Spain', 'Austraalia', 'Indiana', 'Utah', 'Nebraska',
#        'Poland', 'New Hampshire', 'Danmark', 'North Carolina'],
#       dtype=object)

# %%
dfgroup = df_.\
    groupby("country").count()[["Last Name"]].\
    rename(columns={"Last Name":"count"})

#.drop_duplicates("Email").\

# %%
dfgroup.sort_values("count")
# Out:
#                 count
# country
# Wyoming             1
# Missouri            1
# Nebraska            1
# Hungary             1
# New Hampshire       1
# Poland              1
# Finland             1
# Danmark             1
# Utah                1
# Austraalia          1
# Kentucky            1
# Rhode Island        2
# South Africa        2
# South Carolina      2
# Czech Republic      3
# Louisiana           3
# Delaware            3
# Oklahoma            3
# North Carolina      3
# Spain               3
# Tennessee           3
# Slovenia            3
# Serbia              4
# New Zealand         4
# Masachussets        4
# Canada              4
# China               4
# Colorado            4
# Florida             4
# Georgia             4
# Indiana             5
# Australia           5
# Virginia            6
# Connecticut         6
# Germany             7
# Michigan            7
# Brasil              7
# Ohio                8
# Hawaii              8
# New York           15
# Texas              17
# New Jersey         18
# Maryland           21
# Massachusetts      39
# France             44
# Arizona            47
# Illinois           50
# Chile              54
# Pennsylvania       54
# Washington         59
# United Kingdom     81
# Italy              82
# California        136

# %%
dfgroup.index
# Out:
# Index(['Arizona', 'Austraalia', 'Australia', 'Brasil', 'California', 'Canada',
#        'Chile', 'China', 'Colorado', 'Connecticut', 'Czech Republic',
#        'Danmark', 'Delaware', 'Finland', 'Florida', 'France', 'Georgia',
#        'Germany', 'Hawaii', 'Hungary', 'Illinois', 'Indiana', 'Italy',
#        'Kentucky', 'Louisiana', 'Maryland', 'Masachussets', 'Massachusetts',
#        'Michigan', 'Missouri', 'Nebraska', 'New Hampshire', 'New Jersey',
#        'New York', 'New Zealand', 'North Carolina', 'Ohio', 'Oklahoma',
#        'Pennsylvania', 'Poland', 'Rhode Island', 'Serbia', 'Slovenia',
#        'South Africa', 'South Carolina', 'Spain', 'Tennessee', 'Texas',
#        'United Kingdom', 'Utah', 'Virginia', 'Washington', 'Wyoming'],
#       dtype='object', name='country')

# %%
'Arizona',  'California', 'Colorado', 'Connecticut', 'Delaware', 'Florida', 
'Georgia',
        'New Hampshire', 'Hawaii',  'Illinois', 'Indiana',
        'Kentucky', 'Louisiana', 'Maryland', 
       'Massachusetts', 'Michigan', 'Missouri', 'Nebraska', 'New Jersey',
       'New York',  'North Carolina', 'Ohio', 'Oklahoma',
       'Pennsylvania', 'Poland', 'Rhode Island',
       'South Carolina', 'Spain', 'Tennessee', 'Texas',
       'Utah', 'Virginia', 'Washington', 'Wyoming'
# Out:
#   File "<tokenize>", line 5
#     'Massachusetts', 'Michigan', 'Missouri', 'Nebraska', 'New Jersey',
#     ^
# IndentationError: unindent does not match any outer indentation level

# %% [raw]
# dfgroup = pd.concat([dfgroup, pd.DataFrame.from_dict({
#     "country": ["South Africa"],
#     "count" : [5]
# }).set_index('country')])

# %%
logdfgroup = np.log10(dfgroup)

# %%
logdfgroup

# %%
statetsshp.merge(logdfgroup, right_index=True, left_on="NAME")

# %%
countriesshp["centers"] = countriesshp.geometry.centroid
statetsshp["centers"] = statetsshp.geometry.centroid
allgeos = pd.concat([countriesshp[["NAME", "centers"]], statetsshp[["NAME", "centers"]]]).reset_index()

# %%
logdfgroup + 10

# %%
ax = countriesshp.plot(color="#fcfcfc", edgecolor="k", figsize=(20,20))
tmp_ = countriesshp.merge(logdfgroup+3, right_index=True, left_on="NAME", how='outer')
tmp_.fillna(0).plot(cmap="Blues",
                                                        column="count", ax=ax)
tmp_ = statetsshp.merge(logdfgroup+10, right_index=True, left_on="NAME", how='outer')
tmp_.fillna(0).plot(cmap="Oranges", 
                                                    column="count", ax=ax)
ax.axis('off')
pl.savefig("SCmap.png")

# %%
viridis = cm.get_cmap('viridis', 256)
newcolors = viridis(np.linspace(0.5, 1, 256))
newcolors

# %%
allgeos['centers'].values[0]

# %%
statetsshp.merge(dfgroup, right_index=True, left_on="NAME")[["NAME",'count']]

# %%
statetsshp.merge(dfgroup, right_index=True, left_on="NAME")[["NAME",'count']]

# %%
pd.options.display.max_rows = 999

# %%
countriesshp.merge(dfgroup, right_index=True, left_on="NAME")[["NAME", "count"]]

# %%
allcontacts = pd.read_csv("contactdbexport.csv")
allcontacts["Company"].unique()
# Out:
# array(['Lawrence Livermore National Laboratory',
#        'NASA Johnson Space Center', 'University of Washington', nan,
#        'Columbia University', 'IAC', 'University of California',
#        ' Berkeley/ LBNL',
#        'Kavli Institute for Particle Astrophysics and Cosmology (KIPAC)',
#        'SLAC National Accelerator Laboratory',
#        'University of Southampton', 'University of Oxford',
#        'Universidad de Antofagasta', ' Davis', 'Universidad Andres Bello',
#        'Univ. Paris-Sud & LAL - IN2P3/CNRS', 'IN2P3-LPNHE',
#        'INAF-Osservatorio Astronomico di Roma',
#        'Universidad Diego Portales', 'LCOGT & UC Santa Barbara',
#        'Jet Propulsion Laboratory', 'IPAC/Caltech',
#        'The University of Arizona', 'APC', 'University of Chicago',
#        'Rutgers',
#        'Laboratory for Atmosphere and Space Physics University of Colorado at Boulder',
#        'Pennsylvania State University',
#        'Lawrence Berkeley National Laboratory', 'Yale University',
#        'Georgia Institute of Technology',
#        'INAF-Osservatorio Astrofisico di Torino & SNS-Scuola Normale',
#        'University of Waterloo', 'Observatório Nacional/BGP-LSST/LIneA',
#        'Institute of Astronomy', ' University of Cambridge',
#        'Queens University Belfast', 'Universidad de La Serena',
#        'Universidad de Atacama', 'IN2P3-LPSC',
#        'Universidad Metropolitana de Ciencias de la Educacion  (UMCE)',
#        'Pontificia Universidad Cat', ' Irvine', 'Booz Allen Hamilton',
#        'Stanford University', 'Cornell University', 'AURA/LSST',
#        'Michigan State University', 'University of Michigan',
#        'University of Texas', ' Austin',
#        'Istituto Nazionale di Astrofisica (INAF)',
#        'University of Cambridge',
#        'Harvard Smithsonian Center for Astrophysics',
#        'University of Pennsylvania', 'Liverpool John Moores University',
#        'New York University', 'University of Birmingham',
#        'INAF-Osservatorio Astronomico di Trieste',
#        'Laboratoire de l Accelerateur Lineaire / IN2P3',
#        'Ohio State University', ' Berkeley', 'Rider University',
#        'University of Auburn',
#        'B612 Astroid Institute/University of Washington',
#        'INAF-Osservatorio Astronomico di Palermo',
#        'University of Rome Tor Vergata -- INAF Rome Astronomical Observatory',
#        'George Mason University', 'Las Cumbres Observatory',
#        'Princeton University', 'Arizona State University', 'MIT',
#        'INAF-Osservatorio Astronomico di Capodimonte', 'Laboratoire d'],
#       dtype=object)

# %%
df_.head()
# Out:
#    Unnamed: 0                           Company  \
# 0           0          University of Washington
# 1           1                               NaN
# 2           2          University of Washington
# 3           3                           Caltech
# 4           4  University of the Virgin Islands
#
#                            Email First Name      Last Name  \
# 0      agol@astro.washington.edu       Eric           Agol
# 1        javier.alonso@uantof.cl     Javier  Alonso-Garcia
# 2  anderson@astro.washington.edu      Scott       Anderson
# 3           andreoni@caltech.edu       Igor       Andreoni
# 4     antonino.cucchiara@uvi.edu  Cucchiara       Antonino
#
#                               SC               state      state1 state2  \
# 0  Transients and Variable Stars          Washington  Washington    NaN
# 1  Transients and Variable Stars                 NaN         NaN  Chile
# 2  Transients and Variable Stars          Washington  Washington    NaN
# 3  Transients and Variable Stars             Caltech         NaN    NaN
# 4  Transients and Variable Stars  the Virgin Islands         NaN    NaN
#
#        state3      state4     country
# 0  Washington  Washington  Washington
# 1       Chile         NaN       Chile
# 2  Washington  Washington  Washington
# 3         NaN  California  California
# 4         NaN    Virginia    Virginia

# %%
df_.head()
# Out:
#    Unnamed: 0                           Company  \
# 0           0          University of Washington
# 1           1                               NaN
# 2           2          University of Washington
# 3           3                           Caltech
# 4           4  University of the Virgin Islands
#
#                            Email First Name      Last Name  \
# 0      agol@astro.washington.edu       Eric           Agol
# 1        javier.alonso@uantof.cl     Javier  Alonso-Garcia
# 2  anderson@astro.washington.edu      Scott       Anderson
# 3           andreoni@caltech.edu       Igor       Andreoni
# 4     antonino.cucchiara@uvi.edu  Cucchiara       Antonino
#
#                               SC               state      state1 state2  \
# 0  Transients and Variable Stars          Washington  Washington    NaN
# 1  Transients and Variable Stars                 NaN         NaN  Chile
# 2  Transients and Variable Stars          Washington  Washington    NaN
# 3  Transients and Variable Stars             Caltech         NaN    NaN
# 4  Transients and Variable Stars  the Virgin Islands         NaN    NaN
#
#        state3      state4     country
# 0  Washington  Washington  Washington
# 1       Chile         NaN       Chile
# 2  Washington  Washington  Washington
# 3         NaN  California  California
# 4         NaN    Virginia    Virginia

# %%
from shapely.geometry import LineString # To create line geometries that can be used in a GeoDataFrame
def makeline(g0, g1):
    #print(g0,g1)
    start, end = [(g0.x, g0.y), (g1.x, g1.y)]
    line = LineString([start, end]), start, end
    #data = {'geometry': [line]}
    #return gpd.GeoDataFrame(pd.DataFrame(data, 
           #                                 columns = ['geometry'])) 
    return line

# %%
ax = countriesshp.plot(color="#fcfcfc", edgecolor="k", figsize=(20,20))
countriesshp.merge(dfgroup, right_index=True, left_on="NAME").plot(cmap="Blues",
                                                        column="count", ax=ax)
statetsshp.merge(dfgroup, right_index=True, left_on="NAME").plot(cmap="Oranges", 
                                                    column="count", ax=ax)
#ax.axis('off')
g0, g1 = countriesshp[countriesshp["NAME"] == "Brazil"]["geometry"].centroid.values[0],\
countriesshp[countriesshp["NAME"] == "Italy"]["geometry"].centroid.values[0]
#makeline(g0, g1).plot(ax=ax)
#pl.plot(countriesshp['centers'][0], countriesshp['centers'][1])
#countriesshp.head(), countriesshp['centers'][0], countriesshp['centers'][1]

# %%
def getlinks(pairs):
    #print(allgeos["centers"][allgeos["NAME"] == pairs[0]].values[0], 
    #      allgeos["centers"][allgeos["NAME"] == pairs[1]].values[0])
    #print((allgeos["NAME"] == pairs[0]).sum())
    #print((allgeos["NAME"] == pairs[1]).sum())
    return allgeos["centers"][allgeos["NAME"] == pairs[0]].values[0], \
allgeos["centers"][allgeos["NAME"] == pairs[1]].values[0]


def pairup(mylist):
    pairs = []
    for i,l1 in enumerate(mylist):
        for l2 in mylist[i+1:]:
            if (l1 in allgeos["NAME"].values and l2 in allgeos["NAME"].values):
                #print(l1, l2)
                pairs.append((l1, l2))
    pairs, k = np.unique(np.array(pairs), axis=0, return_counts=1)
    #print(pairs)#print([(p[0], p[1]) for p in pairs])
    return [getlinks((p[0], p[1])) for p in pairs], k

# %%
getlinks(("Alabama", "California"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-80-b635c78d4110> in <module>
# ----> 1 getlinks(("Alabama", "California"))
#
# <ipython-input-79-73050af4d46e> in getlinks(pairs)
#       4     #print((allgeos["NAME"] == pairs[0]).sum())
#       5     #print((allgeos["NAME"] == pairs[1]).sum())
# ----> 6     return allgeos["centers"][allgeos["NAME"] == pairs[0]].values[0], \
#       7 allgeos["centers"][allgeos["NAME"] == pairs[1]].values[0]
#       8
#
# NameError: name 'allgeos' is not defined

# %%
df_["SC"].unique()

# %%
pairs = {}
for sc in df_["SC"].unique():
    pairs[sc] = []
    pairs[sc] = pairup(df_[df_.SC == sc]["country"].values)

# %%
pairs.keys()

# %%
ax = pl.figure(figsize=(20,20)).add_subplot(111)
countriesshp.plot(color="#fcfcfc", edgecolor="k", ax=ax)
countriesshp.merge(dfgroup, right_index=True, left_on="NAME").plot(cmap="Blues",
                                                        column="count", ax=ax)
statetsshp.merge(dfgroup, right_index=True, left_on="NAME").plot(cmap="Oranges", 
                                                    column="count", ax=ax)
colors = ['k', 'c', 'm', 'y', 'g', 'b', 'r']
for i,k in enumerate(pairs.keys()):
    print(k)
    for j,p in enumerate(pairs[k][0]):
        #print(p)
        try:
            makeline(p[0], p[1]).plot(ax=ax, alpha=0.01 * pairs[k][1][j], 
                                      color=colors[i])
        except:
            pass
pl.savefig("mapWnetwork.png")

# %%
def plot_line(ax, ob, alpha, color):
    x, y = ob.xy
    #print(color, alpha)
    ax.annotate("",
                xy=(x[0],y[0]), xycoords='data',
                xytext=(x[1],y[1]), textcoords='data',
                arrowprops=dict(arrowstyle="-",
                            connectionstyle="arc3,rad=0.3",
                               ec=color, alpha=alpha),
                #color=color, alpha=alpha
                )
    
    #ax.plot(x, y, color=color, alpha=0.7, linewidth=1, solid_capstyle='round', zorder=2)

# %%
from mpl_toolkits.axes_grid1.anchored_artists import AnchoredDrawingArea

fig, ax = pl.subplots(nrows=1, ncols=1,figsize=(20,10))
countriesshp.plot(color="#fcfcfc", edgecolor="k", ax=ax)
countriesshp.merge(dfgroup, right_index=True, left_on="NAME").plot(cmap="gray_r",
                                                        column="count", ax=ax)
statetsshp.merge(dfgroup, right_index=True, left_on="NAME").plot(cmap="gray", 
                                                    column="count", ax=ax)
colors = {"Transients and Variable Stars":"#44aa99", 'Solar System':"#332288", 
          'Strong Lensing':"#117733", 'DESC':"#cc6677", 
          'Galaxies':"#999933", 'AGN':"#882255", 
          'Stars, Milky Way, and Local Volume':"#88ccee", 
          'Statistics and Informatics':"#aa4499"}
pairslist = np.array(list(list(pairs.keys())))
pairsort = np.argsort([len(pairs[k][1]) 
                       for k in list(pairs.keys())])[::-1]
                    
l = 7
for i,k in enumerate(pairslist[pairsort]):
    print(k, len(pairs[k][1]))
    for j,p in enumerate(pairs[k][0]):
        #print(p, makeline(p[0], p[1])[0], 0.01 * pairs[k][1][j])
        if 1: #
        #try:
            #print(0.01 * pairs[k][1][j])
            #makeline(p[0], p[1]).plot(ax=ax, alpha=0.01 * pairs[k][1][j], 
            #                          color=colors[i])
            #print(makeline(p[0], p[1]))
            #pl.plot(makeline(p[0], p[1])[2], makeline(p[0], p[1])[1], alpha=0.01 * pairs[k][1][j], 
            #                          color=colors[i])
            alpha = 0.03 * pairs[k][1][j]
            #print(alpha)
            if k == "Stars, Milky Way, and Local Volume":
                alpha = alpha * 0.3
            alpha=max(0.02, min(1, alpha))
            plot_line(ax, makeline(p[0], p[1])[0], alpha=alpha, 
                                      color=colors[k])
            #print(makeline(p[0],p[1])[0])
            #makeline(p[0], p[1])[0]#.plot(ax=ax)
        #except:
        #    pass
    pl.plot(-180, -10*i, 'o', ms=10, color=colors[k])
    pl.text(-175, -10*i, k.replace("Stars, Milky Way, and Local Volume", 
                                  "SMWLV"), ha="left", va="center", fontsize=20)
    #break
ax.axis('off');
pl.savefig("SCmapWNet.png")

# %%
#statetsshp.merge(dfgroup, right_index=True, left_on="NAME").head()
dfgroup2 = dfgroup.copy()
dfgroup2["state6"] = dfgroup2.index
dfgroup2 = dfgroup2.reset_index().set_index(["country"])["state6"].repeat(dfgroup['count']).reset_index()#

# %%
dfgroup2

# %%
statetsshp.head()

# %%
def tr(x):
    return x.coords.xy[0][0]#, x.centers.coords.xy[1][0]
def tr1(x):
    return x.coords.xy[1][0]#, x.centers.coords.xy[1][0]
statetsshp["coords0"] = statetsshp["centers"].transform(tr)
statetsshp["coords1"] = statetsshp["centers"].transform(tr1)

# %%
dfnow = statetsshp.merge(dfgroup2, right_on="state5", left_on="NAME")[["coords0", "coords1"]]#.plot(cmap="gray", 
                                                    #column="count", ax=ax)

# %%
import datashader as ds
import datashader.transfer_functions as tf
import dask.dataframe as dd
import numpy as np

# %%
from functools import partial
from datashader.utils import export_image
from datashader.colors import colormap_select, Greys9
from IPython.core.display import HTML, display

export = partial(export_image, background = background, export_path="export")
cm = partial(colormap_select, reverse=(background!="black"))

display(HTML("<style>.container { width:100% !important; }</style>"))

# %% [markdown]
# world, USA

# %%
world           = ((-180, 180), (-180,  180) )
USA           = ((-124.72,  -66.95), (23.55, 50.06))
background = "gray"
from datashader.utils import lnglat_to_meters as webm
x_range,y_range = [list(r) for r in USA]

plot_width  = int(900)
plot_height = int(plot_width*7.0/12)

# %%
cvs = ds.Canvas(plot_width, plot_height, *USA)#*webm(*world))
agg = cvs.points(dfnow, 'coords0', 'coords1')
#dfnow[['coords0', 'coords1']]

# %%
agg.data.flatten()[agg.data.flatten()>0]

# %%
pl.hist(np.log(agg).data.flatten())

# %%
color_key = {'w':'blue', 'b':'green', 'a':'red', 'h':'orange',  'o':'saddlebrown'}
from matplotlib.cm import hot
x_range,y_range=webm(np.array([-180,0]), np.array([-180,180]))
cvs = ds.Canvas(plot_width=plot_width, plot_height=plot_height, x_range=x_range, y_range=y_range)
agg = cvs.points(dfnow, 'coords0', 'coords1')
agg.data = agg.data+1
export(tf.shade(agg, color_key=color_key, how='eq_hist'), "tmp")

# %%
tf.shade(np.log(agg), cmap=plt.get_cmap('viridis'), how='linear')

# %%
agg.data.sum()

# %%
dfnow["coords0"]

# %%
cvs.points(dfnow, "coords0","coords1", agg=None)
