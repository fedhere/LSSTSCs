# %%
import pandas as pd
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df_ = pd.read_csv("contactdbexport.csv")#"SC-List.csv")
df_.Email.map(lambda x: x.strip().split(".")[-1]).unique()
# Out:
# array(['gov', 'edu', 'br', 'org', 'uk', 'cl', 'com', 'fr', 'it', 'net',
#        'ca', 'au', 'es', 'cn', 'de', 'pl', 'nz', 'cz', 'mil', 'si', 'fi',
#        'rs', 'global', 'hu', 'dk'], dtype=object)

# %%
for em in df_.drop_duplicates(subset="Email").Email.values:
    if em.strip().split(".")[-1] in ["com", "net", "mil", "org"]:
        print(df_[df_.Email==em].values[0])
# Out:
# ['Mohammad' 'Akhlaghi' 'mohammad@akhlaghi.org' nan 'IAC' 'Galaxies'
#  'Member' nan nan nan nan nan nan]
# ['Timo' 'Anguita' 'tanguita@gmail.com' '+56227703337'
#  'University of Washington' 'AGN' 'Member' nan nan nan nan nan nan]
# ['Iair' 'Arcavi' 'arcavi@gmail.com' nan
#  'INAF-Osservatorio Astronomico di Roma' 'Galaxies' 'Member' nan nan nan
#  nan nan nan]
# ['Eric' 'Aubourg' 'eric@aubourg.net' '+33-1-57-27-69-27'
#  'Universidad Diego Portales' 'AGN' 'Member' nan nan nan nan nan nan]
# ['Keith' 'Bechtol' 'kbechtol@lsst.org' '(520) 318-8512'
#  'Booz Allen Hamilton' 'Transients' 'Member' nan nan nan nan nan nan]
# ['Rahul' 'Biswas' 'rbiswas4@gmail.com' nan
#  'Liverpool John Moores University' 'Transients' 'Member' nan nan nan nan
#  nan nan]
# ['Michael Rogers' 'Blanton' 'michael.blanton@gmail.com' '212-998-7770'
#  'University of Birmingham' 'Statistics and Informatics' 'Member' nan nan
#  nan nan nan nan]
# ['Bob' 'Blum' 'rblum@lsst.org' '520-318-8233'
#  'Laboratoire de l Accelerateur Lineaire / IN2P3' 'DESC' 'Member' nan nan
#  nan nan nan nan]
# ['John' 'Bochanski' 'bochanski@gmail.com' nan
#  'Kavli Institute for Particle Astrophysics and Cosmology (KIPAC)'
#  'Galaxies' 'Member' nan nan nan nan nan nan]
# ['Bryce' 'Bolin' 'bolin.astro@gmail.com' nan 'University of California'
#  'Galaxies' 'Member' nan nan nan nan nan nan]
# ['Kirk' 'Borne' 'kirk.borne@gmail.com' '(703) 993-8402'
#  'Pennsylvania State University' 'Stars' 'Member' nan nan nan nan nan nan]
# ['Todd' 'Boroson' 'tboroson@lcogt.net' '(805) 880-1618'
#  'INAF-Osservatorio Astronomico di Palermo' 'Solar System' 'Affiliate' nan
#  nan nan nan nan nan]
# ['Sarah' 'Bridle' 'sarah@sarahbridle.net' nan nan 'Transients' 'Member'
#  nan nan nan nan nan nan]
# ['Tim' 'Brown' 'tbrown@lcogt.net' '805-880-1618' nan 'AGN' 'Member' nan
#  nan nan nan nan nan]
# ['Philip' 'Bull' 'philbull@gmail.com' nan nan 'Transients' 'Member' nan
#  nan nan nan nan nan]
# ['Ben' 'Burningham' 'burninghamster@gmail.com' nan nan
#  'Statistics and Informatics' 'Member' nan nan nan nan nan nan]
# ['Jeff' 'Carlin' 'JCarlin@lsst.org' '520-318-8533' nan 'Stars' 'Member'
#  nan nan nan nan nan nan]
# ['Paolo' 'Cassata' 'paolo.cassata@gmail.com' nan nan 'Stars' 'Member' nan
#  nan nan nan nan nan]
# ['Stefano' 'Cavuoti' 'stefano.cavuoti@gmail.com' nan nan
#  'Statistics and Informatics' 'Member' nan nan nan nan nan nan]
# ['Claudia' 'Cicone' 'claudiacicone@gmail.com' nan nan 'Transients'
#  'Member' nan nan nan nan nan nan]
# ['Chuck' 'Claver' 'cclaver@lsst.org' '520-318-8319' nan 'AGN' 'Member' nan
#  nan nan nan nan nan]
# ['Chris' 'Conselice' 'conselice@gmail.com' nan nan 'Stars' 'Member' nan
#  nan nan nan nan nan]
# ['Deanne ' 'Coppejans' 'deanne.coppejans@gmail.com' nan nan 'Transients'
#  'Member' nan nan nan nan nan nan]
# ['Michael' 'Coughlin' 'michael.w.coughlin@gmail.com' nan nan
#  'Statistics and Informatics' 'Member' nan nan nan nan nan nan]
# ['Matija' 'Cuk' 'mcuk@seti.org' nan nan 'Transients' 'Member' nan nan nan
#  nan nan nan]
# ['Scott' 'Daniel' 'scottvalscott@gmail.com' nan nan 'Stars' 'Member' nan
#  nan nan nan nan nan]
# ['William' 'Dawson' 'will@dawsonresearch.com' '(925) 424-3732' nan
#  'Transients' 'Member' nan nan nan nan nan nan]
# ['Demetra ' 'De Cicco' 'demetradecicco@gmail.com' nan nan
#  'Statistics and Informatics' 'Member' nan nan nan nan nan nan]
# ['Victor' 'Debattista' 'vpdebattista@gmail.com' nan nan 'Transients'
#  'Member' nan nan nan nan nan nan]
# ['Jason' 'Dexter' 'jadexter@gmail.com' nan nan 'Transients' 'Affiliate'
#  nan nan nan nan nan nan]
# ['Saurav' 'Dhital' 'dhitals@me.com' nan nan 'Transients' 'Member' nan nan
#  nan nan nan nan]
# ['Aaron' 'Dotter' 'aaron.dotter@gmail.com' '410-338-4310' nan 'Galaxies'
#  'Member' nan nan nan nan nan nan]
# ['Siegfried' 'Eggl' 'siegfried.eggl@gmail.com' nan nan 'Stars' 'Member'
#  nan nan nan nan nan nan]
# ['Tim' 'Eifler' 'timeifler@gmail.com' nan nan
#  ' Milky Way and Local Volume ' 'Member' nan nan nan nan nan nan]
# ['Ross' 'Fadely' 'rossfadely@gmail.com' nan nan 'Galaxies' 'Member' nan
#  nan nan nan nan nan]
# ['Charlie' 'Finch' 'finch@usno.navy.mil' nan nan
#  'Statistics and Informatics' 'Member' nan nan nan nan nan nan]
# ['Merlin' 'Fisher-Levine' 'merlin.fisherlevine@gmail.com' nan nan
#  'Solar System' 'Member' nan nan nan nan nan nan]
# ['Brenda' 'Frye' 'brendafrye@gmail.com' '(520) 626-1857' nan
#  'Solar System' 'Member' nan nan nan nan nan nan]
# ['Lluis' 'Galbany' 'lluisgalbany@gmail.com' nan nan 'Solar System'
#  'Member' nan nan nan nan nan nan]
# ['Christopher' 'Genovese' 'genovese.cr@gmail.com' nan nan 'Solar System'
#  'Member' nan nan nan nan nan nan]
# ['Melissa' 'Graham' 'melissalynngraham@gmail.com' nan nan 'Transients'
#  'Member' nan nan nan nan nan nan]
# ['Sarah' 'Greenstreet' 'sarah@b612foundation.org' nan nan 'Transients'
#  'Member' nan nan nan nan nan nan]
# ['Puragra' 'Guhathakurta' 'raja@ucolick.org' '831-459-5169' nan 'DESC '
#  'Member' nan nan nan nan nan nan]
# ['James' 'Guillochon' 'guillochon@gmail.com' nan nan 'Transients' 'Member'
#  nan nan nan nan nan nan]
# ['Mark' 'Hammergren' 'mhammergren@adlerplanetarium.org' nan nan
#  ' Milky Way and Local Volume ' 'Member' nan nan nan nan nan nan]
# ['Al' 'Harris' 'harris@att.net' '818-790-8291' nan
#  'Statistics and Informatics' 'Member' nan nan nan nan nan nan]
# ['William' 'Hartley' 'willliam.hartley@gmail.com' nan nan 'Transients'
#  'Member' nan nan nan nan nan nan]
# ['Nimish' 'Hathi' 'nphathi@gmail.com' nan nan 'Transients' 'Member' nan
#  nan nan nan nan nan]
# ['Arne' 'Henden' 'arne@aavso.org' '617-354-0484' nan 'Stars' 'Member' nan
#  nan nan nan nan nan]
# ['Benne' 'Holwerda' 'benne.holwerda@gmail.com' nan nan 'Stars' 'Member'
#  nan nan nan nan nan nan]
# ['Johanna' 'Itam-Pasquet' 'johanna.itam@gmail.com' nan nan 'Solar System'
#  'Member' nan nan nan nan nan nan]
# ['Savannah' 'Jacklin' 'savannah.jacklin@gmail.com' nan nan 'Transients'
#  'Member' nan nan nan nan nan nan]
# ['Mike' 'Jarvis' 'michael@jarvis.net' '484-574-4058' nan 'Solar System'
#  'Member' nan nan nan nan nan nan]
# ['James' 'Jee' 'jee.james@gmail.com' '530-754-7428' nan 'Solar System'
#  'Member' nan nan nan nan nan nan]
# ['Garrett' 'Jernigan' 'jgj@h-bar.com' '707-782-9380' nan 'Galaxies'
#  'Affiliate' nan nan nan nan nan nan]
# ['Lynne' 'Jones' 'ljones.uw@gmail.com' '206-543-9487' nan 'Solar System'
#  'Member' nan nan nan nan nan nan]
# ['Steven' 'Kahn' 'skahn@lsst.org' '520-318-8483' nan 'Solar System'
#  'Member' nan nan nan nan nan nan]
# ['Bryce' 'Kalmbach' 'jbkalmbach@gmail.com' nan nan 'Transients' 'Member'
#  nan nan nan nan nan nan]
# ['Vishal' 'Kasliwal' 'vishal.kasliwal@gmail.com' '2158988141' nan
#  'Strong Lensing' 'Member' nan nan nan nan nan nan]
# ['Lee' 'Kelvin' 'lee.s.kelvin@gmail.com' nan nan
#  ' Milky Way and Local Volume ' 'Member' nan nan nan nan nan nan]
# ['Somayeh' 'Khakpash' 'somayeh.khakpash@gmail.com' nan nan 'AGN' 'Member'
#  nan nan nan nan nan nan]
# ['Karl' 'Krughoff' 'krughoff@lsst.org' nan nan 'Solar System' 'Member' nan
#  nan nan nan nan nan]
# ['Peter' 'Kurczynski' 'pkurczynski@mac.com' nan nan 'Galaxies' 'Member'
#  nan nan nan nan nan nan]
# ['Dustin' 'Lang' 'dstndstn@gmail.com' nan nan
#  ' Milky Way and Local Volume' 'Affiliate' nan nan nan nan nan nan]
# ['James' 'Lauroesch' 'jtlauroesch@gmail.com' nan nan 'Transients' 'Member'
#  nan nan nan nan nan nan]
# ['Michelle' 'Lochner' 'dr.michelle.lochner@gmail.com' nan nan 'Transients'
#  'Member' nan nan nan nan nan nan]
# ['Sarah' 'Loebman' 'sloebman@yahoo.com' nan nan 'DESC' 'Member' nan nan
#  nan nan nan nan]
# ['Mike' 'Loucks' 'loucks@see.com' nan nan 'Transients' 'Member' nan nan
#  nan nan nan nan]
# ['Michael' 'Lund' 'mike.lund@gmail.com' nan nan 'DESC' 'Member' nan nan
#  nan nan nan nan]
# ['Elmer' 'Luque' 'fidelluque@gmail.com' nan nan 'Stars' 'Member' nan nan
#  nan nan nan nan]
# ['Yao-Yuan' 'Mao' 'yymao.astro@gmail.com' nan nan 'DESC' 'Member' nan nan
#  nan nan nan nan]
# ['Vera' 'Margoniner' 'vera.margoniner@gmail.com' nan nan 'Transients'
#  'Member' nan nan nan nan nan nan]
# ['Raffaella' 'Margutti' 'rafmargutti@gmail.com' nan nan 'Stars' 'Member'
#  nan nan nan nan nan nan]
# ['Phil' 'Marshall' 'dr.phil.marshall@gmail.com' '650-926-4682' nan 'Stars'
#  'Affiliate' nan nan nan nan nan nan]
# ['Thomas' 'McClintock' 'tmcclintock89@gmail.com' nan nan 'DESC' 'Member'
#  nan nan nan nan nan nan]
# ['Peregrine' 'McGehee' 'peregrine.mcgehee@gmail.com' nan nan
#  ' Milky Way and Local Volume ' 'Member' nan nan nan nan nan nan]
# ['Gerhardt' 'Meurer' 'gerhardt.meurer@icrar.org' nan nan 'AGN' 'Member'
#  nan nan nan nan nan nan]
# ['Joshua' 'Meyers' 'jmeyers314@gmail.com' nan nan 'Solar System' 'Member'
#  nan nan nan nan nan nan]
# ['Andres' 'Meza' 'andresmezac@gmail.com' nan nan 'Stars' 'Member' nan nan
#  nan nan nan nan]
# ['Maryam' 'Modjaz' 'mmodjaz@gmail.com' nan nan 'Strong Lensing' 'Member'
#  nan nan nan nan nan nan]
# ['Lorenzo' 'Monaco' 'lmonaco1976@gmail.com' nan nan 'Solar System'
#  'Member' nan nan nan nan nan nan]
# ['David' 'Monet' 'dgmonet@gmail.com' '928-779-5132' nan 'Galaxies'
#  'Member' nan nan nan nan nan nan]
# ['Mirela' 'Obric' 'mirela.obric@gmail.com' nan nan
#  ' Milky Way and Local Volume' 'Member' nan nan nan nan nan nan]
# ['Elle' 'Ojala' 'elle.ojala@gmail.com ' nan nan 'Galaxies' 'Member' nan
#  nan nan nan nan nan]
# ['Alex' 'Parker' 'alexharrisonparker@gmail.com' nan nan 'DESC' 'Member'
#  nan nan nan nan nan nan]
# ['Matthew' 'Payne' 'matthewjohnpayne@gmail.com' nan nan 'AGN' 'Member' nan
#  nan nan nan nan nan]
# ['Jean-Marc' 'Petit' 'jean-marc.petit@normalesup.org' nan nan
#  ' Milky Way and Local Volume' 'Member' nan nan nan nan nan nan]
# ['Cathy' 'Petry' 'cpetry@lsst.org' '520-318-8472' nan 'Solar System'
#  'Affiliate' nan nan nan nan nan nan]
# ['Giuliano' 'Pignata' 'pignago@gmail.com' nan nan 'Transients' 'Member'
#  nan nan nan nan nan nan]
# ['Silvia ' 'Piranomonte' 'silvia.piranomonte@gmail.com' nan nan 'Galaxies'
#  'Member' nan nan nan nan nan nan]
# ['Andres' 'Plazas' 'plazasmalagon@gmail.com' nan nan
#  ' Milky Way and Local Volume ' 'Member' nan nan nan nan nan nan]
# ['Thomas' 'Puzia' 'tpuzia@gmail.com' nan nan 'Transients' 'Member' nan nan
#  nan nan nan nan]
# ['Joseph' 'Richards' 'joeyrichar@gmail.com' nan nan
#  ' Milky Way and Local Volume' 'Member' nan nan nan nan nan nan]
# ['Adric' 'Riedel' 'adric.riedel@gmail.com' nan nan 'DESC' 'Member' nan nan
#  nan nan nan nan]
# ['Constance' 'Rockosi' 'crockosi@ucolick.org' '831-459-5246' nan
#  'Strong Lensing' 'Member' nan nan nan nan nan nan]
# ['Joseph ' 'Rodriguez' 'rodriguez.jr.joey@gmail.com' nan nan
#  'Strong Lensing' 'Member' nan nan nan nan nan nan]
# ['Wayne' 'Rosing' 'wrosing@lcogt.net' '(805) 880-1601' nan 'DESC' 'Member'
#  nan nan nan nan nan nan]
# ['Gustavo Benedetti ' 'Rossi ' 'gugabrossi@gmail.com' nan nan 'DESC '
#  'Member' nan nan nan nan nan nan]
# ['Meg' 'Schwamb' 'mschwamb.astro@gmail.com' nan nan 'DESC' 'Member' nan
#  nan nan nan nan nan]
# ['Ryan' 'Scranton' 'ryan.scranton@gmail.com' nan nan 'DESC' 'Affiliate'
#  nan nan nan nan nan nan]
# ['Erin' 'Sheldon' 'erin.sheldon@gmail.com' nan nan
#  ' Milky Way and Local Volume ' 'Member' nan nan nan nan nan nan]
# ['Jonathan' 'Sick' 'jsick@lsst.org' '+1 (520) 318-8359' nan
#  ' Milky Way and Local Volume' 'Affiliate' nan nan nan nan nan nan]
# ['Anna' 'Spitz' 'aspitz@lsst.org' '(520)235-4000' nan 'Solar System'
#  'Member' nan nan nan nan nan nan]
# ['Adam' 'Stanford' 'sastanford@mac.com' nan nan 'Transients' 'Member' nan
#  nan nan nan nan nan]
# ['Katrien' 'Steenbrugge' 'katrien.steenbrugge@gmail.com' nan nan
#  'Galaxies' 'Member' nan nan nan nan nan nan]
# ['Scott' 'Stuart' 'jsstuart@gmail.com' '781-981-5259' nan 'AGN' 'Member'
#  nan nan nan nan nan nan]
# ['John' 'Subasavage' 'subasavage@nofs.navy.mil' nan nan 'DESC' 'Member'
#  nan nan nan nan nan nan]
# ['Hyungsuk' 'Tak' 'hyungusk.tak@gmail.com' nan nan
#  ' Milky Way and Local Volume ' 'Member' nan nan nan nan nan nan]
# ['Nicolas' 'Tejos' 'ntejos@ucolick.org' nan nan 'DESC ' 'Member' nan nan
#  nan nan nan nan]
# ['Patricia' 'Tissera' 'tissera.patriciab@gmail.com' nan nan 'DESC'
#  'Member' nan nan nan nan nan nan]
# ['Stefano' 'Valenti' 'stfn.valenti@gmail.com' nan nan 'AGN' 'Member' nan
#  nan nan nan nan nan]
# ['Lucianne' 'Walkowicz' 'l.m.walkowicz@gmail.com' '(312) 542-2412' nan
#  'Galaxies' 'Affiliate' nan nan nan nan nan nan]
# ['John' 'Wallin' 'jfwallin@gmail.com' nan nan 'AGN' 'Member' nan nan nan
#  nan nan nan]
# ['Mark' 'Wells' 'mwellsa@gmail.com' nan nan 'Transients' 'Member' nan nan
#  nan nan nan nan]
# ['Torre' 'Wenaus' 'wenaus@gmail.com' nan nan 'Galaxies' 'Member' nan nan
#  nan nan nan nan]
# ['Matthew' 'Wiesner' 'matthewwiesner@aol.com' '617-358-5879' nan
#  'Transients' 'Member' nan nan nan nan nan nan]
# ['Gerard' 'Williger' 'gmwilliger@gmail.com' '410-338-4963' nan
#  'Transients' 'Member' nan nan nan nan nan nan]
# ['Beth' 'Willman' 'bwillman@lsst.org' '502-852-0821' nan 'Stars' 'Member'
#  nan nan nan nan nan nan]
# ['Padma' 'Yanamandra-Fisher' 'padmayf@gmail.com' '505-667-1381' nan
#  'Stars' 'Member' nan nan nan nan nan nan]
# ['Adi' 'Zolotov' 'adizolotov@gmail.com' nan nan 'Galaxies' 'Member' nan
#  nan nan nan nan nan]
# ['Joe' 'Zuntz' 'joezuntz@googlemail.com' nan nan 'Stars' 'Member' nan nan
#  nan nan nan nan]

# %%
countries = {'mohammad@akhlaghi.org':"ES",
            'tanguita@gmail.com':"CL",
            'arcavi@gmail.com':"IS",'eric@aubourg.net':"FR", 'kbechtol@lsst.org':"US",
            'rbiswas4@gmail.com':"SW", 'michael.blanton@gmail.com':"US",
           'rblum@lsst.org':"US",
             'bochanski@gmail.com':"US",
'bolin.astro@gmail.com':"oth",
'kirk.borne@gmail.com':"oth",
'tboroson@lcogt.net':"US",
'sarah@sarahbridle.net':"US",
'tbrown@lcogt.net':"US",
'philbull@gmail.com':"oth",
'burninghamster@gmail.com':"oth",
'JCarlin@lsst.org':"US",
'paolo.cassata@gmail.com':"oth",
'stefano.cavuoti@gmail.com':"oth",
'claudiacicone@gmail.com':"oth",
'cclaver@lsst.org':"US",
'conselice@gmail.com':"oth",
'deanne.coppejans@gmail.com':"US",
'michael.w.coughlin@gmail.com':"oth",
'mcuk@seti.org':"US",
'scottvalscott@gmail.com':"oth",
'will@dawsonresearch.com':"US",
'demetradecicco@gmail.com':"oth",
'vpdebattista@gmail.com':"oth",
'jadexter@gmail.com':"oth",
'dhitals@me.com':"oth",
'aaron.dotter@gmail.com':"US",
'siegfried.eggl@gmail.com':"oth",
'timeifler@gmail.com':"oth",
'rossfadely@gmail.com':"US",
'finch@usno.navy.mil':"US",
'merlin.fisherlevine@gmail.com':"oth",
'brendafrye@gmail.com':"US",
'lluisgalbany@gmail.com':"CL",
'genovese.cr@gmail.com':"oth",
'melissalynngraham@gmail.com':"US",
'sarah@b612foundation.org':"US",
'raja@ucolick.org':"US",
'guillochon@gmail.com':"US",
'mhammergren@adlerplanetarium.org':"US",
'harris@att.net':"US",
'willliam.hartley@gmail.com': "oth",
'nphathi@gmail.com':"oth",
'arne@aavso.org':"US",
'benne.holwerda@gmail.com':"oth",
'johanna.itam@gmail.com':"oth",
'savannah.jacklin@gmail.com':"US",
'michael@jarvis.net':"US",
'jee.james@gmail.com':"oth",
'jgj@h-bar.com':"US",
'ljones.uw@gmail.com':"US",
'skahn@lsst.org':"US",
'jbkalmbach@gmail.com':"oth",
'vishal.kasliwal@gmail.com':"US",
'lee.s.kelvin@gmail.com':"US",
'somayeh.khakpash@gmail.com':"US",
'krughoff@lsst.org':"US",
'pkurczynski@mac.com':"oth",
'dstndstn@gmail.com':"CA",
'jtlauroesch@gmail.com':"oth",
'dr.michelle.lochner@gmail.com':"SA",
'sloebman@yahoo.com':"oth",
'loucks@see.com':"oth",
'mike.lund@gmail.com':"US",
'fidelluque@gmail.com':"oth",
'yymao.astro@gmail.com':"oth",
'vera.margoniner@gmail.com':"oth",
'rafmargutti@gmail.com':"US",
'dr.phil.marshall@gmail.com':"US",
'tmcclintock89@gmail.com':"oth",
'peregrine.mcgehee@gmail.com':"US",
'gerhardt.meurer@icrar.org':"oth",
'jmeyers314@gmail.com':"oth",
'andresmezac@gmail.com':"oth",
'mmodjaz@gmail.com':"US",
'lmonaco1976@gmail.com':"oth",
'dgmonet@gmail.com':"US",
'mirela.obric@gmail.com':"oth",
'elle.ojala@gmail.com ':"US",
'alexharrisonparker@gmail.com':"US",
'matthewjohnpayne@gmail.com':"oth",
'jean-marc.petit@normalesup.org':"FR",
'cpetry@lsst.org':"US",
'pignago@gmail.com':"oth",
'silvia.piranomonte@gmail.com':"oth",
'plazasmalagon@gmail.com':"CL",
'tpuzia@gmail.com':"oth",
'joeyrichar@gmail.com':"oth",
'adric.riedel@gmail.com':"oth",
'crockosi@ucolick.org':"US",
'rodriguez.jr.joey@gmail.com':"oth",
'wrosing@lcogt.net':"US",
'gugabrossi@gmail.com':"oth",
'mschwamb.astro@gmail.com':"UK",
'ryan.scranton@gmail.com':"oth",
'erin.sheldon@gmail.com':"oth",
'jsick@lsst.org':"US",
'aspitz@lsst.org':"US",
'sastanford@mac.com':"oth",
'katrien.steenbrugge@gmail.com':"oth",
'jsstuart@gmail.com':"US",
'subasavage@nofs.navy.mil':"US",
'hyungusk.tak@gmail.com':"oth",
'ntejos@ucolick.org':"US",
'tissera.patriciab@gmail.com':"oth",
'stfn.valenti@gmail.com':"US",
'l.m.walkowicz@gmail.com':"US",
'jfwallin@gmail.com':"oth",
'mwellsa@gmail.com': "US",
'wenaus@gmail.com':"oth",
'matthewwiesner@aol.com':"oth",
'gmwilliger@gmail.com':"US",
'bwillman@lsst.org':"US",
'padmayf@gmail.com':"US",
'adizolotov@gmail.com':"US",
'joezuntz@googlemail.com':"oth"
            }

# %%
countrymap = {"gov":"US", 'edu':"US", 'br':"BR", 
              'uk':"UK", 'cl':"CL", 
              'fr':"FR", 'it':"IT", 
              'ca':"CA", 
              'au':"AU", 'es':"ES", 'cn':"CN", 'de':"DE", 
              'pl':"PL", 'nz':"NZ", 
              'cz':"CZ", 
              'si':"SI",
              'fi':"FI", 'rs':"RS", 
              'global':"US", 'hu':"HU", 'dk':"DK"}
for c in countries.values():
    countrymap[c.lower()] = c
countrymap
# Out:
# {'gov': 'US',
#  'edu': 'US',
#  'br': 'BR',
#  'uk': 'UK',
#  'cl': 'CL',
#  'fr': 'FR',
#  'it': 'IT',
#  'ca': 'CA',
#  'au': 'AU',
#  'es': 'ES',
#  'cn': 'CN',
#  'de': 'DE',
#  'pl': 'PL',
#  'nz': 'NZ',
#  'cz': 'CZ',
#  'si': 'SI',
#  'fi': 'FI',
#  'rs': 'RS',
#  'global': 'US',
#  'hu': 'HU',
#  'dk': 'DK',
#  'is': 'IS',
#  'us': 'US',
#  'sw': 'SW',
#  'oth': 'oth',
#  'sa': 'SA'}

# %%
df_["Contact Category"] = df_["Contact Category"].map(lambda x:x.strip())
df_.groupby("Contact Category").count()
# Out:
#                             First Name  Last Name  Email  Telephone  Company  \
# Contact Category
# AGN                                 54         54     54         17        6
# DESC                               178        178    178         74       24
# Galaxies                           111        111    111         52       16
# Milky Way and Local Volume         132        132    132         62       11
# Solar System                        96         96     96         48        9
# Stars                              133        133    133         54       11
# Statistics and Informatics          71         71     71         28        6
# Strong Lensing                      43         43     43         17        8
# Transients                         200        200    200         87       22
#
#                             Role  Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# Contact Category
# AGN                           54           0           0           0
# DESC                         178           0           0           0
# Galaxies                     111           0           0           0
# Milky Way and Local Volume   132           0           0           0
# Solar System                  96           0           0           0
# Stars                        133           0           0           0
# Statistics and Informatics    71           0           0           0
# Strong Lensing                43           0           0           0
# Transients                   200           0           0           0
#
#                             Unnamed: 10  Unnamed: 11  Unnamed: 12
# Contact Category
# AGN                                   0            0            0
# DESC                                  0            0            0
# Galaxies                              0            0            0
# Milky Way and Local Volume            0            0            0
# Solar System                          0            0            0
# Stars                                 0            0            0
# Statistics and Informatics            0            0            0
# Strong Lensing                        0            0            0
# Transients                            0            0            0

# %%
affiliations = []
N = len(df_.index.values)
for i,ind in enumerate(df_.index.values):
    print (i, ",", N)
    n1 = "".join(df_.loc[ind, ["First Name","Last Name"]]).strip()
    for j in df_.index.values[i+1:]:
        if n1 == "".join(df_.loc[j, ["First Name","Last Name"]]):
            if not df_.loc[ind, "Contact Category"] == df_.loc[j, "Contact Category"]:
                affiliations.append((n1, df_.loc[ind, "Contact Category"],
                  df_.loc[j, "Contact Category"]))
# Out:
# 0 , 1018
# 1 , 1018
# 2 , 1018
# 3 , 1018
# 4 , 1018
# 5 , 1018
# 6 , 1018
# 7 , 1018
# 8 , 1018
# 9 , 1018
# 10 , 1018
# 11 , 1018
# 12 , 1018
# 13 , 1018
# 14 , 1018
# 15 , 1018
# 16 , 1018
# 17 , 1018
# 18 , 1018
# 19 , 1018
# 20 , 1018
# 21 , 1018
# 22 , 1018
# 23 , 1018
# 24 , 1018
# 25 , 1018
# 26 , 1018
# 27 , 1018
# 28 , 1018
# 29 , 1018
# 30 , 1018
# 31 , 1018
# 32 , 1018
# 33 , 1018
# 34 , 1018
# 35 , 1018
# 36 , 1018
# 37 , 1018
# 38 , 1018
# 39 , 1018
# 40 , 1018
# 41 , 1018
# 42 , 1018
# 43 , 1018
# 44 , 1018
# 45 , 1018
# 46 , 1018
# 47 , 1018
# 48 , 1018
# 49 , 1018
# 50 , 1018
# 51 , 1018
# 52 , 1018
# 53 , 1018
# 54 , 1018
# 55 , 1018
# 56 , 1018
# 57 , 1018
# 58 , 1018
# 59 , 1018
# 60 , 1018
# 61 , 1018
# 62 , 1018
# 63 , 1018
# 64 , 1018
# 65 , 1018
# 66 , 1018
# 67 , 1018
# 68 , 1018
# 69 , 1018
# 70 , 1018
# 71 , 1018
# 72 , 1018
# 73 , 1018
# 74 , 1018
# 75 , 1018
# 76 , 1018
# 77 , 1018
# 78 , 1018
# 79 , 1018
# 80 , 1018
# 81 , 1018
# 82 , 1018
# 83 , 1018
# 84 , 1018
# 85 , 1018
# 86 , 1018
# 87 , 1018
# 88 , 1018
# 89 , 1018
# 90 , 1018
# 91 , 1018
# 92 , 1018
# 93 , 1018
# 94 , 1018
# 95 , 1018
# 96 , 1018
# 97 , 1018
# 98 , 1018
# 99 , 1018
# 100 , 1018
# 101 , 1018
# 102 , 1018
# 103 , 1018
# 104 , 1018
# 105 , 1018
# 106 , 1018
# 107 , 1018
# 108 , 1018
# 109 , 1018
# 110 , 1018
# 111 , 1018
# 112 , 1018
# 113 , 1018
# 114 , 1018
# 115 , 1018
# 116 , 1018
# 117 , 1018
# 118 , 1018
# 119 , 1018
# 120 , 1018
# 121 , 1018
# 122 , 1018
# 123 , 1018
# 124 , 1018
# 125 , 1018
# 126 , 1018
# 127 , 1018
# 128 , 1018
# 129 , 1018
# 130 , 1018
# 131 , 1018
# 132 , 1018
# 133 , 1018
# 134 , 1018
# 135 , 1018
# 136 , 1018
# 137 , 1018
# 138 , 1018
# 139 , 1018
# 140 , 1018
# 141 , 1018
# 142 , 1018
# 143 , 1018
# 144 , 1018
# 145 , 1018
# 146 , 1018
# 147 , 1018
# 148 , 1018
# 149 , 1018
# 150 , 1018
# 151 , 1018
# 152 , 1018
# 153 , 1018
# 154 , 1018
# 155 , 1018
# 156 , 1018
# 157 , 1018
# 158 , 1018
# 159 , 1018
# 160 , 1018
# 161 , 1018
# 162 , 1018
# 163 , 1018
# 164 , 1018
# 165 , 1018
# 166 , 1018
# 167 , 1018
# 168 , 1018
# 169 , 1018
# 170 , 1018
# 171 , 1018
# 172 , 1018
# 173 , 1018
# 174 , 1018
# 175 , 1018
# 176 , 1018
# 177 , 1018
# 178 , 1018
# 179 , 1018
# 180 , 1018
# 181 , 1018
# 182 , 1018
# 183 , 1018
# 184 , 1018
# 185 , 1018
# 186 , 1018
# 187 , 1018
# 188 , 1018
# 189 , 1018
# 190 , 1018
# 191 , 1018
# 192 , 1018
# 193 , 1018
# 194 , 1018
# 195 , 1018
# 196 , 1018
# 197 , 1018
# 198 , 1018
# 199 , 1018
# 200 , 1018
# 201 , 1018
# 202 , 1018
# 203 , 1018
# 204 , 1018
# 205 , 1018
# 206 , 1018
# 207 , 1018
# 208 , 1018
# 209 , 1018
# 210 , 1018
# 211 , 1018
# 212 , 1018
# 213 , 1018
# 214 , 1018
# 215 , 1018
# 216 , 1018
# 217 , 1018
# 218 , 1018
# 219 , 1018
# 220 , 1018
# 221 , 1018
# 222 , 1018
# 223 , 1018
# 224 , 1018
# 225 , 1018
# 226 , 1018
# 227 , 1018
# 228 , 1018
# 229 , 1018
# 230 , 1018
# 231 , 1018
# 232 , 1018
# 233 , 1018
# 234 , 1018
# 235 , 1018
# 236 , 1018
# 237 , 1018
# 238 , 1018
# 239 , 1018
# 240 , 1018
# 241 , 1018
# 242 , 1018
# 243 , 1018
# 244 , 1018
# 245 , 1018
# 246 , 1018
# 247 , 1018
# 248 , 1018
# 249 , 1018
# 250 , 1018
# 251 , 1018
# 252 , 1018
# 253 , 1018
# 254 , 1018
# 255 , 1018
# 256 , 1018
# 257 , 1018
# 258 , 1018
# 259 , 1018
# 260 , 1018
# 261 , 1018
# 262 , 1018
# 263 , 1018
# 264 , 1018
# 265 , 1018
# 266 , 1018
# 267 , 1018
# 268 , 1018
# 269 , 1018
# 270 , 1018
# 271 , 1018
# 272 , 1018
# 273 , 1018
# 274 , 1018
# 275 , 1018
# 276 , 1018
# 277 , 1018
# 278 , 1018
# 279 , 1018
# 280 , 1018
# 281 , 1018
# 282 , 1018
# 283 , 1018
# 284 , 1018
# 285 , 1018
# 286 , 1018
# 287 , 1018
# 288 , 1018
# 289 , 1018
# 290 , 1018
# 291 , 1018
# 292 , 1018
# 293 , 1018
# 294 , 1018
# 295 , 1018
# 296 , 1018
# 297 , 1018
# 298 , 1018
# 299 , 1018
# 300 , 1018
# 301 , 1018
# 302 , 1018
# 303 , 1018
# 304 , 1018
# 305 , 1018
# 306 , 1018
# 307 , 1018
# 308 , 1018
# 309 , 1018
# 310 , 1018
# 311 , 1018
# 312 , 1018
# 313 , 1018
# 314 , 1018
# 315 , 1018
# 316 , 1018
# 317 , 1018
# 318 , 1018
# 319 , 1018
# 320 , 1018
# 321 , 1018
# 322 , 1018
# 323 , 1018
# 324 , 1018
# 325 , 1018
# 326 , 1018
# 327 , 1018
# 328 , 1018
# 329 , 1018
# 330 , 1018
# 331 , 1018
# 332 , 1018
# 333 , 1018
# 334 , 1018
# 335 , 1018
# 336 , 1018
# 337 , 1018
# 338 , 1018
# 339 , 1018
# 340 , 1018
# 341 , 1018
# 342 , 1018
# 343 , 1018
# 344 , 1018
# 345 , 1018
# 346 , 1018
# 347 , 1018
# 348 , 1018
# 349 , 1018
# 350 , 1018
# 351 , 1018
# 352 , 1018
# 353 , 1018
# 354 , 1018
# 355 , 1018
# 356 , 1018
# 357 , 1018
# 358 , 1018
# 359 , 1018
# 360 , 1018
# 361 , 1018
# 362 , 1018
# 363 , 1018
# 364 , 1018
# 365 , 1018
# 366 , 1018
# 367 , 1018
# 368 , 1018
# 369 , 1018
# 370 , 1018
# 371 , 1018
# 372 , 1018
# 373 , 1018
# 374 , 1018
# 375 , 1018
# 376 , 1018
# 377 , 1018
# 378 , 1018
# 379 , 1018
# 380 , 1018
# 381 , 1018
# 382 , 1018
# 383 , 1018
# 384 , 1018
# 385 , 1018
# 386 , 1018
# 387 , 1018
# 388 , 1018
# 389 , 1018
# 390 , 1018
# 391 , 1018
# 392 , 1018
# 393 , 1018
# 394 , 1018
# 395 , 1018
# 396 , 1018
# 397 , 1018
# 398 , 1018
# 399 , 1018
# 400 , 1018
# 401 , 1018
# 402 , 1018
# 403 , 1018
# 404 , 1018
# 405 , 1018
# 406 , 1018
# 407 , 1018
# 408 , 1018
# 409 , 1018
# 410 , 1018
# 411 , 1018
# 412 , 1018
# 413 , 1018
# 414 , 1018
# 415 , 1018
# 416 , 1018
# 417 , 1018
# 418 , 1018
# 419 , 1018
# 420 , 1018
# 421 , 1018
# 422 , 1018
# 423 , 1018
# 424 , 1018
# 425 , 1018
# 426 , 1018
# 427 , 1018
# 428 , 1018
# 429 , 1018
# 430 , 1018
# 431 , 1018
# 432 , 1018
# 433 , 1018
# 434 , 1018
# 435 , 1018
# 436 , 1018
# 437 , 1018
# 438 , 1018
# 439 , 1018
# 440 , 1018
# 441 , 1018
# 442 , 1018
# 443 , 1018
# 444 , 1018
# 445 , 1018
# 446 , 1018
# 447 , 1018
# 448 , 1018
# 449 , 1018
# 450 , 1018
# 451 , 1018
# 452 , 1018
# 453 , 1018
# 454 , 1018
# 455 , 1018
# 456 , 1018
# 457 , 1018
# 458 , 1018
# 459 , 1018
# 460 , 1018
# 461 , 1018
# 462 , 1018
# 463 , 1018
# 464 , 1018
# 465 , 1018
# 466 , 1018
# 467 , 1018
# 468 , 1018
# 469 , 1018
# 470 , 1018
# 471 , 1018
# 472 , 1018
# 473 , 1018
# 474 , 1018
# 475 , 1018
# 476 , 1018
# 477 , 1018
# 478 , 1018
# 479 , 1018
# 480 , 1018
# 481 , 1018
# 482 , 1018
# 483 , 1018
# 484 , 1018
# 485 , 1018
# 486 , 1018
# 487 , 1018
# 488 , 1018
# 489 , 1018
# 490 , 1018
# 491 , 1018
# 492 , 1018
# 493 , 1018
# 494 , 1018
# 495 , 1018
# 496 , 1018
# 497 , 1018
# 498 , 1018
# 499 , 1018
# 500 , 1018
# 501 , 1018
# 502 , 1018
# 503 , 1018
# 504 , 1018
# 505 , 1018
# 506 , 1018
# 507 , 1018
# 508 , 1018
# 509 , 1018
# 510 , 1018
# 511 , 1018
# 512 , 1018
# 513 , 1018
# 514 , 1018
# 515 , 1018
# 516 , 1018
# 517 , 1018
# 518 , 1018
# 519 , 1018
# 520 , 1018
# 521 , 1018
# 522 , 1018
# 523 , 1018
# 524 , 1018
# 525 , 1018
# 526 , 1018
# 527 , 1018
# 528 , 1018
# 529 , 1018
# 530 , 1018
# 531 , 1018
# 532 , 1018
# 533 , 1018
# 534 , 1018
# 535 , 1018
# 536 , 1018
# 537 , 1018
# 538 , 1018
# 539 , 1018
# 540 , 1018
# 541 , 1018
# 542 , 1018
# 543 , 1018
# 544 , 1018
# 545 , 1018
# 546 , 1018
# 547 , 1018
# 548 , 1018
# 549 , 1018
# 550 , 1018
# 551 , 1018
# 552 , 1018
# 553 , 1018
# 554 , 1018
# 555 , 1018
# 556 , 1018
# 557 , 1018
# 558 , 1018
# 559 , 1018
# 560 , 1018
# 561 , 1018
# 562 , 1018
# 563 , 1018
# 564 , 1018
# 565 , 1018
# 566 , 1018
# 567 , 1018
# 568 , 1018
# 569 , 1018
# 570 , 1018
# 571 , 1018
# 572 , 1018
# 573 , 1018
# 574 , 1018
# 575 , 1018
# 576 , 1018
# 577 , 1018
# 578 , 1018
# 579 , 1018
# 580 , 1018
# 581 , 1018
# 582 , 1018
# 583 , 1018
# 584 , 1018
# 585 , 1018
# 586 , 1018
# 587 , 1018
# 588 , 1018
# 589 , 1018
# 590 , 1018
# 591 , 1018
# 592 , 1018
# 593 , 1018
# 594 , 1018
# 595 , 1018
# 596 , 1018
# 597 , 1018
# 598 , 1018
# 599 , 1018
# 600 , 1018
# 601 , 1018
# 602 , 1018
# 603 , 1018
# 604 , 1018
# 605 , 1018
# 606 , 1018
# 607 , 1018
# 608 , 1018
# 609 , 1018
# 610 , 1018
# 611 , 1018
# 612 , 1018
# 613 , 1018
# 614 , 1018
# 615 , 1018
# 616 , 1018
# 617 , 1018
# 618 , 1018
# 619 , 1018
# 620 , 1018
# 621 , 1018
# 622 , 1018
# 623 , 1018
# 624 , 1018
# 625 , 1018
# 626 , 1018
# 627 , 1018
# 628 , 1018
# 629 , 1018
# 630 , 1018
# 631 , 1018
# 632 , 1018
# 633 , 1018
# 634 , 1018
# 635 , 1018
# 636 , 1018
# 637 , 1018
# 638 , 1018
# 639 , 1018
# 640 , 1018
# 641 , 1018
# 642 , 1018
# 643 , 1018
# 644 , 1018
# 645 , 1018
# 646 , 1018
# 647 , 1018
# 648 , 1018
# 649 , 1018
# 650 , 1018
# 651 , 1018
# 652 , 1018
# 653 , 1018
# 654 , 1018
# 655 , 1018
# 656 , 1018
# 657 , 1018
# 658 , 1018
# 659 , 1018
# 660 , 1018
# 661 , 1018
# 662 , 1018
# 663 , 1018
# 664 , 1018
# 665 , 1018
# 666 , 1018
# 667 , 1018
# 668 , 1018
# 669 , 1018
# 670 , 1018
# 671 , 1018
# 672 , 1018
# 673 , 1018
# 674 , 1018
# 675 , 1018
# 676 , 1018
# 677 , 1018
# 678 , 1018
# 679 , 1018
# 680 , 1018
# 681 , 1018
# 682 , 1018
# 683 , 1018
# 684 , 1018
# 685 , 1018
# 686 , 1018
# 687 , 1018
# 688 , 1018
# 689 , 1018
# 690 , 1018
# 691 , 1018
# 692 , 1018
# 693 , 1018
# 694 , 1018
# 695 , 1018
# 696 , 1018
# 697 , 1018
# 698 , 1018
# 699 , 1018
# 700 , 1018
# 701 , 1018
# 702 , 1018
# 703 , 1018
# 704 , 1018
# 705 , 1018
# 706 , 1018
# 707 , 1018
# 708 , 1018
# 709 , 1018
# 710 , 1018
# 711 , 1018
# 712 , 1018
# 713 , 1018
# 714 , 1018
# 715 , 1018
# 716 , 1018
# 717 , 1018
# 718 , 1018
# 719 , 1018
# 720 , 1018
# 721 , 1018
# 722 , 1018
# 723 , 1018
# 724 , 1018
# 725 , 1018
# 726 , 1018
# 727 , 1018
# 728 , 1018
# 729 , 1018
# 730 , 1018
# 731 , 1018
# 732 , 1018
# 733 , 1018
# 734 , 1018
# 735 , 1018
# 736 , 1018
# 737 , 1018
# 738 , 1018
# 739 , 1018
# 740 , 1018
# 741 , 1018
# 742 , 1018
# 743 , 1018
# 744 , 1018
# 745 , 1018
# 746 , 1018
# 747 , 1018
# 748 , 1018
# 749 , 1018
# 750 , 1018
# 751 , 1018
# 752 , 1018
# 753 , 1018
# 754 , 1018
# 755 , 1018
# 756 , 1018
# 757 , 1018
# 758 , 1018
# 759 , 1018
# 760 , 1018
# 761 , 1018
# 762 , 1018
# 763 , 1018
# 764 , 1018
# 765 , 1018
# 766 , 1018
# 767 , 1018
# 768 , 1018
# 769 , 1018
# 770 , 1018
# 771 , 1018
# 772 , 1018
# 773 , 1018
# 774 , 1018
# 775 , 1018
# 776 , 1018
# 777 , 1018
# 778 , 1018
# 779 , 1018
# 780 , 1018
# 781 , 1018
# 782 , 1018
# 783 , 1018
# 784 , 1018
# 785 , 1018
# 786 , 1018
# 787 , 1018
# 788 , 1018
# 789 , 1018
# 790 , 1018
# 791 , 1018
# 792 , 1018
# 793 , 1018
# 794 , 1018
# 795 , 1018
# 796 , 1018
# 797 , 1018
# 798 , 1018
# 799 , 1018
# 800 , 1018
# 801 , 1018
# 802 , 1018
# 803 , 1018
# 804 , 1018
# 805 , 1018
# 806 , 1018
# 807 , 1018
# 808 , 1018
# 809 , 1018
# 810 , 1018
# 811 , 1018
# 812 , 1018
# 813 , 1018
# 814 , 1018
# 815 , 1018
# 816 , 1018
# 817 , 1018
# 818 , 1018
# 819 , 1018
# 820 , 1018
# 821 , 1018
# 822 , 1018
# 823 , 1018
# 824 , 1018
# 825 , 1018
# 826 , 1018
# 827 , 1018
# 828 , 1018
# 829 , 1018
# 830 , 1018
# 831 , 1018
# 832 , 1018
# 833 , 1018
# 834 , 1018
# 835 , 1018
# 836 , 1018
# 837 , 1018
# 838 , 1018
# 839 , 1018
# 840 , 1018
# 841 , 1018
# 842 , 1018
# 843 , 1018
# 844 , 1018
# 845 , 1018
# 846 , 1018
# 847 , 1018
# 848 , 1018
# 849 , 1018
# 850 , 1018
# 851 , 1018
# 852 , 1018
# 853 , 1018
# 854 , 1018
# 855 , 1018
# 856 , 1018
# 857 , 1018
# 858 , 1018
# 859 , 1018
# 860 , 1018
# 861 , 1018
# 862 , 1018
# 863 , 1018
# 864 , 1018
# 865 , 1018
# 866 , 1018
# 867 , 1018
# 868 , 1018
# 869 , 1018
# 870 , 1018
# 871 , 1018
# 872 , 1018
# 873 , 1018
# 874 , 1018
# 875 , 1018
# 876 , 1018
# 877 , 1018
# 878 , 1018
# 879 , 1018
# 880 , 1018
# 881 , 1018
# 882 , 1018
# 883 , 1018
# 884 , 1018
# 885 , 1018
# 886 , 1018
# 887 , 1018
# 888 , 1018
# 889 , 1018
# 890 , 1018
# 891 , 1018
# 892 , 1018
# 893 , 1018
# 894 , 1018
# 895 , 1018
# 896 , 1018
# 897 , 1018
# 898 , 1018
# 899 , 1018
# 900 , 1018
# 901 , 1018
# 902 , 1018
# 903 , 1018
# 904 , 1018
# 905 , 1018
# 906 , 1018
# 907 , 1018
# 908 , 1018
# 909 , 1018
# 910 , 1018
# 911 , 1018
# 912 , 1018
# 913 , 1018
# 914 , 1018
# 915 , 1018
# 916 , 1018
# 917 , 1018
# 918 , 1018
# 919 , 1018
# 920 , 1018
# 921 , 1018
# 922 , 1018
# 923 , 1018
# 924 , 1018
# 925 , 1018
# 926 , 1018
# 927 , 1018
# 928 , 1018
# 929 , 1018
# 930 , 1018
# 931 , 1018
# 932 , 1018
# 933 , 1018
# 934 , 1018
# 935 , 1018
# 936 , 1018
# 937 , 1018
# 938 , 1018
# 939 , 1018
# 940 , 1018
# 941 , 1018
# 942 , 1018
# 943 , 1018
# 944 , 1018
# 945 , 1018
# 946 , 1018
# 947 , 1018
# 948 , 1018
# 949 , 1018
# 950 , 1018
# 951 , 1018
# 952 , 1018
# 953 , 1018
# 954 , 1018
# 955 , 1018
# 956 , 1018
# 957 , 1018
# 958 , 1018
# 959 , 1018
# 960 , 1018
# 961 , 1018
# 962 , 1018
# 963 , 1018
# 964 , 1018
# 965 , 1018
# 966 , 1018
# 967 , 1018
# 968 , 1018
# 969 , 1018
# 970 , 1018
# 971 , 1018
# 972 , 1018
# 973 , 1018
# 974 , 1018
# 975 , 1018
# 976 , 1018
# 977 , 1018
# 978 , 1018
# 979 , 1018
# 980 , 1018
# 981 , 1018
# 982 , 1018
# 983 , 1018
# 984 , 1018
# 985 , 1018
# 986 , 1018
# 987 , 1018
# 988 , 1018
# 989 , 1018
# 990 , 1018
# 991 , 1018
# 992 , 1018
# 993 , 1018
# 994 , 1018
# 995 , 1018
# 996 , 1018
# 997 , 1018
# 998 , 1018
# 999 , 1018
# 1000 , 1018
# 1001 , 1018
# 1002 , 1018
# 1003 , 1018
# 1004 , 1018
# 1005 , 1018
# 1006 , 1018
# 1007 , 1018
# 1008 , 1018
# 1009 , 1018
# 1010 , 1018
# 1011 , 1018
# 1012 , 1018
# 1013 , 1018
# 1014 , 1018
# 1015 , 1018
# 1016 , 1018
# 1017 , 1018

# %%
df_.head()
# Out:
#        First Name Last Name                      Email     Telephone  \
# 0          Ghaleb   Abdulla          abdulla1@llnl.gov  925-423-5947
# 1  Paul Alexander     Abell      paul.a.abell@nasa.gov  281-483-0293
# 2            Eric      Agol  agol@astro.washington.edu           NaN
# 3            Eric      Agol  agol@astro.washington.edu           NaN
# 4          Michel    Aguena           aguena@if.usp.br           NaN
#
#                                   Company Contact Category       Role  \
# 0  Lawrence Livermore National Laboratory       Transients     Member
# 1               NASA Johnson Space Center     Solar System     Member
# 2                University of Washington       Transients     Member
# 3                University of Washington   Strong Lensing  Affiliate
# 4                                     NaN             DESC     Member
#
#    Unnamed: 7  Unnamed: 8  Unnamed: 9  Unnamed: 10  Unnamed: 11  Unnamed: 12
# 0         NaN         NaN         NaN          NaN          NaN          NaN
# 1         NaN         NaN         NaN          NaN          NaN          NaN
# 2         NaN         NaN         NaN          NaN          NaN          NaN
# 3         NaN         NaN         NaN          NaN          NaN          NaN
# 4         NaN         NaN         NaN          NaN          NaN          NaN

# %%
df_['First Name'].values[1].replace(" ", "")
# Out:
# 'PaulAlexander'

# %%
df_['name'] = (df_['Last Name'].str.replace("","").str.replace(" ","") + 
               df_['First Name'].str.replace(" ","").str.replace(" ",
            "")).str.replace(" ","").str.replace("''","")

affiliationsDF = pd.get_dummies(df_.set_index('name')["Contact Category"])
affiliationsDF
# Out:
#                                AGN  DESC  Galaxies  \
# name
# AbdullaGhaleb                    0     0         0
# AbellPaulAlexander               0     0         0
# AgolEric                         0     0         0
# AgolEric                         0     0         0
# AguenaMichel                     0     1         0
# AguerosMarcel                    0     0         0
# AguerosMarcel                    0     0         0
# AkhlaghiMohammad                 0     0         1
# AlderingGreg                     0     1         0
# AllenMark                        0     0         0
# AllenSteven                      0     1         0
# AlmeydaTriana                    1     0         0
# AlonsoDavid                      0     1         0
# Alonso-GarciaJavier              0     0         0
# Alonso-GarciaJavier              0     0         0
# AnderesEthan                     0     0         0
# AndersonScott                    0     0         0
# AndersonScott                    0     0         0
# AnguitaTimo                      1     0         0
# AnguitaTimo                      0     0         0
# AnsariReza                       0     0         1
# AntilogusPierre                  0     1         0
# AntoniucciSimone                 0     1         0
# AravenaManuel                    0     0         0
# ArcaviIair                       0     0         1
# ArdilaDavid                      0     0         0
# ArgudoFernandezMariadelCarmen    0     0         0
# ArmusLee                         0     0         0
# ArnettW.David                    0     0         1
# AssefRoberto                     0     0         1
# ...                            ...   ...       ...
# WolpertRobert                    0     0         1
# WomackMaria                      0     0         0
# Wood-VaseyMichael                0     0         0
# Wood-VaseyMichael                1     0         0
# Wood-VaseyMichael                0     0         0
# WoodroofeMichael                 0     0         0
# WozniakPrzemek                   0     0         1
# Yanamandra-FisherPadma           0     0         0
# YangGuang                        0     0         0
# YangSheng                        0     0         0
# YeQuan-Zhi                       0     0         0
# YoachimPeter                     0     0         0
# YoachimPeter                     0     0         0
# YoungDavid                       0     0         0
# YoungLeslie                      0     0         0
# YuWeixiang                       0     0         0
# ZabludoffAnn                     0     0         0
# ZaudererAshley                   0     1         0
# ZehaviIdit                       0     0         0
# ZentnerAndrew                    0     0         1
# ZentnerAndrew                    0     0         0
# ZentnerAndrew                    0     0         0
# ZentnerAndrew                    0     0         0
# ZentnerAndrew                    0     0         0
# ZhanHu                           0     0         0
# ZhaoGong-Bo                      0     0         0
# ZhengZhenia                      1     0         0
# ZoccaliManuela                   0     0         0
# ZolotovAdi                       0     0         1
# ZuntzJoe                         0     0         0
#
#                                Milky Way and Local Volume  Solar System  \
# name
# AbdullaGhaleb                                           0             0
# AbellPaulAlexander                                      0             1
# AgolEric                                                0             0
# AgolEric                                                0             0
# AguenaMichel                                            0             0
# AguerosMarcel                                           0             0
# AguerosMarcel                                           0             0
# AkhlaghiMohammad                                        0             0
# AlderingGreg                                            0             0
# AllenMark                                               0             0
# AllenSteven                                             0             0
# AlmeydaTriana                                           0             0
# AlonsoDavid                                             0             0
# Alonso-GarciaJavier                                     0             0
# Alonso-GarciaJavier                                     0             0
# AnderesEthan                                            1             0
# AndersonScott                                           0             0
# AndersonScott                                           0             0
# AnguitaTimo                                             0             0
# AnguitaTimo                                             0             0
# AnsariReza                                              0             0
# AntilogusPierre                                         0             0
# AntoniucciSimone                                        0             0
# AravenaManuel                                           0             0
# ArcaviIair                                              0             0
# ArdilaDavid                                             0             0
# ArgudoFernandezMariadelCarmen                           0             0
# ArmusLee                                                1             0
# ArnettW.David                                           0             0
# AssefRoberto                                            0             0
# ...                                                   ...           ...
# WolpertRobert                                           0             0
# WomackMaria                                             0             0
# Wood-VaseyMichael                                       0             0
# Wood-VaseyMichael                                       0             0
# Wood-VaseyMichael                                       0             1
# WoodroofeMichael                                        0             1
# WozniakPrzemek                                          0             0
# Yanamandra-FisherPadma                                  0             0
# YangGuang                                               1             0
# YangSheng                                               0             0
# YeQuan-Zhi                                              0             1
# YoachimPeter                                            0             0
# YoachimPeter                                            0             0
# YoungDavid                                              0             0
# YoungLeslie                                             1             0
# YuWeixiang                                              0             0
# ZabludoffAnn                                            1             0
# ZaudererAshley                                          0             0
# ZehaviIdit                                              0             1
# ZentnerAndrew                                           0             0
# ZentnerAndrew                                           0             0
# ZentnerAndrew                                           1             0
# ZentnerAndrew                                           0             0
# ZentnerAndrew                                           0             0
# ZhanHu                                                  0             1
# ZhaoGong-Bo                                             0             0
# ZhengZhenia                                             0             0
# ZoccaliManuela                                          0             1
# ZolotovAdi                                              0             0
# ZuntzJoe                                                0             0
#
#                                Stars  Statistics and Informatics  \
# name
# AbdullaGhaleb                      0                           0
# AbellPaulAlexander                 0                           0
# AgolEric                           0                           0
# AgolEric                           0                           0
# AguenaMichel                       0                           0
# AguerosMarcel                      0                           0
# AguerosMarcel                      0                           0
# AkhlaghiMohammad                   0                           0
# AlderingGreg                       0                           0
# AllenMark                          0                           0
# AllenSteven                        0                           0
# AlmeydaTriana                      0                           0
# AlonsoDavid                        0                           0
# Alonso-GarciaJavier                0                           0
# Alonso-GarciaJavier                1                           0
# AnderesEthan                       0                           0
# AndersonScott                      0                           1
# AndersonScott                      0                           0
# AnguitaTimo                        0                           0
# AnguitaTimo                        0                           0
# AnsariReza                         0                           0
# AntilogusPierre                    0                           0
# AntoniucciSimone                   0                           0
# AravenaManuel                      0                           0
# ArcaviIair                         0                           0
# ArdilaDavid                        0                           0
# ArgudoFernandezMariadelCarmen      1                           0
# ArmusLee                           0                           0
# ArnettW.David                      0                           0
# AssefRoberto                       0                           0
# ...                              ...                         ...
# WolpertRobert                      0                           0
# WomackMaria                        0                           0
# Wood-VaseyMichael                  0                           0
# Wood-VaseyMichael                  0                           0
# Wood-VaseyMichael                  0                           0
# WoodroofeMichael                   0                           0
# WozniakPrzemek                     0                           0
# Yanamandra-FisherPadma             1                           0
# YangGuang                          0                           0
# YangSheng                          0                           1
# YeQuan-Zhi                         0                           0
# YoachimPeter                       0                           0
# YoachimPeter                       0                           0
# YoungDavid                         1                           0
# YoungLeslie                        0                           0
# YuWeixiang                         1                           0
# ZabludoffAnn                       0                           0
# ZaudererAshley                     0                           0
# ZehaviIdit                         0                           0
# ZentnerAndrew                      0                           0
# ZentnerAndrew                      1                           0
# ZentnerAndrew                      0                           0
# ZentnerAndrew                      0                           1
# ZentnerAndrew                      0                           0
# ZhanHu                             0                           0
# ZhaoGong-Bo                        0                           0
# ZhengZhenia                        0                           0
# ZoccaliManuela                     0                           0
# ZolotovAdi                         0                           0
# ZuntzJoe                           1                           0
#
#                                Strong Lensing  Transients
# name
# AbdullaGhaleb                               0           1
# AbellPaulAlexander                          0           0
# AgolEric                                    0           1
# AgolEric                                    1           0
# AguenaMichel                                0           0
# AguerosMarcel                               0           1
# AguerosMarcel                               1           0
# AkhlaghiMohammad                            0           0
# AlderingGreg                                0           0
# AllenMark                                   1           0
# AllenSteven                                 0           0
# AlmeydaTriana                               0           0
# AlonsoDavid                                 0           0
# Alonso-GarciaJavier                         0           1
# Alonso-GarciaJavier                         0           0
# AnderesEthan                                0           0
# AndersonScott                               0           0
# AndersonScott                               0           1
# AnguitaTimo                                 0           0
# AnguitaTimo                                 1           0
# AnsariReza                                  0           0
# AntilogusPierre                             0           0
# AntoniucciSimone                            0           0
# AravenaManuel                               0           1
# ArcaviIair                                  0           0
# ArdilaDavid                                 0           1
# ArgudoFernandezMariadelCarmen               0           0
# ArmusLee                                    0           0
# ArnettW.David                               0           0
# AssefRoberto                                0           0
# ...                                       ...         ...
# WolpertRobert                               0           0
# WomackMaria                                 0           1
# Wood-VaseyMichael                           0           1
# Wood-VaseyMichael                           0           0
# Wood-VaseyMichael                           0           0
# WoodroofeMichael                            0           0
# WozniakPrzemek                              0           0
# Yanamandra-FisherPadma                      0           0
# YangGuang                                   0           0
# YangSheng                                   0           0
# YeQuan-Zhi                                  0           0
# YoachimPeter                                1           0
# YoachimPeter                                0           1
# YoungDavid                                  0           0
# YoungLeslie                                 0           0
# YuWeixiang                                  0           0
# ZabludoffAnn                                0           0
# ZaudererAshley                              0           0
# ZehaviIdit                                  0           0
# ZentnerAndrew                               0           0
# ZentnerAndrew                               0           0
# ZentnerAndrew                               0           0
# ZentnerAndrew                               0           0
# ZentnerAndrew                               0           1
# ZhanHu                                      0           0
# ZhaoGong-Bo                                 0           1
# ZhengZhenia                                 0           0
# ZoccaliManuela                              0           0
# ZolotovAdi                                  0           0
# ZuntzJoe                                    0           0
#
# [1018 rows x 9 columns]

# %%
affiliationsDF = affiliationsDF.groupby("name").sum()
affiliationsDF.replace(2,1, inplace=True)
affiliationsDF.replace(3,1, inplace=True)

# %%
affiliationset = set(affiliations)

# %%
df_["Contact Category"].unique()
# Out:
# array(['Transients', 'Solar System', 'Strong Lensing', 'DESC', 'Galaxies',
#        'AGN', 'Stars', 'Milky Way and Local Volume',
#        'Statistics and Informatics'], dtype=object)

# %%
propernames = {"Transients":'TVS', 
               'Solar System':'SS', 
               'Strong Lensing':'SL', 
               'DESC':'DESC', 
               'Galaxies':'Galaxies',
               'AGN':'AGN', 
               'Stars': "SMWLV",
               'Milky Way and Local Volume':'SMWLV',
               ' Milky Way and Local Volume':'SMWLV',
               'Statistics and Informatics':'IS'}
def hex_to_rgba(value):
    value = value.lstrip('#')
    lv = len(value)
    return tuple(list(int(value[i:i + lv // 3], 16) for i in range(0, lv, lv // 3)) + [1])

properhexcolors = {"TVS":"#44aa99",
               'SS':"#332288",
               'SL':"#117733", 
               'DESC':"#cc6677", 
               'Galaxies':"#aa4499",
               'AGN':"#882255", 
               'SMWLV': "#88ccee",
               'IS':"#ddcc77"}
propercolors = {"Transients":properhexcolors[propernames["Transients"]],
                'Solar System':properhexcolors[propernames['Solar System']],
               'Strong Lensing':properhexcolors[propernames["Strong Lensing"]], 
               'DESC':properhexcolors[propernames["DESC"]], 
               'Galaxies':properhexcolors[propernames["Galaxies"]],
               'AGN':properhexcolors[propernames["AGN"]], 
               'Stars': properhexcolors[propernames["Stars"]],
               'Milky Way and Local Volume':properhexcolors[propernames["Milky Way and Local Volume"]],
               'Statistics and Informatics':properhexcolors[propernames["Statistics and Informatics"]]}
propercolorsNat = {"Transients":properhexcolors[propernames["Transients"]],
                'Solar System':properhexcolors[propernames['Solar System']],
               'Strong Lensing':properhexcolors[propernames["Strong Lensing"]], 
               'DESC':properhexcolors[propernames["DESC"]], 
               'Galaxies':properhexcolors[propernames["Galaxies"]],
               'AGN':properhexcolors[propernames["AGN"]], 
               'Stars': properhexcolors[propernames["Stars"]],
               'Milky Way and Local Volume':properhexcolors[propernames["Milky Way and Local Volume"]],
               'Statistics and Informatics':properhexcolors[propernames["Statistics and Informatics"]]}

sccolor = {}

countrycolor = {}

def rgb2hex(x):
    print(x)
    if isinstance(x[0], float):
        r = (x[0]*255).astype(np.uint8)
        g = (x[1]*255).astype(np.uint8)
        b = (x[2]*255).astype(np.uint8)
        print(r,g,b)
        return "#{0:02x}{1:02x}{2:02x}".format(max(r, min(r, 255)), 
                                           max(g, min(g, 255)),
                                           max(b, min(b, 255)))
    return "#{0:02x}{1:02x}{2:02x}".format(max(x[0], min(x[0], 255)), 
                                           max(x[1], min(x[1], 255)),
                                           max(x[2], min(x[2], 255)))

   
print(rgb2hex((0,1,255)))


import pylab
NUM_COLORS = len(countrymap)+1

cm = pylab.get_cmap('viridis')
for i,cc in enumerate(countrymap.values()):
    print(cc)
    if cc in ['US']: 
        print("here")
        countrycolor[cc] = rgb2hex((192,192,192))
    else: 
        countrycolor[cc] = rgb2hex(cm(1.*i / (NUM_COLORS))[:-1])
    print(countrycolor[cc])

    



NUM_COLORS = 8

cm = pylab.get_cmap('viridis')
for i,cc in enumerate(propernames.values()):
    sccolor[cc] = rgb2hex((0, 128, 64))
    
propercolors, countrycolor
# Out:
# (0, 1, 255)
# #0001ff
# US
# here
# (192, 192, 192)
# #c0c0c0
# US
# here
# (192, 192, 192)
# #c0c0c0
# BR
# (0.28291, 0.105393, 0.426902)
# 72 26 108
# #481a6c
# UK
# (0.281412, 0.155834, 0.469201)
# 71 39 119
# #472777
# CL
# (0.274128, 0.199721, 0.498911)
# 69 50 127
# #45327f
# FR
# (0.260571, 0.246922, 0.522828)
# 66 62 133
# #423e85
# IT
# (0.244972, 0.287675, 0.53726)
# 62 73 137
# #3e4989
# CA
# (0.225863, 0.330805, 0.547314)
# 57 84 139
# #39548b
# AU
# (0.208623, 0.367752, 0.552675)
# 53 93 140
# #355d8c
# ES
# (0.190631, 0.407061, 0.556089)
# 48 103 141
# #30678d
# CN
# (0.175841, 0.44129, 0.557685)
# 44 112 142
# #2c708e
# DE
# (0.160665, 0.47854, 0.558115)
# 40 122 142
# #287a8e
# PL
# (0.147607, 0.511733, 0.557049)
# 37 130 142
# #25828e
# NZ
# (0.133743, 0.548535, 0.553541)
# 34 139 141
# #228b8d
# CZ
# (0.123463, 0.581687, 0.547445)
# 31 148 139
# #1f948b
# SI
# (0.119699, 0.61849, 0.536347)
# 30 157 136
# #1e9d88
# FI
# (0.130067, 0.651384, 0.521608)
# 33 166 133
# #21a685
# RS
# (0.162016, 0.687316, 0.499129)
# 41 175 127
# #29af7f
# US
# here
# (192, 192, 192)
# #c0c0c0
# HU
# (0.274149, 0.751988, 0.436601)
# 69 191 111
# #45bf6f
# DK
# (0.344074, 0.780029, 0.397381)
# 87 198 101
# #57c665
# IS
# (0.430983, 0.808473, 0.346476)
# 109 206 88
# #6dce58
# US
# here
# (192, 192, 192)
# #c0c0c0
# SW
# (0.616293, 0.852709, 0.230052)
# 157 217 58
# #9dd93a
# oth
# (0.709898, 0.868751, 0.169257)
# 181 221 43
# #b5dd2b
# SA
# (0.814576, 0.883393, 0.110347)
# 207 225 28
# #cfe11c
# (0, 128, 64)
# (0, 128, 64)
# (0, 128, 64)
# (0, 128, 64)
# (0, 128, 64)
# (0, 128, 64)
# (0, 128, 64)
# (0, 128, 64)
# (0, 128, 64)
# (0, 128, 64)
# ({'Transients': '#44aa99',
#   'Solar System': '#332288',
#   'Strong Lensing': '#117733',
#   'DESC': '#cc6677',
#   'Galaxies': '#aa4499',
#   'AGN': '#882255',
#   'Stars': '#88ccee',
#   'Milky Way and Local Volume': '#88ccee',
#   'Statistics and Informatics': '#ddcc77'},
#  {'US': '#c0c0c0',
#   'BR': '#481a6c',
#   'UK': '#472777',
#   'CL': '#45327f',
#   'FR': '#423e85',
#   'IT': '#3e4989',
#   'CA': '#39548b',
#   'AU': '#355d8c',
#   'ES': '#30678d',
#   'CN': '#2c708e',
#   'DE': '#287a8e',
#   'PL': '#25828e',
#   'NZ': '#228b8d',
#   'CZ': '#1f948b',
#   'SI': '#1e9d88',
#   'FI': '#21a685',
#   'RS': '#29af7f',
#   'HU': '#45bf6f',
#   'DK': '#57c665',
#   'IS': '#6dce58',
#   'SW': '#9dd93a',
#   'oth': '#b5dd2b',
#   'SA': '#cfe11c'})

# %%
affiliationsDF.head()
# Out:
#                     AGN  DESC  Galaxies  Milky Way and Local Volume  \
# name
# AbdullaGhaleb         0     0         0                           0
# AbellPaulAlexander    0     0         0                           0
# AgolEric              0     0         0                           0
# AguenaMichel          0     1         0                           0
# AguerosMarcel         0     0         0                           0
#
#                     Solar System  Stars  Statistics and Informatics  \
# name
# AbdullaGhaleb                  0      0                           0
# AbellPaulAlexander             1      0                           0
# AgolEric                       0      0                           0
# AguenaMichel                   0      0                           0
# AguerosMarcel                  0      0                           0
#
#                     Strong Lensing  Transients
# name
# AbdullaGhaleb                    0           1
# AbellPaulAlexander               0           0
# AgolEric                         1           1
# AguenaMichel                     0           0
# AguerosMarcel                    1           1

# %%
import networkx as nx
p = {}
c = {}
countrylabel = {}
my_graph = nx.Graph()
edges = nx.read_edgelist('affedges.txt')
nodes = nx.read_adjlist("affnodes.txt")
for i,n1 in enumerate(affiliationsDF.index.values):
    p[n1] = propernames[df_[df_['name'] == n1]["Contact Category"].values[0].strip().lstrip()]
    #propercolors[df_[df_['name'] == n1]["Contact Category"].values[0].strip().lstrip()]
    tmp_ = df_[df_['name'] == n1]["Email"].values[0]
    if tmp_.strip().split('.')[-1] in countrymap:
        c[n1] = countrycolor[countrymap[tmp_.strip().split('.')[-1]]]
        countrylabel[n1] = countrymap[tmp_.strip().split('.')[-1]]
    else:
        c[n1] = countrycolor[countries[df_[df_['name'] == n1]["Email"].values[0]]]
        countrylabel[n1] = countries[df_[df_['name'] == n1]["Email"].values[0]]

    
p
# Out:
# {'AbdullaGhaleb': 'TVS',
#  'AbellPaulAlexander': 'SS',
#  'AgolEric': 'TVS',
#  'AguenaMichel': 'DESC',
#  'AguerosMarcel': 'TVS',
#  'AkhlaghiMohammad': 'Galaxies',
#  'AlderingGreg': 'DESC',
#  'AllenMark': 'SL',
#  'AllenSteven': 'DESC',
#  'AlmeydaTriana': 'AGN',
#  'Alonso-GarciaJavier': 'TVS',
#  'AlonsoDavid': 'DESC',
#  'AnderesEthan': 'SMWLV',
#  'AndersonScott': 'IS',
#  'AnguitaTimo': 'AGN',
#  'AnsariReza': 'Galaxies',
#  'AntilogusPierre': 'DESC',
#  'AntoniucciSimone': 'DESC',
#  'AravenaManuel': 'TVS',
#  'ArcaviIair': 'Galaxies',
#  'ArdilaDavid': 'TVS',
#  'ArgudoFernandezMariadelCarmen': 'SMWLV',
#  'ArmusLee': 'SMWLV',
#  'ArnettW.David': 'Galaxies',
#  'AssefRoberto': 'Galaxies',
#  'AstierPierre': 'TVS',
#  'AubourgEric': 'AGN',
#  'AvestruzCamille': 'DESC',
#  'AwanHumna': 'SL',
#  'AyeMichael': 'DESC',
#  'BabuJogesh': 'DESC',
#  'BaileyStephen': 'SS',
#  'BailynCharles': 'IS',
#  'BallandChristophe': 'IS',
#  'BallantyneDavid': 'TVS',
#  'BalmaverdeBarbara': 'DESC',
#  'BaloghMichael': 'AGN',
#  'BaltzTed': 'TVS',
#  'BandaMartin': 'Galaxies',
#  'BanerjiManda': 'SL',
#  'BannisterMichele': 'SS',
#  'BarbaRodolfo': 'Galaxies',
#  'BarbieriMauro': 'SS',
#  'BardDeborah': 'SMWLV',
#  'BarrauAurelien': 'SMWLV',
#  'BarreraLuis': 'SMWLV',
#  'BarrientosFelipe': 'SMWLV',
#  'BarthAaron': 'DESC',
#  'BartlettJames': 'DESC',
#  'BassGideon': 'Galaxies',
#  'BauerFranz': 'AGN',
#  'BaumerMichael': 'Galaxies',
#  'BeanRachel': 'DESC',
#  'BechtolKeith': 'TVS',
#  'BeckerAndrew': 'AGN',
#  'BeclaJacek': 'DESC',
#  'BeersTimothyC.': 'SS',
#  'BellEric': 'TVS',
#  'BellKeaton': 'DESC',
#  'BellagambaFabio': 'IS',
#  'BellmEric': 'SMWLV',
#  'BelokurovVasily': 'SMWLV',
#  'BergerEdo': 'SMWLV',
#  'BernsteinGary': 'SMWLV',
#  'BersierDavid': 'TVS',
#  'BetouleMarc': 'Galaxies',
#  'BiancoFederica': 'TVS',
#  'BianconiMatteo': 'SMWLV',
#  'BiswasRahul': 'TVS',
#  'BivianoAndrea': 'SS',
#  'BlancGuillaume': 'TVS',
#  'BlandfordRoger': 'DESC',
#  'BlantonMichaelRogers': 'IS',
#  'BlazekJonathan': 'TVS',
#  'BloomJosh': 'Galaxies',
#  'BlumBob': 'DESC',
#  'BochanskiJohn': 'Galaxies',
#  'BodewitsDennis': 'DESC',
#  'BoeshaarPatricia': 'SL',
#  'BolinBryce': 'Galaxies',
#  'BondHoward': 'DESC',
#  'BongardSebastien': 'TVS',
#  'BonitoRosaria': 'SMWLV',
#  'BonoGiuseppe': 'SMWLV',
#  'BoquienMederic': 'SMWLV',
#  'BorglandAnders': 'SS',
#  'BorneKirk': 'SMWLV',
#  'BorosonTodd': 'SS',
#  'BoschJames': 'TVS',
#  'BoschJim': 'DESC',
#  'BoseMaitrayee': 'SMWLV',
#  'BoshAmanda': 'SMWLV',
#  'BotticellaMariaTeresa': 'TVS',
#  'BoutignyDominique': 'TVS',
#  'BowlerRebecca': 'Galaxies',
#  'BradacMarusa': 'DESC',
#  'BradshawAndrew': 'IS',
#  'BrandtNiel': 'Galaxies',
#  'BremerMalcolm': 'SS',
#  'BridgeCarrie': 'SS',
#  'BridleSarah': 'TVS',
#  'BrittChristopher': 'DESC',
#  'BrocatoEnzo': 'Galaxies',
#  'BrothertonMichael': 'SL',
#  'BroughSarah': 'DESC',
#  'BrownMichael': 'TVS',
#  'BrownPeter': 'Galaxies',
#  'BrownTim': 'AGN',
#  'BrozovicMarina': 'IS',
#  'BrunnerRobert': 'Galaxies',
#  'BudavariTamas': 'DESC',
#  'BuenodeCamargoJulioIgnacio': 'SMWLV',
#  'BuieMarc': 'SMWLV',
#  'BullPhilip': 'TVS',
#  'BullockJames': 'AGN',
#  'BurchatPatricia': 'Galaxies',
#  'BurgasserAdam': 'SS',
#  'BurkeDavid': 'TVS',
#  'BurkeDouglas': 'SS',
#  'BurninghamBen': 'IS',
#  'ButlerNathaniel': 'AGN',
#  'CabreraGuillermo': 'IS',
#  'CaiYongzhi': 'SS',
#  'CalabreseErminia': 'SS',
#  'CalamidaAnnalisa': 'DESC',
#  'CampagneJean-Eric': 'SMWLV',
#  'Cantat-GaudinTristan': 'SMWLV',
#  'CargilePhillip': 'DESC',
#  'CariniRoberta': 'SL',
#  'CarlinJeff': 'SMWLV',
#  'CarnereroMartinMariaIsabel': 'SMWLV',
#  'Carrasco-KindMatias': 'DESC',
#  'CasettiDanaIoana': 'IS',
#  'CassataPaolo': 'SMWLV',
#  'CatelanMarcio': 'SMWLV',
#  'CavuotiStefano': 'IS',
#  'CenkoStephen': 'TVS',
#  'ChambaNushkia': 'DESC',
#  'ChanameJulio': 'SMWLV',
#  'ChangChihway': 'SMWLV',
#  'ChartasGeorge': 'DESC',
#  'ChenXuelei': 'SMWLV',
#  'ChenYen-Chi': 'SMWLV',
#  'ChernoffDavid': 'SMWLV',
#  'ChesleySteve': 'SMWLV',
#  'CheuElliott': 'SMWLV',
#  'ChiangJim': 'TVS',
#  'ChiniRolf': 'DESC',
#  'ChisariElisa': 'SMWLV',
#  'ChomiukLaura': 'SMWLV',
#  'ChornockRyan': 'Galaxies',
#  'ChristensenEric': 'SMWLV',
#  'ChuYou-Hua': 'SMWLV',
#  'CiardiDavid': 'TVS',
#  'CiconeClaudia': 'TVS',
#  'CiezaLucas': 'Galaxies',
#  'CignoniMichele': 'SMWLV',
#  'CioniMaria-Rosa': 'SMWLV',
#  'CisewskiJessi': 'DESC',
#  'ClarksonWilliam': 'SL',
#  'ClaverChuck': 'AGN',
#  'ClaytonGeoffrey': 'IS',
#  'ClementiniGisella': 'TVS',
#  'CloweDouglas': 'IS',
#  'Cohen-TanugiJohann': 'SS',
#  'CohnJoanne': 'DESC',
#  'CollettThomas': 'TVS',
#  'CombetCeline': 'DESC',
#  'ConnollyAndrew': 'TVS',
#  'ConseliceChris': 'SMWLV',
#  'ContrerasHantkeSergio': 'SMWLV',
#  'CookKem': 'TVS',
#  'CooperMichael': 'SMWLV',
#  'CoorayAsantha': 'AGN',
#  'CoppejansDeanne': 'TVS',
#  'CoppiPaoloSevero': 'SMWLV',
#  'CordesJim': 'SMWLV',
#  'CoughlinMichael': 'IS',
#  'CoveyKevin': 'SMWLV',
#  'CowanNick': 'DESC',
#  'CuadraJorge': 'SMWLV',
#  'CucchiaraAntonino': 'SMWLV',
#  'CuiWei': 'TVS',
#  'CukMatija': 'TVS',
#  'CusanoFelice': 'DESC',
#  'Cyr-RacineFrancis-Yan': 'TVS',
#  'CzernyBozena': 'DESC',
#  "D'AmmandoFilippo": 'DESC',
#  "D'AndreaChris": 'DESC',
#  "D'AvanzoPaolo": 'DESC',
#  'DagoretSylvie': 'DESC',
#  'DalPonteMarina': 'SS',
#  "Dall'OraMassimo": 'Galaxies',
#  'DanielScott': 'SMWLV',
#  'DavenportJames': 'SMWLV',
#  'DaviesJon': 'Galaxies',
#  'DaviesLuke': 'TVS',
#  'DaviesRoger': 'SS',
#  'DavisChristopher': 'SS',
#  'DawsonWilliam': 'TVS',
#  'DeCiccoDemetra': 'IS',
#  'DeLeeNathan': 'SMWLV',
#  'DeMarcoOrsola': 'SMWLV',
#  'DeMeoFrancesca': 'SL',
#  'DeasonAlis': 'AGN',
#  'DebattistaVictor': 'TVS',
#  'DellAntonioIan': 'SS',
#  'DemarcoRicardo': 'TVS',
#  'DenneauLarry': 'AGN',
#  'DevriendtJulien': 'TVS',
#  'DexterJason': 'TVS',
#  'DhitalSaurav': 'TVS',
#  'DiStefanoRosanne': 'SMWLV',
#  'DiazTanio': 'SS',
#  'DickinsonMark': 'DESC',
#  'DigelSeth': 'SMWLV',
#  'DjorgovskiGeorge': 'SMWLV',
#  'DoblerGreg': 'TVS',
#  'DoctorZoheyr': 'DESC',
#  'DodelsonScott': 'SMWLV',
#  'DonachieMartin': 'SMWLV',
#  'DonesLuke': 'Galaxies',
#  'DoreOlivier': 'Galaxies',
#  'DotterAaron': 'Galaxies',
#  'DrakeJeremy': 'DESC',
#  'DriverSimon': 'DESC',
#  'Drlica-WagnerAlex': 'SMWLV',
#  'DroutMaria': 'SMWLV',
#  'DuboisRichard': 'Galaxies',
#  'DunkleyJo': 'SMWLV',
#  'DurechJosef': 'SMWLV',
#  'EgglSiegfried': 'SMWLV',
#  'EiflerTim': 'SMWLV',
#  'EliasJonathan': 'TVS',
#  'EliasdottirArdis': 'SS',
#  'ElsnerFranz': 'AGN',
#  'ElvisMartin': 'SMWLV',
#  'EracleousMike': 'SMWLV',
#  'EscalaAndres': 'TVS',
#  'EscarateMonettaPedroAntonio': 'SMWLV',
#  'EyheramendySusana': 'SMWLV',
#  'FabrizioMichele': 'DESC',
#  'FadelyRoss': 'Galaxies',
#  'FalcoEmilio': 'SS',
#  'FanXiaohui': 'SS',
#  'FarihiJay': 'Galaxies',
#  'FarnocchiaDavide': 'SL',
#  'FassnachtChris': 'SMWLV',
#  'FeigelsonEric': 'Galaxies',
#  'FeinsteinFabrice': 'Galaxies',
#  'FergusonAnnette': 'DESC',
#  'FergusonHenry': 'SMWLV',
#  'FerreiraPedro': 'TVS',
#  'FinchCharlie': 'IS',
#  'FinkelsteinSteven': 'SL',
#  'FinleyDavid': 'TVS',
#  'FiorentinoGiuliana': 'DESC',
#  'Fisher-LevineMerlin': 'SS',
#  'FitzsimmonsAlan': 'DESC',
#  'FongMatthew': 'SMWLV',
#  'FongWen-fai': 'SMWLV',
#  'FouchezDominique': 'TVS',
#  'FoxDerek': 'Galaxies',
#  'FoxOri': 'SMWLV',
#  'FrankJuhan': 'SMWLV',
#  'FraserWesley': 'TVS',
#  'FreemanPeter': 'DESC',
#  'FreyLucille': 'DESC',
#  'FryeBrenda': 'SS',
#  'FryerChris': 'TVS',
#  'FuentesCesar': 'SL',
#  'GalazGaspar': 'DESC',
#  'GalbanyLluis': 'SS',
#  'GandhiPoshak': 'AGN',
#  'GanglerEmmanuel': 'IS',
#  'GarofaloAlessia': 'IS',
#  'GawiserEric': 'TVS',
#  'GehaMarla': 'SL',
#  'GeislerDoug': 'AGN',
#  'GellerAaron': 'SMWLV',
#  'GenoveseChristopher': 'SS',
#  'GerdesDavid': 'DESC',
#  'GezariSuvi': 'SL',
#  'GhirlandaGiancarlo': 'IS',
#  'GianninasAlexandros': 'DESC',
#  'GianniniTeresa': 'Galaxies',
#  'GibbsAlex': 'SMWLV',
#  'GibsonRob': 'SMWLV',
#  'GilmanFred': 'Galaxies',
#  'GilmoreKirk': 'DESC',
#  'GirardTerrence': 'SMWLV',
#  'GirardiLeo': 'Galaxies',
#  'GizisJohn': 'DESC',
#  'GlanzmanTom': 'TVS',
#  'GlazebrookKarl': 'SMWLV',
#  'GoldsteinDaniel': 'DESC',
#  'GombocAndreja': 'DESC',
#  'GomezMatias': 'TVS',
#  'GrahamMatthew': 'DESC',
#  'GrahamMelissa': 'TVS',
#  'GranvikMikael': 'TVS',
#  'GrapsAmara': 'TVS',
#  'GraurOr': 'SS',
#  'GrayAlexander': 'IS',
#  'GrazianAndrea': 'TVS',
#  'GrazianiCarlo': 'SL',
#  'GrecoJohnny': 'SMWLV',
#  'GreenRichard': 'SMWLV',
#  'GreenstreetSarah': 'TVS',
#  'GreggioLaura': 'SS',
#  'GrillmairCarl': 'Galaxies',
#  'GrindlayJosh': 'TVS',
#  'GrisPhilippe': 'DESC',
#  'GschwendJulia': 'TVS',
#  'GuhathakurtaPuragra': 'DESC',
#  'GuillochonJames': 'TVS',
#  'GuyonnetAugustin': 'DESC',
#  'HabibSalman': 'Galaxies',
#  'HaimanZoltan': 'SMWLV',
#  'HakkilaJon': 'SMWLV',
#  'HambletonKelly': 'SMWLV',
#  'HammergrenMark': 'SMWLV',
#  'HargisJonathan': 'TVS',
#  'HarrisAl': 'IS',
#  'HartiganPatrick': 'SS',
#  'HartleyWilliam': 'TVS',
#  'HathiNimish': 'TVS',
#  'HawleySuzanne': 'SMWLV',
#  'HearinAndrew': 'TVS',
#  'HebbLeslie': 'SS',
#  'HeeCharlotte': 'DESC',
#  'HeitmannKatrin': 'DESC',
#  'HelouGeorge': 'Galaxies',
#  'HendenArne': 'SMWLV',
#  'HendlerNathanial': 'SMWLV',
#  'HenryTodd': 'SMWLV',
#  'HerXiachang': 'SMWLV',
#  'HerstrofferDaniel': 'SMWLV',
#  'HiltonEric': 'SMWLV',
#  'HlozekRenee': 'DESC',
#  'HoShirley': 'SL',
#  'HoenigSebastian': 'Galaxies',
#  'HolbergJayB.': 'SL',
#  'HollerBryan': 'SL',
#  'HolmanMatthew': 'TVS',
#  'HolwerdaBenne': 'SMWLV',
#  'HolzDaniel': 'SMWLV',
#  'HowellSteve': 'IS',
#  'HsiehHenry': 'TVS',
#  'HuberMark': 'SS',
#  'HundertmarkMarkus': 'SS',
#  'InfanteLeopoldo': 'TVS',
#  'InnesWalter': 'IS',
#  'InnoLaura': 'AGN',
#  'InserraCosimo': 'Galaxies',
#  'IrwinJohn': 'IS',
#  'IshakMustapha': 'Galaxies',
#  'IshidaEmille': 'AGN',
#  'Itam-PasquetJohanna': 'SS',
#  'IvansInese': 'TVS',
#  'IvezicZeljko': 'SMWLV',
#  'JacklinSavannah': 'TVS',
#  'JacksonRyan': 'DESC',
#  'JaffeAndrew': 'IS',
#  'JainBhuvnesh': 'TVS',
#  'JaoWei-Chun': 'IS',
#  'JarvisMatt': 'TVS',
#  'JarvisMike': 'SS',
#  'JedickeRobert': 'SMWLV',
#  'JeeJames': 'SS',
#  'JenningsElise': 'Galaxies',
#  'JerniganGarrett': 'Galaxies',
#  'JevremovicDarko': 'SMWLV',
#  'JhaSaurabh': 'SMWLV',
#  'JiInchan': 'DESC',
#  'JiangYan-Fei': 'TVS',
#  'JoachimiBenjamin': 'SMWLV',
#  'Johns-KrullChristopher': 'SMWLV',
#  'JohnsonAnthony': 'DESC',
#  'JohnsonChristian': 'SS',
#  'JohnsonMichael': 'DESC',
#  'JohnstonKathryn': 'TVS',
#  'JonesLynne': 'SS',
#  'JordanAndres': 'AGN',
#  'JuricMario': 'SMWLV',
#  'KaasalAinenMikko': 'SMWLV',
#  'KafkaStella': 'SS',
#  'KahnSteven': 'SS',
#  'KaibNathan': 'TVS',
#  'KaliraiJason': 'TVS',
#  'KallivayalilNityaJacob': 'SS',
#  'KalmbachBryce': 'TVS',
#  'KalogeraVicky': 'TVS',
#  'KamathSowmya': 'Galaxies',
#  'KanburShashi': 'DESC',
#  'KaplanDavid': 'SMWLV',
#  'KartaltepeJeyhan': 'SMWLV',
#  'KashyapVinayL.': 'TVS',
#  'KasliwalMansi': 'DESC',
#  'KasliwalVishal': 'SL',
#  'KavirajSugata': 'DESC',
#  'KeetonCharles': 'DESC',
#  'KelleyMichael': 'SMWLV',
#  'KelvinLee': 'SMWLV',
#  'KentStephen': 'Galaxies',
#  'KerinsEamonn': 'IS',
#  'KhakpashSomayeh': 'AGN',
#  'KiesslingAlina': 'SS',
#  'KilicMukremin': 'SL',
#  'KimAlex': 'SMWLV',
#  'KimPeter': 'TVS',
#  'KimballAmy': 'SMWLV',
#  'KirbyEvan': 'DESC',
#  'KirkbyDavid': 'IS',
#  'KirkpatrickDavy': 'TVS',
#  'KnapenJohan': 'Galaxies',
#  'KnezevicZoran': 'IS',
#  'KnightMatthew': 'DESC',
#  'KnuthKevin': 'SMWLV',
#  'KoposovSergey': 'SMWLV',
#  'KovacsEve': 'Galaxies',
#  'KowalskiAdam': 'DESC',
#  'KrauseElisabeth': 'AGN',
#  'KrughoffKarl': 'SS',
#  'KrughoffSimon': 'DESC',
#  'KuhlmannSteve': 'IS',
#  'KulierAndrea': 'SL',
#  'KulkarniShri': 'TVS',
#  'KuncarayaktiHanindyo': 'DESC',
#  'KunderAndrea': 'TVS',
#  'KurczynskiPeter': 'Galaxies',
#  'KurtevRadostin': 'AGN',
#  'LacernaIvan': 'DESC',
#  'LacyMark': 'TVS',
#  'LageCraig': 'DESC',
#  'LahavOfer': 'TVS',
#  'LandoniMarco': 'SMWLV',
#  'LangDustin': 'SMWLV',
#  'LarsenJeffreyArthur': 'SMWLV',
#  'LarsenPatricia': 'SMWLV',
#  'LauroeschJames': 'TVS',
#  'LawrenceAndy': 'Galaxies',
#  'LeBretonRemy': 'DESC',
#  'LeGuillouLaurent': 'SS',
#  'LeeAnn': 'IS',
#  'LeeChien-Hsiu': 'SL',
#  'LegetPierre-Francois': 'SMWLV',
#  'LeistedtBoris': 'SMWLV',
#  'LeonardDanielle': 'SMWLV',
#  'LepineSebastien': 'SMWLV',
#  'LevanAndrew': 'IS',
#  'LiGongjie': 'DESC',
#  'LimKian-Tat': 'SS',
#  'LinHsing-Wen(Edward)': 'SMWLV',
#  'LinHuan': 'SMWLV',
#  'LinWeikang': 'TVS',
#  'LinderEric': 'DESC',
#  'LintottChris': 'SS',
#  'LiodakisYannis': 'SMWLV',
#  'LiraPaulina': 'SMWLV',
#  'ListerTim': 'SMWLV',
#  'LiuBinyang': 'DESC',
#  'LiuMichael': 'SMWLV',
#  'LochnerMichelle': 'TVS',
#  'LoebmanSarah': 'DESC',
#  'LongJames': 'TVS',
#  'LongKnoxS.': 'TVS',
#  'LopezSebastian': 'Galaxies',
#  'LoredoTom': 'IS',
#  'LotzJennifer': 'Galaxies',
#  'LoucksMike': 'TVS',
#  'LovedayJon': 'Galaxies',
#  'LubinLori': 'SL',
#  'LucasPhilip': 'SS',
#  'LuhmanKevin': 'Galaxies',
#  'LundMichael': 'DESC',
#  'LunnanRagnhild': 'TVS',
#  'LuptonRobert': 'TVS',
#  'LuqueElmer': 'SMWLV',
#  'LurieJohn': 'SMWLV',
#  'LutzJulie': 'SL',
#  'MacLeodChelsea': 'AGN',
#  'MaccaroneThomas': 'DESC',
#  'MacriLucas': 'SMWLV',
#  'MadejskiGreg(Grzegorz)': 'DESC',
#  'MagriniLaura': 'SMWLV',
#  'MaguireKate': 'SMWLV',
#  'MagurnoDavide': 'Galaxies',
#  'MahabalAshish': 'SS',
#  'MainettiDeborah': 'TVS',
#  'MalhotraRenu': 'DESC',
#  'MalzAlex': 'TVS',
#  'ManconeConorL.': 'DESC',
#  'MandelKaisey': 'DESC',
#  'MandelbaumRachel': 'IS',
#  'MantzAdam': 'TVS',
#  'MaoYao-Yuan': 'DESC',
#  'MarconiMarcella': 'Galaxies',
#  'MargoninerVera': 'TVS',
#  'MarguttiRaffaella': 'SMWLV',
#  'MarinoAlessio': 'SMWLV',
#  'MarinoniSilvia': 'TVS',
#  'MarshallJennifer': 'AGN',
#  'MarshallPhil': 'SMWLV',
#  'Martanez-LombillaCristina': 'AGN',
#  'MartinGarreth': 'Galaxies',
#  'Martinez-GalarzaRafael': 'SS',
#  'MasonElena': 'DESC',
#  'MastersKaren': 'SMWLV',
#  'MathesonTom': 'SMWLV',
#  'MaundJustyn': 'AGN',
#  'MaureiraJuanCarlos': 'DESC',
#  'MauroFrancesco': 'DESC',
#  'MauronNicolas': 'SL',
#  'MayMorgan': 'IS',
#  'McClintockThomas': 'DESC',
#  'McCollumBruce': 'DESC',
#  'McEwenJason': 'DESC',
#  'McGeheePeregrine': 'SMWLV',
#  'McGreerIan': 'TVS',
#  'McMahonRichard': 'SS',
#  'MelandriAndrea': 'IS',
#  'MenardBrice': 'DESC',
#  'MennickentRonald': 'SS',
#  'MercurioAmata': 'DESC',
#  'MerlinEmiliano': 'Galaxies',
#  'MeurerGerhardt': 'AGN',
#  'MeyerDavid': 'AGN',
#  'MeyersJoshua': 'SS',
#  'MezaAndres': 'SMWLV',
#  'MilaniAndrea': 'SMWLV',
#  'MilisavljevicDanny': 'DESC',
#  'MillerAdam': 'DESC',
#  'MillerBryan': 'SMWLV',
#  'MillerChris': 'IS',
#  'MinnitiDante': 'TVS',
#  'ModjazMaryam': 'SL',
#  'MoeyensJoachim': 'IS',
#  'MommertMichael': 'Galaxies',
#  'MonacoLorenzo': 'SS',
#  'MonetDavid': 'Galaxies',
#  'MoniezMarc': 'Galaxies',
#  'MorettiAlberto': 'SMWLV',
#  'MorettiMariaIda': 'SMWLV',
#  'MorrisDave': 'TVS',
#  'MorrisGlenn': 'TVS',
#  'MorrisonChristopher': 'Galaxies',
#  'MortlockDaniel': 'DESC',
#  'MoskovitzNicholas': 'SMWLV',
#  'MottaVeronica': 'SMWLV',
#  'MuellerBeatrice': 'SMWLV',
#  'MukadamAnjum': 'SMWLV',
#  'MundellCarole': 'SMWLV',
#  'MunozRicardo': 'SMWLV',
#  'MunozRobertoPablo': 'AGN',
#  'MunozarArancibiaAlejandra': 'TVS',
#  'MuravevaTatiana': 'SMWLV',
#  'MurgiaSimona': 'SMWLV',
#  'MusellaIlaria': 'AGN',
#  'NaiduShantanu': 'SMWLV',
#  'NantaisJulieBeth': 'TVS',
#  'NapolitanoNicola': 'SMWLV',
#  'NarayanGautham': 'TVS',
#  'NaylorTim': 'IS',
#  'NeilsenEric': 'TVS',
#  'NeveuJeremy': 'TVS',
#  'NewmanJeffrey': 'SS',
#  'NeyrinckMark': 'IS',
#  'NiQingling': 'DESC',
#  'NicholBob': 'DESC',
#  'NiederhoferFlorian': 'TVS',
#  'NierenbergAnna': 'SMWLV',
#  'NightingaleJames': 'SMWLV',
#  'NikolaevSergei': 'Galaxies',
#  'NissankeSamaya': 'TVS',
#  'NomerotskiAndrei': 'TVS',
#  'NormanDara': 'TVS',
#  'NugentPeter': 'AGN',
#  'NussEric': 'IS',
#  "O'ConnorPaul": 'SMWLV',
#  'ObricMirela': 'SMWLV',
#  'OfekEranO.': 'Galaxies',
#  'OgandoRicardo': 'SL',
#  'OguriMasamune': 'Galaxies',
#  'OjalaElle': 'Galaxies',
#  'OlivierScot': 'TVS',
#  'OlkinCatherine': 'TVS',
#  'OlsenKnut': 'Galaxies',
#  'OlszewskiEdward': 'TVS',
#  'OluseyiHakeem': 'IS',
#  'PadillaNelson': 'IS',
#  'PageGary': 'TVS',
#  'PandaSwayamtrupta': 'DESC',
#  'PankowChris': 'DESC',
#  'PapovichCasey': 'IS',
#  'ParkHyeYun': 'IS',
#  'ParkerAlex': 'DESC',
#  'ParrentJerod': 'SMWLV',
#  'ParsonsSteven': 'SMWLV',
#  'PastorelloAndrea': 'AGN',
#  'PayneMatthew': 'AGN',
#  'PedersenEske': 'TVS',
#  'PeirisHiranya': 'DESC',
#  'Penna-LimaMariana': 'TVS',
#  'PepperJoshua': 'SMWLV',
#  'PerlmutterSaul': 'Galaxies',
#  'PerrefortDaniel': 'Galaxies',
#  'PesensonMisha': 'SMWLV',
#  'PetersChristina': 'SMWLV',
#  'PetersonJohn': 'SMWLV',
#  'PetitJean-Marc': 'SMWLV',
#  'PetryCathy': 'SS',
#  'PieresAdriano': 'TVS',
#  'PignataGiuliano': 'TVS',
#  'PiranomonteSilvia': 'Galaxies',
#  'PironFrederic': 'TVS',
#  'PlavchanPeter': 'IS',
#  'PlazasAndres': 'SMWLV',
#  'PonderKara': 'TVS',
#  'PopeAdrian': 'SS',
#  'PopovicLuka': 'SS',
#  'PowerChris': 'SMWLV',
#  'PrisinzanoLoredana': 'SMWLV',
#  'ProtopapasPavlos': 'SMWLV',
#  'ProuzaMichael': 'SMWLV',
#  'PrsaAndrej': 'DESC',
#  'PtakAndrew': 'AGN',
#  'PuckettAndy': 'AGN',
#  'PuziaThomas': 'TVS',
#  'QuataertEliot': 'DESC',
#  'QuinnTom': 'DESC',
#  'RabusMarkus': 'IS',
#  'RagozzineDarin': 'SS',
#  'RahmanMubdi': 'SL',
#  'RaiteriClaudiaM.': 'SS',
#  'RajMariaAngela': 'SMWLV',
#  'RajagopalJayadev': 'SMWLV',
#  'RamirezAmelia': 'TVS',
#  'RasmussenAndrew': 'AGN',
#  'RasmussenAndy': 'SMWLV',
#  'RattenburyNicholas': 'SMWLV',
#  'RauArne': 'IS',
#  'ReachWilliam': 'IS',
#  'RebbapragadaUmaa': 'TVS',
#  'ReddyNaveen': 'SMWLV',
#  'RegnaultNicolas': 'SMWLV',
#  'ReilKevin': 'TVS',
#  'ReissDavid': 'SS',
#  'RestArmin': 'Galaxies',
#  'RhoadsJamesE.': 'Galaxies',
#  'RhodesJason': 'SL',
#  'RichR.Michael': 'TVS',
#  'RichardsGordon': 'DESC',
#  'RichardsJoseph': 'SMWLV',
#  'RichardsMercedes': 'SMWLV',
#  'RichterMatt': 'DESC',
#  'RickerPaul': 'AGN',
#  'RicolJean-Stephane': 'Galaxies',
#  'RidgwayStephen': 'DESC',
#  'RiedelAdric': 'DESC',
#  'RighiChiara': 'AGN',
#  'RitzSteve': 'IS',
#  'RivkinAndy': 'TVS',
#  'RobertsonBrant': 'SMWLV',
#  'RobothamAaron': 'SMWLV',
#  'RockosiConstance': 'SL',
#  'RodriguezJoseph': 'SL',
#  'RojoPatricio': 'SMWLV',
#  'RomanAlexandre': 'SMWLV',
#  'RomaniRoger': 'DESC',
#  'RoncarelliMauro': 'Galaxies',
#  'RoodmanAaron': 'TVS',
#  'RosingWayne': 'DESC',
#  'RossiGustavoBenedetti': 'DESC',
#  'RoucelleCecile': 'Galaxies',
#  'RozoEduardo': 'TVS',
#  'RunnoeJessie': 'Galaxies',
#  'RuppertDavid': 'SL',
#  'RutkowskiMichael': 'TVS',
#  'RykoffEli': 'DESC',
#  'SaccoGiuseppe': 'SS',
#  'SahaAbi': 'SMWLV',
#  'SaintongeAmelie': 'SMWLV',
#  'SaitoRoberto': 'SMWLV',
#  'SakoMasao': 'TVS',
#  'SalafiaOmSharan': 'SS',
#  'SalimSamir': 'AGN',
#  'SamarasinhaNalin': 'TVS',
#  'SanchezJavier': 'Galaxies',
#  'SantiagoBasilio': 'DESC',
#  'SarajediniAta': 'SS',
#  'SaridGal': 'TVS',
#  'SasselovDimitar': 'SMWLV',
#  'ScargleJeffrey': 'SMWLV',
#  'SchaferChad': 'TVS',
#  'SchambeauCharles': 'SS',
#  'SchechterPaul': 'DESC',
#  'SchindlerJan-Torge': 'DESC',
#  'SchmidtEdward': 'SMWLV',
#  'SchmidtSam': 'SMWLV',
#  'SchmidtSamuel': 'DESC',
#  'SchneiderDon': 'IS',
#  'SchneiderMichael': 'DESC',
#  'SchwambMeg': 'DESC',
#  'ScowenPaul': 'IS',
#  'ScrantonRyan': 'DESC',
#  'ScudderJillian': 'AGN',
#  'SeamanRob': 'DESC',
#  'SeljakUros': 'SMWLV',
#  'SembroskiGlenn': 'SMWLV',
#  'SerenoMauro': 'IS',
#  'SesarBranimir': 'TVS',
#  'SethAnil': 'TVS',
#  'ShafterAllenW.': 'TVS',
#  'ShamirLior': 'SMWLV',
#  'SheldonErin': 'SMWLV',
#  'ShemmerOhad': 'DESC',
#  'ShenKen': 'DESC',
#  'SheppardScott': 'DESC',
#  'ShipseyIan': 'AGN',
#  'ShirleyRaphael': 'Galaxies',
#  'ShporerAvi': 'SMWLV',
#  'SickJonathan': 'SMWLV',
#  'SiemiginowskaAneta': 'Galaxies',
#  'SilvaDavid': 'SS',
#  'SilvestriNicole': 'Galaxies',
#  'SimetMelanie': 'SS',
#  'SimonJoshuaD.': 'TVS',
#  'SingerLeo': 'SS',
#  'SlaterColin': 'DESC',
#  'SlosarAnze': 'TVS',
#  'SmarttStephen': 'TVS',
#  'SmithChris': 'DESC',
#  'SmithGraham': 'TVS',
#  'SmithHoward': 'TVS',
#  'SmithJ.Allyn': 'SS',
#  'SmithKen': 'IS',
#  'SmithNathan': 'DESC',
#  'SmothermanHayden': 'TVS',
#  'SnodgrassColin': 'TVS',
#  'SnyderGreg': 'DESC',
#  'SobeckJennifer': 'SMWLV',
#  'SolarzAleksandra': 'SMWLV',
#  'SolontoiMike': 'TVS',
#  'SonnefeldAlessandro': 'IS',
#  'SoraisamMonika': 'AGN',
#  'SordoRosanna': 'SS',
#  'SpergelDavid': 'DESC',
#  'SpitzAnna': 'SS',
#  'StanfordAdam': 'TVS',
#  'StassunKeivan': 'SMWLV',
#  'SteckloffJordan': 'DESC',
#  'SteeghsDanny': 'SS',
#  'SteenbruggeKatrien': 'Galaxies',
#  'SternAlan': 'Galaxies',
#  'StottJohn': 'SMWLV',
#  'StraderJay': 'SMWLV',
#  'StrattaGiulia': 'TVS',
#  'StraussMichael': 'SMWLV',
#  'StreetRachel': 'DESC',
#  'StuartScott': 'AGN',
#  'StubbsChristopher': 'IS',
#  'SubasavageJohn': 'DESC',
#  'SullivanMark': 'SMWLV',
#  'SzaboRobert': 'TVS',
#  'SzkodyPaula': 'SMWLV',
#  'TakHyungsuk': 'SMWLV',
#  'TamayoDaniel': 'Galaxies',
#  'TaranuDan': 'TVS',
#  'TejosNicolas': 'DESC',
#  'TheilerJamesP.': 'TVS',
#  'ThirouinAudrey': 'SS',
#  'ThomasCristina': 'TVS',
#  'ThormanPaul': 'Galaxies',
#  'ThorstensenJohnRobert': 'SS',
#  'TisseraPatricia': 'DESC',
#  'TreisterEzequiel': 'SMWLV',
#  'TreuTommaso': 'SMWLV',
#  'TrillingDavid': 'SMWLV',
#  'TrimbleVirginia': 'SS',
#  'TrouilleLaura': 'TVS',
#  'TroxelMichael': 'IS',
#  'TrujilloChad': 'IS',
#  'TrujilloIgnacio': 'SS',
#  'TsaprasYiannis': 'SL',
#  'TsybychevDmitri': 'AGN',
#  'TysonTony': 'DESC',
#  'UrryMeg': 'Galaxies',
#  'ValentiStefano': 'AGN',
#  'VallenariAntonella': 'DESC',
#  'VandenBerkDan': 'SS',
#  'VenutiLaura': 'TVS',
#  'VeresPeter': 'Galaxies',
#  'VermaAprajita': 'Galaxies',
#  'VestrandTom': 'TVS',
#  'VianelloGiacomo': 'SS',
#  'VieiraJoaquin': 'DESC',
#  'VilaltaRicardo': 'DESC',
#  'VillarVictoriaAshley': 'Galaxies',
#  'VillarrealAntonio': 'SMWLV',
#  'VinkJorick': 'SMWLV',
#  'VivasKathy': 'AGN',
#  'VogeleyMichael': 'TVS',
#  'VolkKat': 'IS',
#  'VonDerLindenAnja': 'DESC',
#  'VrastilMichal': 'TVS',
#  'WainscoatRichard': 'SS',
#  'WalkerAlistair': 'DESC',
#  'WalkowiczLucianne': 'Galaxies',
#  'WallersteinGeorge': 'IS',
#  'WallinJohn': 'AGN',
#  'WalterChris': 'SL',
#  'WaltonNicholas': 'IS',
#  'WangYun': 'SMWLV',
#  'WassermanLarry': 'SMWLV',
#  'WeatherillDaniel': 'TVS',
#  'WebsterRachel': 'SMWLV',
#  'WechslerRisa': 'SMWLV',
#  'WeinbergMartin': 'SMWLV',
#  'WeinerBen': 'SMWLV',
#  'WellsMark': 'TVS',
#  'WenausTorre': 'Galaxies',
#  'WernerNorbert': 'SMWLV',
#  'WestAndrew': 'SMWLV',
#  'WiesnerMatthew': 'TVS',
#  'WildVivienne': 'AGN',
#  'WilliamsBen': 'SL',
#  'WilliamsRobert': 'DESC',
#  'WilligerGerard': 'TVS',
#  'WillmanBeth': 'SMWLV',
#  'WittmanDavid': 'SMWLV',
#  'WolpertRobert': 'Galaxies',
#  'WomackMaria': 'TVS',
#  'Wood-VaseyMichael': 'TVS',
#  'WoodroofeMichael': 'SS',
#  'WozniakPrzemek': 'Galaxies',
#  'Yanamandra-FisherPadma': 'SMWLV',
#  'YangGuang': 'SMWLV',
#  'YangSheng': 'IS',
#  'YeQuan-Zhi': 'SS',
#  'YoachimPeter': 'SL',
#  'YoungDavid': 'SMWLV',
#  'YoungLeslie': 'SMWLV',
#  'YuWeixiang': 'SMWLV',
#  'ZabludoffAnn': 'SMWLV',
#  'ZaudererAshley': 'DESC',
#  'ZehaviIdit': 'SS',
#  'ZentnerAndrew': 'Galaxies',
#  'ZhanHu': 'SS',
#  'ZhaoGong-Bo': 'TVS',
#  'ZhengZhenia': 'AGN',
#  'ZoccaliManuela': 'SS',
#  'ZolotovAdi': 'Galaxies',
#  'ZuntzJoe': 'SMWLV',
#  'daCostaLuiz': 'Galaxies',
#  'deAndradeQueirozAnnaBarbara': 'AGN',
#  'deJongRoelof': 'DESC',
#  'deVal-BorroMiguel': 'TVS',
#  'deVriesWim': 'TVS'}

# %%
countrylabel
# Out:
# {'AbdullaGhaleb': 'US',
#  'AbellPaulAlexander': 'US',
#  'AgolEric': 'US',
#  'AguenaMichel': 'BR',
#  'AguerosMarcel': 'US',
#  'AkhlaghiMohammad': 'ES',
#  'AlderingGreg': 'US',
#  'AllenMark': 'US',
#  'AllenSteven': 'US',
#  'AlmeydaTriana': 'UK',
#  'Alonso-GarciaJavier': 'CL',
#  'AlonsoDavid': 'UK',
#  'AnderesEthan': 'US',
#  'AndersonScott': 'US',
#  'AnguitaTimo': 'CL',
#  'AnsariReza': 'FR',
#  'AntilogusPierre': 'FR',
#  'AntoniucciSimone': 'IT',
#  'AravenaManuel': 'CL',
#  'ArcaviIair': 'IS',
#  'ArdilaDavid': 'US',
#  'ArgudoFernandezMariadelCarmen': 'CL',
#  'ArmusLee': 'US',
#  'ArnettW.David': 'US',
#  'AssefRoberto': 'CL',
#  'AstierPierre': 'FR',
#  'AubourgEric': 'FR',
#  'AvestruzCamille': 'US',
#  'AwanHumna': 'US',
#  'AyeMichael': 'US',
#  'BabuJogesh': 'US',
#  'BaileyStephen': 'US',
#  'BailynCharles': 'US',
#  'BallandChristophe': 'FR',
#  'BallantyneDavid': 'US',
#  'BalmaverdeBarbara': 'IT',
#  'BaloghMichael': 'CA',
#  'BaltzTed': 'US',
#  'BandaMartin': 'BR',
#  'BanerjiManda': 'UK',
#  'BannisterMichele': 'UK',
#  'BarbaRodolfo': 'CL',
#  'BarbieriMauro': 'CL',
#  'BardDeborah': 'US',
#  'BarrauAurelien': 'FR',
#  'BarreraLuis': 'CL',
#  'BarrientosFelipe': 'CL',
#  'BarthAaron': 'US',
#  'BartlettJames': 'FR',
#  'BassGideon': 'US',
#  'BauerFranz': 'CL',
#  'BaumerMichael': 'US',
#  'BeanRachel': 'US',
#  'BechtolKeith': 'US',
#  'BeckerAndrew': 'US',
#  'BeclaJacek': 'US',
#  'BeersTimothyC.': 'US',
#  'BellEric': 'US',
#  'BellKeaton': 'US',
#  'BellagambaFabio': 'IT',
#  'BellmEric': 'US',
#  'BelokurovVasily': 'UK',
#  'BergerEdo': 'US',
#  'BernsteinGary': 'US',
#  'BersierDavid': 'UK',
#  'BetouleMarc': 'FR',
#  'BiancoFederica': 'US',
#  'BianconiMatteo': 'UK',
#  'BiswasRahul': 'SW',
#  'BivianoAndrea': 'IT',
#  'BlancGuillaume': 'FR',
#  'BlandfordRoger': 'US',
#  'BlantonMichaelRogers': 'US',
#  'BlazekJonathan': 'US',
#  'BloomJosh': 'US',
#  'BlumBob': 'US',
#  'BochanskiJohn': 'US',
#  'BodewitsDennis': 'US',
#  'BoeshaarPatricia': 'US',
#  'BolinBryce': 'oth',
#  'BondHoward': 'US',
#  'BongardSebastien': 'FR',
#  'BonitoRosaria': 'IT',
#  'BonoGiuseppe': 'IT',
#  'BoquienMederic': 'CL',
#  'BorglandAnders': 'US',
#  'BorneKirk': 'oth',
#  'BorosonTodd': 'US',
#  'BoschJames': 'US',
#  'BoschJim': 'US',
#  'BoseMaitrayee': 'US',
#  'BoshAmanda': 'US',
#  'BotticellaMariaTeresa': 'IT',
#  'BoutignyDominique': 'FR',
#  'BowlerRebecca': 'UK',
#  'BradacMarusa': 'US',
#  'BradshawAndrew': 'US',
#  'BrandtNiel': 'US',
#  'BremerMalcolm': 'UK',
#  'BridgeCarrie': 'US',
#  'BridleSarah': 'US',
#  'BrittChristopher': 'US',
#  'BrocatoEnzo': 'IT',
#  'BrothertonMichael': 'US',
#  'BroughSarah': 'AU',
#  'BrownMichael': 'US',
#  'BrownPeter': 'US',
#  'BrownTim': 'US',
#  'BrozovicMarina': 'US',
#  'BrunnerRobert': 'US',
#  'BudavariTamas': 'US',
#  'BuenodeCamargoJulioIgnacio': 'BR',
#  'BuieMarc': 'US',
#  'BullPhilip': 'oth',
#  'BullockJames': 'US',
#  'BurchatPatricia': 'US',
#  'BurgasserAdam': 'US',
#  'BurkeDavid': 'US',
#  'BurkeDouglas': 'US',
#  'BurninghamBen': 'oth',
#  'ButlerNathaniel': 'US',
#  'CabreraGuillermo': 'CL',
#  'CaiYongzhi': 'IT',
#  'CalabreseErminia': 'UK',
#  'CalamidaAnnalisa': 'US',
#  'CampagneJean-Eric': 'FR',
#  'Cantat-GaudinTristan': 'IT',
#  'CargilePhillip': 'US',
#  'CariniRoberta': 'IT',
#  'CarlinJeff': 'US',
#  'CarnereroMartinMariaIsabel': 'IT',
#  'Carrasco-KindMatias': 'US',
#  'CasettiDanaIoana': 'US',
#  'CassataPaolo': 'oth',
#  'CatelanMarcio': 'CL',
#  'CavuotiStefano': 'oth',
#  'CenkoStephen': 'US',
#  'ChambaNushkia': 'ES',
#  'ChanameJulio': 'CL',
#  'ChangChihway': 'US',
#  'ChartasGeorge': 'US',
#  'ChenXuelei': 'CN',
#  'ChenYen-Chi': 'US',
#  'ChernoffDavid': 'US',
#  'ChesleySteve': 'US',
#  'CheuElliott': 'US',
#  'ChiangJim': 'US',
#  'ChiniRolf': 'CL',
#  'ChisariElisa': 'UK',
#  'ChomiukLaura': 'US',
#  'ChornockRyan': 'US',
#  'ChristensenEric': 'US',
#  'ChuYou-Hua': 'US',
#  'CiardiDavid': 'US',
#  'CiconeClaudia': 'oth',
#  'CiezaLucas': 'CL',
#  'CignoniMichele': 'IT',
#  'CioniMaria-Rosa': 'DE',
#  'CisewskiJessi': 'US',
#  'ClarksonWilliam': 'US',
#  'ClaverChuck': 'US',
#  'ClaytonGeoffrey': 'US',
#  'ClementiniGisella': 'IT',
#  'CloweDouglas': 'US',
#  'Cohen-TanugiJohann': 'FR',
#  'CohnJoanne': 'US',
#  'CollettThomas': 'UK',
#  'CombetCeline': 'FR',
#  'ConnollyAndrew': 'US',
#  'ConseliceChris': 'oth',
#  'ContrerasHantkeSergio': 'CL',
#  'CookKem': 'US',
#  'CooperMichael': 'US',
#  'CoorayAsantha': 'US',
#  'CoppejansDeanne': 'US',
#  'CoppiPaoloSevero': 'US',
#  'CordesJim': 'US',
#  'CoughlinMichael': 'oth',
#  'CoveyKevin': 'US',
#  'CowanNick': 'US',
#  'CuadraJorge': 'CL',
#  'CucchiaraAntonino': 'US',
#  'CuiWei': 'US',
#  'CukMatija': 'US',
#  'CusanoFelice': 'IT',
#  'Cyr-RacineFrancis-Yan': 'US',
#  'CzernyBozena': 'PL',
#  "D'AmmandoFilippo": 'IT',
#  "D'AndreaChris": 'US',
#  "D'AvanzoPaolo": 'IT',
#  'DagoretSylvie': 'FR',
#  'DalPonteMarina': 'BR',
#  "Dall'OraMassimo": 'IT',
#  'DanielScott': 'oth',
#  'DavenportJames': 'US',
#  'DaviesJon': 'UK',
#  'DaviesLuke': 'AU',
#  'DaviesRoger': 'UK',
#  'DavisChristopher': 'US',
#  'DawsonWilliam': 'US',
#  'DeCiccoDemetra': 'oth',
#  'DeLeeNathan': 'US',
#  'DeMarcoOrsola': 'AU',
#  'DeMeoFrancesca': 'US',
#  'DeasonAlis': 'UK',
#  'DebattistaVictor': 'oth',
#  'DellAntonioIan': 'US',
#  'DemarcoRicardo': 'CL',
#  'DenneauLarry': 'US',
#  'DevriendtJulien': 'UK',
#  'DexterJason': 'oth',
#  'DhitalSaurav': 'oth',
#  'DiStefanoRosanne': 'US',
#  'DiazTanio': 'CL',
#  'DickinsonMark': 'US',
#  'DigelSeth': 'US',
#  'DjorgovskiGeorge': 'US',
#  'DoblerGreg': 'US',
#  'DoctorZoheyr': 'US',
#  'DodelsonScott': 'US',
#  'DonachieMartin': 'NZ',
#  'DonesLuke': 'US',
#  'DoreOlivier': 'US',
#  'DotterAaron': 'US',
#  'DrakeJeremy': 'US',
#  'DriverSimon': 'AU',
#  'Drlica-WagnerAlex': 'US',
#  'DroutMaria': 'US',
#  'DuboisRichard': 'US',
#  'DunkleyJo': 'UK',
#  'DurechJosef': 'CZ',
#  'EgglSiegfried': 'oth',
#  'EiflerTim': 'oth',
#  'EliasJonathan': 'US',
#  'EliasdottirArdis': 'US',
#  'ElsnerFranz': 'UK',
#  'ElvisMartin': 'US',
#  'EracleousMike': 'US',
#  'EscalaAndres': 'CL',
#  'EscarateMonettaPedroAntonio': 'CL',
#  'EyheramendySusana': 'CL',
#  'FabrizioMichele': 'IT',
#  'FadelyRoss': 'US',
#  'FalcoEmilio': 'US',
#  'FanXiaohui': 'US',
#  'FarihiJay': 'UK',
#  'FarnocchiaDavide': 'US',
#  'FassnachtChris': 'US',
#  'FeigelsonEric': 'US',
#  'FeinsteinFabrice': 'FR',
#  'FergusonAnnette': 'UK',
#  'FergusonHenry': 'US',
#  'FerreiraPedro': 'UK',
#  'FinchCharlie': 'US',
#  'FinkelsteinSteven': 'US',
#  'FinleyDavid': 'US',
#  'FiorentinoGiuliana': 'IT',
#  'Fisher-LevineMerlin': 'oth',
#  'FitzsimmonsAlan': 'UK',
#  'FongMatthew': 'US',
#  'FongWen-fai': 'US',
#  'FouchezDominique': 'FR',
#  'FoxDerek': 'US',
#  'FoxOri': 'US',
#  'FrankJuhan': 'US',
#  'FraserWesley': 'UK',
#  'FreemanPeter': 'US',
#  'FreyLucille': 'US',
#  'FryeBrenda': 'US',
#  'FryerChris': 'US',
#  'FuentesCesar': 'CL',
#  'GalazGaspar': 'CL',
#  'GalbanyLluis': 'CL',
#  'GandhiPoshak': 'UK',
#  'GanglerEmmanuel': 'FR',
#  'GarofaloAlessia': 'IT',
#  'GawiserEric': 'US',
#  'GehaMarla': 'US',
#  'GeislerDoug': 'CL',
#  'GellerAaron': 'US',
#  'GenoveseChristopher': 'oth',
#  'GerdesDavid': 'US',
#  'GezariSuvi': 'US',
#  'GhirlandaGiancarlo': 'IT',
#  'GianninasAlexandros': 'US',
#  'GianniniTeresa': 'IT',
#  'GibbsAlex': 'US',
#  'GibsonRob': 'US',
#  'GilmanFred': 'US',
#  'GilmoreKirk': 'US',
#  'GirardTerrence': 'US',
#  'GirardiLeo': 'IT',
#  'GizisJohn': 'US',
#  'GlanzmanTom': 'US',
#  'GlazebrookKarl': 'AU',
#  'GoldsteinDaniel': 'US',
#  'GombocAndreja': 'SI',
#  'GomezMatias': 'CL',
#  'GrahamMatthew': 'US',
#  'GrahamMelissa': 'US',
#  'GranvikMikael': 'FI',
#  'GrapsAmara': 'US',
#  'GraurOr': 'US',
#  'GrayAlexander': 'US',
#  'GrazianAndrea': 'IT',
#  'GrazianiCarlo': 'US',
#  'GrecoJohnny': 'US',
#  'GreenRichard': 'US',
#  'GreenstreetSarah': 'US',
#  'GreggioLaura': 'IT',
#  'GrillmairCarl': 'US',
#  'GrindlayJosh': 'US',
#  'GrisPhilippe': 'FR',
#  'GschwendJulia': 'BR',
#  'GuhathakurtaPuragra': 'US',
#  'GuillochonJames': 'US',
#  'GuyonnetAugustin': 'US',
#  'HabibSalman': 'US',
#  'HaimanZoltan': 'US',
#  'HakkilaJon': 'US',
#  'HambletonKelly': 'US',
#  'HammergrenMark': 'US',
#  'HargisJonathan': 'US',
#  'HarrisAl': 'US',
#  'HartiganPatrick': 'US',
#  'HartleyWilliam': 'oth',
#  'HathiNimish': 'oth',
#  'HawleySuzanne': 'US',
#  'HearinAndrew': 'US',
#  'HebbLeslie': 'US',
#  'HeeCharlotte': 'US',
#  'HeitmannKatrin': 'US',
#  'HelouGeorge': 'US',
#  'HendenArne': 'US',
#  'HendlerNathanial': 'US',
#  'HenryTodd': 'US',
#  'HerXiachang': 'US',
#  'HerstrofferDaniel': 'FR',
#  'HiltonEric': 'US',
#  'HlozekRenee': 'CA',
#  'HoShirley': 'US',
#  'HoenigSebastian': 'UK',
#  'HolbergJayB.': 'US',
#  'HollerBryan': 'US',
#  'HolmanMatthew': 'US',
#  'HolwerdaBenne': 'oth',
#  'HolzDaniel': 'US',
#  'HowellSteve': 'US',
#  'HsiehHenry': 'US',
#  'HuberMark': 'US',
#  'HundertmarkMarkus': 'DE',
#  'InfanteLeopoldo': 'CL',
#  'InnesWalter': 'US',
#  'InnoLaura': 'IT',
#  'InserraCosimo': 'UK',
#  'IrwinJohn': 'US',
#  'IshakMustapha': 'US',
#  'IshidaEmille': 'FR',
#  'Itam-PasquetJohanna': 'oth',
#  'IvansInese': 'US',
#  'IvezicZeljko': 'US',
#  'JacklinSavannah': 'US',
#  'JacksonRyan': 'UK',
#  'JaffeAndrew': 'UK',
#  'JainBhuvnesh': 'US',
#  'JaoWei-Chun': 'US',
#  'JarvisMatt': 'UK',
#  'JarvisMike': 'US',
#  'JedickeRobert': 'US',
#  'JeeJames': 'oth',
#  'JenningsElise': 'US',
#  'JerniganGarrett': 'US',
#  'JevremovicDarko': 'RS',
#  'JhaSaurabh': 'US',
#  'JiInchan': 'US',
#  'JiangYan-Fei': 'US',
#  'JoachimiBenjamin': 'UK',
#  'Johns-KrullChristopher': 'US',
#  'JohnsonAnthony': 'US',
#  'JohnsonChristian': 'US',
#  'JohnsonMichael': 'UK',
#  'JohnstonKathryn': 'US',
#  'JonesLynne': 'US',
#  'JordanAndres': 'CL',
#  'JuricMario': 'US',
#  'KaasalAinenMikko': 'FI',
#  'KafkaStella': 'US',
#  'KahnSteven': 'US',
#  'KaibNathan': 'US',
#  'KaliraiJason': 'US',
#  'KallivayalilNityaJacob': 'US',
#  'KalmbachBryce': 'oth',
#  'KalogeraVicky': 'US',
#  'KamathSowmya': 'US',
#  'KanburShashi': 'US',
#  'KaplanDavid': 'US',
#  'KartaltepeJeyhan': 'US',
#  'KashyapVinayL.': 'US',
#  'KasliwalMansi': 'US',
#  'KasliwalVishal': 'US',
#  'KavirajSugata': 'UK',
#  'KeetonCharles': 'US',
#  'KelleyMichael': 'US',
#  'KelvinLee': 'US',
#  'KentStephen': 'US',
#  'KerinsEamonn': 'UK',
#  'KhakpashSomayeh': 'US',
#  'KiesslingAlina': 'US',
#  'KilicMukremin': 'US',
#  'KimAlex': 'US',
#  'KimPeter': 'US',
#  'KimballAmy': 'US',
#  'KirbyEvan': 'US',
#  'KirkbyDavid': 'US',
#  'KirkpatrickDavy': 'US',
#  'KnapenJohan': 'ES',
#  'KnezevicZoran': 'RS',
#  'KnightMatthew': 'US',
#  'KnuthKevin': 'US',
#  'KoposovSergey': 'US',
#  'KovacsEve': 'US',
#  'KowalskiAdam': 'US',
#  'KrauseElisabeth': 'US',
#  'KrughoffKarl': 'US',
#  'KrughoffSimon': 'US',
#  'KuhlmannSteve': 'US',
#  'KulierAndrea': 'CL',
#  'KulkarniShri': 'US',
#  'KuncarayaktiHanindyo': 'CL',
#  'KunderAndrea': 'DE',
#  'KurczynskiPeter': 'oth',
#  'KurtevRadostin': 'CL',
#  'LacernaIvan': 'CL',
#  'LacyMark': 'US',
#  'LageCraig': 'US',
#  'LahavOfer': 'UK',
#  'LandoniMarco': 'IT',
#  'LangDustin': 'CA',
#  'LarsenJeffreyArthur': 'US',
#  'LarsenPatricia': 'US',
#  'LauroeschJames': 'oth',
#  'LawrenceAndy': 'UK',
#  'LeBretonRemy': 'FR',
#  'LeGuillouLaurent': 'FR',
#  'LeeAnn': 'US',
#  'LeeChien-Hsiu': 'US',
#  'LegetPierre-Francois': 'US',
#  'LeistedtBoris': 'UK',
#  'LeonardDanielle': 'US',
#  'LepineSebastien': 'US',
#  'LevanAndrew': 'UK',
#  'LiGongjie': 'US',
#  'LimKian-Tat': 'US',
#  'LinHsing-Wen(Edward)': 'US',
#  'LinHuan': 'US',
#  'LinWeikang': 'US',
#  'LinderEric': 'US',
#  'LintottChris': 'UK',
#  'LiodakisYannis': 'US',
#  'LiraPaulina': 'CL',
#  'ListerTim': 'US',
#  'LiuBinyang': 'US',
#  'LiuMichael': 'US',
#  'LochnerMichelle': 'SA',
#  'LoebmanSarah': 'oth',
#  'LongJames': 'US',
#  'LongKnoxS.': 'US',
#  'LopezSebastian': 'CL',
#  'LoredoTom': 'US',
#  'LotzJennifer': 'US',
#  'LoucksMike': 'oth',
#  'LovedayJon': 'UK',
#  'LubinLori': 'US',
#  'LucasPhilip': 'UK',
#  'LuhmanKevin': 'US',
#  'LundMichael': 'US',
#  'LunnanRagnhild': 'US',
#  'LuptonRobert': 'US',
#  'LuqueElmer': 'oth',
#  'LurieJohn': 'US',
#  'LutzJulie': 'US',
#  'MacLeodChelsea': 'US',
#  'MaccaroneThomas': 'US',
#  'MacriLucas': 'US',
#  'MadejskiGreg(Grzegorz)': 'US',
#  'MagriniLaura': 'IT',
#  'MaguireKate': 'UK',
#  'MagurnoDavide': 'IT',
#  'MahabalAshish': 'US',
#  'MainettiDeborah': 'IT',
#  'MalhotraRenu': 'US',
#  'MalzAlex': 'US',
#  'ManconeConorL.': 'US',
#  'MandelKaisey': 'US',
#  'MandelbaumRachel': 'US',
#  'MantzAdam': 'US',
#  'MaoYao-Yuan': 'oth',
#  'MarconiMarcella': 'IT',
#  'MargoninerVera': 'oth',
#  'MarguttiRaffaella': 'US',
#  'MarinoAlessio': 'IT',
#  'MarinoniSilvia': 'IT',
#  'MarshallJennifer': 'US',
#  'MarshallPhil': 'US',
#  'Martanez-LombillaCristina': 'ES',
#  'MartinGarreth': 'UK',
#  'Martinez-GalarzaRafael': 'US',
#  'MasonElena': 'IT',
#  'MastersKaren': 'US',
#  'MathesonTom': 'US',
#  'MaundJustyn': 'UK',
#  'MaureiraJuanCarlos': 'CL',
#  'MauroFrancesco': 'CL',
#  'MauronNicolas': 'FR',
#  'MayMorgan': 'US',
#  'McClintockThomas': 'oth',
#  'McCollumBruce': 'US',
#  'McEwenJason': 'UK',
#  'McGeheePeregrine': 'US',
#  'McGreerIan': 'US',
#  'McMahonRichard': 'UK',
#  'MelandriAndrea': 'IT',
#  'MenardBrice': 'US',
#  'MennickentRonald': 'CL',
#  'MercurioAmata': 'IT',
#  'MerlinEmiliano': 'IT',
#  'MeurerGerhardt': 'oth',
#  'MeyerDavid': 'US',
#  'MeyersJoshua': 'oth',
#  'MezaAndres': 'oth',
#  'MilaniAndrea': 'IT',
#  'MilisavljevicDanny': 'US',
#  'MillerAdam': 'US',
#  'MillerBryan': 'US',
#  'MillerChris': 'US',
#  'MinnitiDante': 'CL',
#  'ModjazMaryam': 'US',
#  'MoeyensJoachim': 'US',
#  'MommertMichael': 'US',
#  'MonacoLorenzo': 'oth',
#  'MonetDavid': 'US',
#  'MoniezMarc': 'FR',
#  'MorettiAlberto': 'IT',
#  'MorettiMariaIda': 'IT',
#  'MorrisDave': 'UK',
#  'MorrisGlenn': 'US',
#  'MorrisonChristopher': 'US',
#  'MortlockDaniel': 'UK',
#  'MoskovitzNicholas': 'US',
#  'MottaVeronica': 'CL',
#  'MuellerBeatrice': 'US',
#  'MukadamAnjum': 'US',
#  'MundellCarole': 'UK',
#  'MunozRicardo': 'CL',
#  'MunozRobertoPablo': 'CL',
#  'MunozarArancibiaAlejandra': 'CL',
#  'MuravevaTatiana': 'IT',
#  'MurgiaSimona': 'US',
#  'MusellaIlaria': 'IT',
#  'NaiduShantanu': 'US',
#  'NantaisJulieBeth': 'CL',
#  'NapolitanoNicola': 'IT',
#  'NarayanGautham': 'US',
#  'NaylorTim': 'UK',
#  'NeilsenEric': 'US',
#  'NeveuJeremy': 'FR',
#  'NewmanJeffrey': 'US',
#  'NeyrinckMark': 'US',
#  'NiQingling': 'US',
#  'NicholBob': 'UK',
#  'NiederhoferFlorian': 'DE',
#  'NierenbergAnna': 'US',
#  'NightingaleJames': 'UK',
#  'NikolaevSergei': 'US',
#  'NissankeSamaya': 'US',
#  'NomerotskiAndrei': 'US',
#  'NormanDara': 'US',
#  'NugentPeter': 'US',
#  'NussEric': 'FR',
#  "O'ConnorPaul": 'US',
#  'ObricMirela': 'oth',
#  'OfekEranO.': 'US',
#  'OgandoRicardo': 'BR',
#  'OguriMasamune': 'US',
#  'OjalaElle': 'US',
#  'OlivierScot': 'US',
#  'OlkinCatherine': 'US',
#  'OlsenKnut': 'US',
#  'OlszewskiEdward': 'US',
#  'OluseyiHakeem': 'US',
#  'PadillaNelson': 'CL',
#  'PageGary': 'US',
#  'PandaSwayamtrupta': 'PL',
#  'PankowChris': 'US',
#  'PapovichCasey': 'US',
#  'ParkHyeYun': 'US',
#  'ParkerAlex': 'US',
#  'ParrentJerod': 'US',
#  'ParsonsSteven': 'CL',
#  'PastorelloAndrea': 'IT',
#  'PayneMatthew': 'oth',
#  'PedersenEske': 'US',
#  'PeirisHiranya': 'UK',
#  'Penna-LimaMariana': 'FR',
#  'PepperJoshua': 'US',
#  'PerlmutterSaul': 'US',
#  'PerrefortDaniel': 'US',
#  'PesensonMisha': 'US',
#  'PetersChristina': 'CA',
#  'PetersonJohn': 'US',
#  'PetitJean-Marc': 'FR',
#  'PetryCathy': 'US',
#  'PieresAdriano': 'BR',
#  'PignataGiuliano': 'oth',
#  'PiranomonteSilvia': 'oth',
#  'PironFrederic': 'FR',
#  'PlavchanPeter': 'US',
#  'PlazasAndres': 'CL',
#  'PonderKara': 'US',
#  'PopeAdrian': 'US',
#  'PopovicLuka': 'RS',
#  'PowerChris': 'AU',
#  'PrisinzanoLoredana': 'IT',
#  'ProtopapasPavlos': 'US',
#  'ProuzaMichael': 'CZ',
#  'PrsaAndrej': 'US',
#  'PtakAndrew': 'US',
#  'PuckettAndy': 'US',
#  'PuziaThomas': 'oth',
#  'QuataertEliot': 'US',
#  'QuinnTom': 'US',
#  'RabusMarkus': 'CL',
#  'RagozzineDarin': 'US',
#  'RahmanMubdi': 'US',
#  'RaiteriClaudiaM.': 'IT',
#  'RajMariaAngela': 'IT',
#  'RajagopalJayadev': 'US',
#  'RamirezAmelia': 'CL',
#  'RasmussenAndrew': 'US',
#  'RasmussenAndy': 'US',
#  'RattenburyNicholas': 'NZ',
#  'RauArne': 'DE',
#  'ReachWilliam': 'US',
#  'RebbapragadaUmaa': 'US',
#  'ReddyNaveen': 'US',
#  'RegnaultNicolas': 'FR',
#  'ReilKevin': 'US',
#  'ReissDavid': 'US',
#  'RestArmin': 'US',
#  'RhoadsJamesE.': 'US',
#  'RhodesJason': 'US',
#  'RichR.Michael': 'US',
#  'RichardsGordon': 'US',
#  'RichardsJoseph': 'oth',
#  'RichardsMercedes': 'US',
#  'RichterMatt': 'US',
#  'RickerPaul': 'US',
#  'RicolJean-Stephane': 'FR',
#  'RidgwayStephen': 'US',
#  'RiedelAdric': 'oth',
#  'RighiChiara': 'IT',
#  'RitzSteve': 'US',
#  'RivkinAndy': 'US',
#  'RobertsonBrant': 'US',
#  'RobothamAaron': 'AU',
#  'RockosiConstance': 'US',
#  'RodriguezJoseph': 'oth',
#  'RojoPatricio': 'CL',
#  'RomanAlexandre': 'CL',
#  'RomaniRoger': 'US',
#  'RoncarelliMauro': 'IT',
#  'RoodmanAaron': 'US',
#  'RosingWayne': 'US',
#  'RossiGustavoBenedetti': 'oth',
#  'RoucelleCecile': 'FR',
#  'RozoEduardo': 'US',
#  'RunnoeJessie': 'US',
#  'RuppertDavid': 'US',
#  'RutkowskiMichael': 'US',
#  'RykoffEli': 'US',
#  'SaccoGiuseppe': 'IT',
#  'SahaAbi': 'US',
#  'SaintongeAmelie': 'UK',
#  'SaitoRoberto': 'CL',
#  'SakoMasao': 'US',
#  'SalafiaOmSharan': 'IT',
#  'SalimSamir': 'US',
#  'SamarasinhaNalin': 'US',
#  'SanchezJavier': 'US',
#  'SantiagoBasilio': 'BR',
#  'SarajediniAta': 'US',
#  'SaridGal': 'US',
#  'SasselovDimitar': 'US',
#  'ScargleJeffrey': 'US',
#  'SchaferChad': 'US',
#  'SchambeauCharles': 'US',
#  'SchechterPaul': 'US',
#  'SchindlerJan-Torge': 'US',
#  'SchmidtEdward': 'US',
#  'SchmidtSam': 'US',
#  'SchmidtSamuel': 'US',
#  'SchneiderDon': 'US',
#  'SchneiderMichael': 'US',
#  'SchwambMeg': 'UK',
#  'ScowenPaul': 'US',
#  'ScrantonRyan': 'oth',
#  'ScudderJillian': 'US',
#  'SeamanRob': 'US',
#  'SeljakUros': 'US',
#  'SembroskiGlenn': 'US',
#  'SerenoMauro': 'IT',
#  'SesarBranimir': 'US',
#  'SethAnil': 'US',
#  'ShafterAllenW.': 'US',
#  'ShamirLior': 'US',
#  'SheldonErin': 'oth',
#  'ShemmerOhad': 'US',
#  'ShenKen': 'US',
#  'SheppardScott': 'US',
#  'ShipseyIan': 'UK',
#  'ShirleyRaphael': 'UK',
#  'ShporerAvi': 'US',
#  'SickJonathan': 'US',
#  'SiemiginowskaAneta': 'US',
#  'SilvaDavid': 'US',
#  'SilvestriNicole': 'US',
#  'SimetMelanie': 'US',
#  'SimonJoshuaD.': 'US',
#  'SingerLeo': 'US',
#  'SlaterColin': 'US',
#  'SlosarAnze': 'US',
#  'SmarttStephen': 'UK',
#  'SmithChris': 'US',
#  'SmithGraham': 'UK',
#  'SmithHoward': 'US',
#  'SmithJ.Allyn': 'US',
#  'SmithKen': 'UK',
#  'SmithNathan': 'US',
#  'SmothermanHayden': 'US',
#  'SnodgrassColin': 'UK',
#  'SnyderGreg': 'US',
#  'SobeckJennifer': 'US',
#  'SolarzAleksandra': 'PL',
#  'SolontoiMike': 'US',
#  'SonnefeldAlessandro': 'US',
#  'SoraisamMonika': 'US',
#  'SordoRosanna': 'IT',
#  'SpergelDavid': 'US',
#  'SpitzAnna': 'US',
#  'StanfordAdam': 'oth',
#  'StassunKeivan': 'US',
#  'SteckloffJordan': 'US',
#  'SteeghsDanny': 'UK',
#  'SteenbruggeKatrien': 'oth',
#  'SternAlan': 'US',
#  'StottJohn': 'UK',
#  'StraderJay': 'US',
#  'StrattaGiulia': 'IT',
#  'StraussMichael': 'US',
#  'StreetRachel': 'US',
#  'StuartScott': 'US',
#  'StubbsChristopher': 'US',
#  'SubasavageJohn': 'US',
#  'SullivanMark': 'UK',
#  'SzaboRobert': 'HU',
#  'SzkodyPaula': 'US',
#  'TakHyungsuk': 'oth',
#  'TamayoDaniel': 'US',
#  'TaranuDan': 'US',
#  'TejosNicolas': 'US',
#  'TheilerJamesP.': 'US',
#  'ThirouinAudrey': 'US',
#  'ThomasCristina': 'US',
#  'ThormanPaul': 'US',
#  'ThorstensenJohnRobert': 'US',
#  'TisseraPatricia': 'oth',
#  'TreisterEzequiel': 'CL',
#  'TreuTommaso': 'US',
#  'TrillingDavid': 'US',
#  'TrimbleVirginia': 'US',
#  'TrouilleLaura': 'US',
#  'TroxelMichael': 'US',
#  'TrujilloChad': 'US',
#  'TrujilloIgnacio': 'ES',
#  'TsaprasYiannis': 'DE',
#  'TsybychevDmitri': 'US',
#  'TysonTony': 'US',
#  'UrryMeg': 'US',
#  'ValentiStefano': 'US',
#  'VallenariAntonella': 'IT',
#  'VandenBerkDan': 'US',
#  'VenutiLaura': 'IT',
#  'VeresPeter': 'US',
#  'VermaAprajita': 'UK',
#  'VestrandTom': 'US',
#  'VianelloGiacomo': 'US',
#  'VieiraJoaquin': 'US',
#  'VilaltaRicardo': 'US',
#  'VillarVictoriaAshley': 'US',
#  'VillarrealAntonio': 'US',
#  'VinkJorick': 'UK',
#  'VivasKathy': 'US',
#  'VogeleyMichael': 'US',
#  'VolkKat': 'US',
#  'VonDerLindenAnja': 'DK',
#  'VrastilMichal': 'CZ',
#  'WainscoatRichard': 'US',
#  'WalkerAlistair': 'US',
#  'WalkowiczLucianne': 'US',
#  'WallersteinGeorge': 'US',
#  'WallinJohn': 'oth',
#  'WalterChris': 'US',
#  'WaltonNicholas': 'UK',
#  'WangYun': 'US',
#  'WassermanLarry': 'US',
#  'WeatherillDaniel': 'UK',
#  'WebsterRachel': 'AU',
#  'WechslerRisa': 'US',
#  'WeinbergMartin': 'US',
#  'WeinerBen': 'US',
#  'WellsMark': 'US',
#  'WenausTorre': 'oth',
#  'WernerNorbert': 'US',
#  'WestAndrew': 'US',
#  'WiesnerMatthew': 'oth',
#  'WildVivienne': 'UK',
#  'WilliamsBen': 'US',
#  'WilliamsRobert': 'US',
#  'WilligerGerard': 'US',
#  'WillmanBeth': 'US',
#  'WittmanDavid': 'US',
#  'WolpertRobert': 'US',
#  'WomackMaria': 'US',
#  'Wood-VaseyMichael': 'US',
#  'WoodroofeMichael': 'US',
#  'WozniakPrzemek': 'US',
#  'Yanamandra-FisherPadma': 'US',
#  'YangGuang': 'US',
#  'YangSheng': 'IT',
#  'YeQuan-Zhi': 'US',
#  'YoachimPeter': 'US',
#  'YoungDavid': 'UK',
#  'YoungLeslie': 'US',
#  'YuWeixiang': 'US',
#  'ZabludoffAnn': 'US',
#  'ZaudererAshley': 'US',
#  'ZehaviIdit': 'US',
#  'ZentnerAndrew': 'US',
#  'ZhanHu': 'CN',
#  'ZhaoGong-Bo': 'CN',
#  'ZhengZhenia': 'CL',
#  'ZoccaliManuela': 'CL',
#  'ZolotovAdi': 'US',
#  'ZuntzJoe': 'oth',
#  'daCostaLuiz': 'BR',
#  'deAndradeQueirozAnnaBarbara': 'BR',
#  'deJongRoelof': 'DE',
#  'deVal-BorroMiguel': 'US',
#  'deVriesWim': 'US'}

# %%
f = open("affnodes.txt", "w")
#for i in df_["Contact Category"].unique():
#    f.write('"'+propernames[i].replace(" ","_") + '"\n')
#f.close()

for n in affiliationsDF.index.values:
    f.write(n + '\n')
f.close()

# %%
cols = affiliationsDF.columns
affdic = {}
f = open("affedges.txt", "w")
for i,n1 in enumerate(affiliationsDF.index.values):
    affdic[n1] = {}
    for n2 in affiliationsDF.index.values[i+1:]:
        for c in cols:
            
            if affiliationsDF.loc[n1,c] > 0:
                if affiliationsDF.loc[n2,c] > 0:
                    f.write(n1 + " "  + n2  +'\n')
                    affdic[n1][n2] = {"color" : p[n1]} 

f.close()

# %%
d = {0: {1: {}, 2: {}},
    2: {1: {}}} # dict-of-dicts single edge (0,1)

G = nx.Graph(d, multigraph_input =True)
nx.draw(G, with_labels=False, font_weight='bold')
d
# Out:
# {0: {1: {}, 2: {}}, 2: {1: {}}}

# %%
G = nx.Graph(affdic, multigraph_input =True)
nx.draw(G, with_labels=False, width=0.03, alpha=0.5)

# %%
p
# Out:
# {'AbdullaGhaleb': 'TVS',
#  'AbellPaulAlexander': 'SS',
#  'AgolEric': 'TVS',
#  'AguenaMichel': 'DESC',
#  'AguerosMarcel': 'TVS',
#  'AkhlaghiMohammad': 'Galaxies',
#  'AlderingGreg': 'DESC',
#  'AllenMark': 'SL',
#  'AllenSteven': 'DESC',
#  'AlmeydaTriana': 'AGN',
#  'Alonso-GarciaJavier': 'TVS',
#  'AlonsoDavid': 'DESC',
#  'AnderesEthan': 'SMWLV',
#  'AndersonScott': 'IS',
#  'AnguitaTimo': 'AGN',
#  'AnsariReza': 'Galaxies',
#  'AntilogusPierre': 'DESC',
#  'AntoniucciSimone': 'DESC',
#  'AravenaManuel': 'TVS',
#  'ArcaviIair': 'Galaxies',
#  'ArdilaDavid': 'TVS',
#  'ArgudoFernandezMariadelCarmen': 'SMWLV',
#  'ArmusLee': 'SMWLV',
#  'ArnettW.David': 'Galaxies',
#  'AssefRoberto': 'Galaxies',
#  'AstierPierre': 'TVS',
#  'AubourgEric': 'AGN',
#  'AvestruzCamille': 'DESC',
#  'AwanHumna': 'SL',
#  'AyeMichael': 'DESC',
#  'BabuJogesh': 'DESC',
#  'BaileyStephen': 'SS',
#  'BailynCharles': 'IS',
#  'BallandChristophe': 'IS',
#  'BallantyneDavid': 'TVS',
#  'BalmaverdeBarbara': 'DESC',
#  'BaloghMichael': 'AGN',
#  'BaltzTed': 'TVS',
#  'BandaMartin': 'Galaxies',
#  'BanerjiManda': 'SL',
#  'BannisterMichele': 'SS',
#  'BarbaRodolfo': 'Galaxies',
#  'BarbieriMauro': 'SS',
#  'BardDeborah': 'SMWLV',
#  'BarrauAurelien': 'SMWLV',
#  'BarreraLuis': 'SMWLV',
#  'BarrientosFelipe': 'SMWLV',
#  'BarthAaron': 'DESC',
#  'BartlettJames': 'DESC',
#  'BassGideon': 'Galaxies',
#  'BauerFranz': 'AGN',
#  'BaumerMichael': 'Galaxies',
#  'BeanRachel': 'DESC',
#  'BechtolKeith': 'TVS',
#  'BeckerAndrew': 'AGN',
#  'BeclaJacek': 'DESC',
#  'BeersTimothyC.': 'SS',
#  'BellEric': 'TVS',
#  'BellKeaton': 'DESC',
#  'BellagambaFabio': 'IS',
#  'BellmEric': 'SMWLV',
#  'BelokurovVasily': 'SMWLV',
#  'BergerEdo': 'SMWLV',
#  'BernsteinGary': 'SMWLV',
#  'BersierDavid': 'TVS',
#  'BetouleMarc': 'Galaxies',
#  'BiancoFederica': 'TVS',
#  'BianconiMatteo': 'SMWLV',
#  'BiswasRahul': 'TVS',
#  'BivianoAndrea': 'SS',
#  'BlancGuillaume': 'TVS',
#  'BlandfordRoger': 'DESC',
#  'BlantonMichaelRogers': 'IS',
#  'BlazekJonathan': 'TVS',
#  'BloomJosh': 'Galaxies',
#  'BlumBob': 'DESC',
#  'BochanskiJohn': 'Galaxies',
#  'BodewitsDennis': 'DESC',
#  'BoeshaarPatricia': 'SL',
#  'BolinBryce': 'Galaxies',
#  'BondHoward': 'DESC',
#  'BongardSebastien': 'TVS',
#  'BonitoRosaria': 'SMWLV',
#  'BonoGiuseppe': 'SMWLV',
#  'BoquienMederic': 'SMWLV',
#  'BorglandAnders': 'SS',
#  'BorneKirk': 'SMWLV',
#  'BorosonTodd': 'SS',
#  'BoschJames': 'TVS',
#  'BoschJim': 'DESC',
#  'BoseMaitrayee': 'SMWLV',
#  'BoshAmanda': 'SMWLV',
#  'BotticellaMariaTeresa': 'TVS',
#  'BoutignyDominique': 'TVS',
#  'BowlerRebecca': 'Galaxies',
#  'BradacMarusa': 'DESC',
#  'BradshawAndrew': 'IS',
#  'BrandtNiel': 'Galaxies',
#  'BremerMalcolm': 'SS',
#  'BridgeCarrie': 'SS',
#  'BridleSarah': 'TVS',
#  'BrittChristopher': 'DESC',
#  'BrocatoEnzo': 'Galaxies',
#  'BrothertonMichael': 'SL',
#  'BroughSarah': 'DESC',
#  'BrownMichael': 'TVS',
#  'BrownPeter': 'Galaxies',
#  'BrownTim': 'AGN',
#  'BrozovicMarina': 'IS',
#  'BrunnerRobert': 'Galaxies',
#  'BudavariTamas': 'DESC',
#  'BuenodeCamargoJulioIgnacio': 'SMWLV',
#  'BuieMarc': 'SMWLV',
#  'BullPhilip': 'TVS',
#  'BullockJames': 'AGN',
#  'BurchatPatricia': 'Galaxies',
#  'BurgasserAdam': 'SS',
#  'BurkeDavid': 'TVS',
#  'BurkeDouglas': 'SS',
#  'BurninghamBen': 'IS',
#  'ButlerNathaniel': 'AGN',
#  'CabreraGuillermo': 'IS',
#  'CaiYongzhi': 'SS',
#  'CalabreseErminia': 'SS',
#  'CalamidaAnnalisa': 'DESC',
#  'CampagneJean-Eric': 'SMWLV',
#  'Cantat-GaudinTristan': 'SMWLV',
#  'CargilePhillip': 'DESC',
#  'CariniRoberta': 'SL',
#  'CarlinJeff': 'SMWLV',
#  'CarnereroMartinMariaIsabel': 'SMWLV',
#  'Carrasco-KindMatias': 'DESC',
#  'CasettiDanaIoana': 'IS',
#  'CassataPaolo': 'SMWLV',
#  'CatelanMarcio': 'SMWLV',
#  'CavuotiStefano': 'IS',
#  'CenkoStephen': 'TVS',
#  'ChambaNushkia': 'DESC',
#  'ChanameJulio': 'SMWLV',
#  'ChangChihway': 'SMWLV',
#  'ChartasGeorge': 'DESC',
#  'ChenXuelei': 'SMWLV',
#  'ChenYen-Chi': 'SMWLV',
#  'ChernoffDavid': 'SMWLV',
#  'ChesleySteve': 'SMWLV',
#  'CheuElliott': 'SMWLV',
#  'ChiangJim': 'TVS',
#  'ChiniRolf': 'DESC',
#  'ChisariElisa': 'SMWLV',
#  'ChomiukLaura': 'SMWLV',
#  'ChornockRyan': 'Galaxies',
#  'ChristensenEric': 'SMWLV',
#  'ChuYou-Hua': 'SMWLV',
#  'CiardiDavid': 'TVS',
#  'CiconeClaudia': 'TVS',
#  'CiezaLucas': 'Galaxies',
#  'CignoniMichele': 'SMWLV',
#  'CioniMaria-Rosa': 'SMWLV',
#  'CisewskiJessi': 'DESC',
#  'ClarksonWilliam': 'SL',
#  'ClaverChuck': 'AGN',
#  'ClaytonGeoffrey': 'IS',
#  'ClementiniGisella': 'TVS',
#  'CloweDouglas': 'IS',
#  'Cohen-TanugiJohann': 'SS',
#  'CohnJoanne': 'DESC',
#  'CollettThomas': 'TVS',
#  'CombetCeline': 'DESC',
#  'ConnollyAndrew': 'TVS',
#  'ConseliceChris': 'SMWLV',
#  'ContrerasHantkeSergio': 'SMWLV',
#  'CookKem': 'TVS',
#  'CooperMichael': 'SMWLV',
#  'CoorayAsantha': 'AGN',
#  'CoppejansDeanne': 'TVS',
#  'CoppiPaoloSevero': 'SMWLV',
#  'CordesJim': 'SMWLV',
#  'CoughlinMichael': 'IS',
#  'CoveyKevin': 'SMWLV',
#  'CowanNick': 'DESC',
#  'CuadraJorge': 'SMWLV',
#  'CucchiaraAntonino': 'SMWLV',
#  'CuiWei': 'TVS',
#  'CukMatija': 'TVS',
#  'CusanoFelice': 'DESC',
#  'Cyr-RacineFrancis-Yan': 'TVS',
#  'CzernyBozena': 'DESC',
#  "D'AmmandoFilippo": 'DESC',
#  "D'AndreaChris": 'DESC',
#  "D'AvanzoPaolo": 'DESC',
#  'DagoretSylvie': 'DESC',
#  'DalPonteMarina': 'SS',
#  "Dall'OraMassimo": 'Galaxies',
#  'DanielScott': 'SMWLV',
#  'DavenportJames': 'SMWLV',
#  'DaviesJon': 'Galaxies',
#  'DaviesLuke': 'TVS',
#  'DaviesRoger': 'SS',
#  'DavisChristopher': 'SS',
#  'DawsonWilliam': 'TVS',
#  'DeCiccoDemetra': 'IS',
#  'DeLeeNathan': 'SMWLV',
#  'DeMarcoOrsola': 'SMWLV',
#  'DeMeoFrancesca': 'SL',
#  'DeasonAlis': 'AGN',
#  'DebattistaVictor': 'TVS',
#  'DellAntonioIan': 'SS',
#  'DemarcoRicardo': 'TVS',
#  'DenneauLarry': 'AGN',
#  'DevriendtJulien': 'TVS',
#  'DexterJason': 'TVS',
#  'DhitalSaurav': 'TVS',
#  'DiStefanoRosanne': 'SMWLV',
#  'DiazTanio': 'SS',
#  'DickinsonMark': 'DESC',
#  'DigelSeth': 'SMWLV',
#  'DjorgovskiGeorge': 'SMWLV',
#  'DoblerGreg': 'TVS',
#  'DoctorZoheyr': 'DESC',
#  'DodelsonScott': 'SMWLV',
#  'DonachieMartin': 'SMWLV',
#  'DonesLuke': 'Galaxies',
#  'DoreOlivier': 'Galaxies',
#  'DotterAaron': 'Galaxies',
#  'DrakeJeremy': 'DESC',
#  'DriverSimon': 'DESC',
#  'Drlica-WagnerAlex': 'SMWLV',
#  'DroutMaria': 'SMWLV',
#  'DuboisRichard': 'Galaxies',
#  'DunkleyJo': 'SMWLV',
#  'DurechJosef': 'SMWLV',
#  'EgglSiegfried': 'SMWLV',
#  'EiflerTim': 'SMWLV',
#  'EliasJonathan': 'TVS',
#  'EliasdottirArdis': 'SS',
#  'ElsnerFranz': 'AGN',
#  'ElvisMartin': 'SMWLV',
#  'EracleousMike': 'SMWLV',
#  'EscalaAndres': 'TVS',
#  'EscarateMonettaPedroAntonio': 'SMWLV',
#  'EyheramendySusana': 'SMWLV',
#  'FabrizioMichele': 'DESC',
#  'FadelyRoss': 'Galaxies',
#  'FalcoEmilio': 'SS',
#  'FanXiaohui': 'SS',
#  'FarihiJay': 'Galaxies',
#  'FarnocchiaDavide': 'SL',
#  'FassnachtChris': 'SMWLV',
#  'FeigelsonEric': 'Galaxies',
#  'FeinsteinFabrice': 'Galaxies',
#  'FergusonAnnette': 'DESC',
#  'FergusonHenry': 'SMWLV',
#  'FerreiraPedro': 'TVS',
#  'FinchCharlie': 'IS',
#  'FinkelsteinSteven': 'SL',
#  'FinleyDavid': 'TVS',
#  'FiorentinoGiuliana': 'DESC',
#  'Fisher-LevineMerlin': 'SS',
#  'FitzsimmonsAlan': 'DESC',
#  'FongMatthew': 'SMWLV',
#  'FongWen-fai': 'SMWLV',
#  'FouchezDominique': 'TVS',
#  'FoxDerek': 'Galaxies',
#  'FoxOri': 'SMWLV',
#  'FrankJuhan': 'SMWLV',
#  'FraserWesley': 'TVS',
#  'FreemanPeter': 'DESC',
#  'FreyLucille': 'DESC',
#  'FryeBrenda': 'SS',
#  'FryerChris': 'TVS',
#  'FuentesCesar': 'SL',
#  'GalazGaspar': 'DESC',
#  'GalbanyLluis': 'SS',
#  'GandhiPoshak': 'AGN',
#  'GanglerEmmanuel': 'IS',
#  'GarofaloAlessia': 'IS',
#  'GawiserEric': 'TVS',
#  'GehaMarla': 'SL',
#  'GeislerDoug': 'AGN',
#  'GellerAaron': 'SMWLV',
#  'GenoveseChristopher': 'SS',
#  'GerdesDavid': 'DESC',
#  'GezariSuvi': 'SL',
#  'GhirlandaGiancarlo': 'IS',
#  'GianninasAlexandros': 'DESC',
#  'GianniniTeresa': 'Galaxies',
#  'GibbsAlex': 'SMWLV',
#  'GibsonRob': 'SMWLV',
#  'GilmanFred': 'Galaxies',
#  'GilmoreKirk': 'DESC',
#  'GirardTerrence': 'SMWLV',
#  'GirardiLeo': 'Galaxies',
#  'GizisJohn': 'DESC',
#  'GlanzmanTom': 'TVS',
#  'GlazebrookKarl': 'SMWLV',
#  'GoldsteinDaniel': 'DESC',
#  'GombocAndreja': 'DESC',
#  'GomezMatias': 'TVS',
#  'GrahamMatthew': 'DESC',
#  'GrahamMelissa': 'TVS',
#  'GranvikMikael': 'TVS',
#  'GrapsAmara': 'TVS',
#  'GraurOr': 'SS',
#  'GrayAlexander': 'IS',
#  'GrazianAndrea': 'TVS',
#  'GrazianiCarlo': 'SL',
#  'GrecoJohnny': 'SMWLV',
#  'GreenRichard': 'SMWLV',
#  'GreenstreetSarah': 'TVS',
#  'GreggioLaura': 'SS',
#  'GrillmairCarl': 'Galaxies',
#  'GrindlayJosh': 'TVS',
#  'GrisPhilippe': 'DESC',
#  'GschwendJulia': 'TVS',
#  'GuhathakurtaPuragra': 'DESC',
#  'GuillochonJames': 'TVS',
#  'GuyonnetAugustin': 'DESC',
#  'HabibSalman': 'Galaxies',
#  'HaimanZoltan': 'SMWLV',
#  'HakkilaJon': 'SMWLV',
#  'HambletonKelly': 'SMWLV',
#  'HammergrenMark': 'SMWLV',
#  'HargisJonathan': 'TVS',
#  'HarrisAl': 'IS',
#  'HartiganPatrick': 'SS',
#  'HartleyWilliam': 'TVS',
#  'HathiNimish': 'TVS',
#  'HawleySuzanne': 'SMWLV',
#  'HearinAndrew': 'TVS',
#  'HebbLeslie': 'SS',
#  'HeeCharlotte': 'DESC',
#  'HeitmannKatrin': 'DESC',
#  'HelouGeorge': 'Galaxies',
#  'HendenArne': 'SMWLV',
#  'HendlerNathanial': 'SMWLV',
#  'HenryTodd': 'SMWLV',
#  'HerXiachang': 'SMWLV',
#  'HerstrofferDaniel': 'SMWLV',
#  'HiltonEric': 'SMWLV',
#  'HlozekRenee': 'DESC',
#  'HoShirley': 'SL',
#  'HoenigSebastian': 'Galaxies',
#  'HolbergJayB.': 'SL',
#  'HollerBryan': 'SL',
#  'HolmanMatthew': 'TVS',
#  'HolwerdaBenne': 'SMWLV',
#  'HolzDaniel': 'SMWLV',
#  'HowellSteve': 'IS',
#  'HsiehHenry': 'TVS',
#  'HuberMark': 'SS',
#  'HundertmarkMarkus': 'SS',
#  'InfanteLeopoldo': 'TVS',
#  'InnesWalter': 'IS',
#  'InnoLaura': 'AGN',
#  'InserraCosimo': 'Galaxies',
#  'IrwinJohn': 'IS',
#  'IshakMustapha': 'Galaxies',
#  'IshidaEmille': 'AGN',
#  'Itam-PasquetJohanna': 'SS',
#  'IvansInese': 'TVS',
#  'IvezicZeljko': 'SMWLV',
#  'JacklinSavannah': 'TVS',
#  'JacksonRyan': 'DESC',
#  'JaffeAndrew': 'IS',
#  'JainBhuvnesh': 'TVS',
#  'JaoWei-Chun': 'IS',
#  'JarvisMatt': 'TVS',
#  'JarvisMike': 'SS',
#  'JedickeRobert': 'SMWLV',
#  'JeeJames': 'SS',
#  'JenningsElise': 'Galaxies',
#  'JerniganGarrett': 'Galaxies',
#  'JevremovicDarko': 'SMWLV',
#  'JhaSaurabh': 'SMWLV',
#  'JiInchan': 'DESC',
#  'JiangYan-Fei': 'TVS',
#  'JoachimiBenjamin': 'SMWLV',
#  'Johns-KrullChristopher': 'SMWLV',
#  'JohnsonAnthony': 'DESC',
#  'JohnsonChristian': 'SS',
#  'JohnsonMichael': 'DESC',
#  'JohnstonKathryn': 'TVS',
#  'JonesLynne': 'SS',
#  'JordanAndres': 'AGN',
#  'JuricMario': 'SMWLV',
#  'KaasalAinenMikko': 'SMWLV',
#  'KafkaStella': 'SS',
#  'KahnSteven': 'SS',
#  'KaibNathan': 'TVS',
#  'KaliraiJason': 'TVS',
#  'KallivayalilNityaJacob': 'SS',
#  'KalmbachBryce': 'TVS',
#  'KalogeraVicky': 'TVS',
#  'KamathSowmya': 'Galaxies',
#  'KanburShashi': 'DESC',
#  'KaplanDavid': 'SMWLV',
#  'KartaltepeJeyhan': 'SMWLV',
#  'KashyapVinayL.': 'TVS',
#  'KasliwalMansi': 'DESC',
#  'KasliwalVishal': 'SL',
#  'KavirajSugata': 'DESC',
#  'KeetonCharles': 'DESC',
#  'KelleyMichael': 'SMWLV',
#  'KelvinLee': 'SMWLV',
#  'KentStephen': 'Galaxies',
#  'KerinsEamonn': 'IS',
#  'KhakpashSomayeh': 'AGN',
#  'KiesslingAlina': 'SS',
#  'KilicMukremin': 'SL',
#  'KimAlex': 'SMWLV',
#  'KimPeter': 'TVS',
#  'KimballAmy': 'SMWLV',
#  'KirbyEvan': 'DESC',
#  'KirkbyDavid': 'IS',
#  'KirkpatrickDavy': 'TVS',
#  'KnapenJohan': 'Galaxies',
#  'KnezevicZoran': 'IS',
#  'KnightMatthew': 'DESC',
#  'KnuthKevin': 'SMWLV',
#  'KoposovSergey': 'SMWLV',
#  'KovacsEve': 'Galaxies',
#  'KowalskiAdam': 'DESC',
#  'KrauseElisabeth': 'AGN',
#  'KrughoffKarl': 'SS',
#  'KrughoffSimon': 'DESC',
#  'KuhlmannSteve': 'IS',
#  'KulierAndrea': 'SL',
#  'KulkarniShri': 'TVS',
#  'KuncarayaktiHanindyo': 'DESC',
#  'KunderAndrea': 'TVS',
#  'KurczynskiPeter': 'Galaxies',
#  'KurtevRadostin': 'AGN',
#  'LacernaIvan': 'DESC',
#  'LacyMark': 'TVS',
#  'LageCraig': 'DESC',
#  'LahavOfer': 'TVS',
#  'LandoniMarco': 'SMWLV',
#  'LangDustin': 'SMWLV',
#  'LarsenJeffreyArthur': 'SMWLV',
#  'LarsenPatricia': 'SMWLV',
#  'LauroeschJames': 'TVS',
#  'LawrenceAndy': 'Galaxies',
#  'LeBretonRemy': 'DESC',
#  'LeGuillouLaurent': 'SS',
#  'LeeAnn': 'IS',
#  'LeeChien-Hsiu': 'SL',
#  'LegetPierre-Francois': 'SMWLV',
#  'LeistedtBoris': 'SMWLV',
#  'LeonardDanielle': 'SMWLV',
#  'LepineSebastien': 'SMWLV',
#  'LevanAndrew': 'IS',
#  'LiGongjie': 'DESC',
#  'LimKian-Tat': 'SS',
#  'LinHsing-Wen(Edward)': 'SMWLV',
#  'LinHuan': 'SMWLV',
#  'LinWeikang': 'TVS',
#  'LinderEric': 'DESC',
#  'LintottChris': 'SS',
#  'LiodakisYannis': 'SMWLV',
#  'LiraPaulina': 'SMWLV',
#  'ListerTim': 'SMWLV',
#  'LiuBinyang': 'DESC',
#  'LiuMichael': 'SMWLV',
#  'LochnerMichelle': 'TVS',
#  'LoebmanSarah': 'DESC',
#  'LongJames': 'TVS',
#  'LongKnoxS.': 'TVS',
#  'LopezSebastian': 'Galaxies',
#  'LoredoTom': 'IS',
#  'LotzJennifer': 'Galaxies',
#  'LoucksMike': 'TVS',
#  'LovedayJon': 'Galaxies',
#  'LubinLori': 'SL',
#  'LucasPhilip': 'SS',
#  'LuhmanKevin': 'Galaxies',
#  'LundMichael': 'DESC',
#  'LunnanRagnhild': 'TVS',
#  'LuptonRobert': 'TVS',
#  'LuqueElmer': 'SMWLV',
#  'LurieJohn': 'SMWLV',
#  'LutzJulie': 'SL',
#  'MacLeodChelsea': 'AGN',
#  'MaccaroneThomas': 'DESC',
#  'MacriLucas': 'SMWLV',
#  'MadejskiGreg(Grzegorz)': 'DESC',
#  'MagriniLaura': 'SMWLV',
#  'MaguireKate': 'SMWLV',
#  'MagurnoDavide': 'Galaxies',
#  'MahabalAshish': 'SS',
#  'MainettiDeborah': 'TVS',
#  'MalhotraRenu': 'DESC',
#  'MalzAlex': 'TVS',
#  'ManconeConorL.': 'DESC',
#  'MandelKaisey': 'DESC',
#  'MandelbaumRachel': 'IS',
#  'MantzAdam': 'TVS',
#  'MaoYao-Yuan': 'DESC',
#  'MarconiMarcella': 'Galaxies',
#  'MargoninerVera': 'TVS',
#  'MarguttiRaffaella': 'SMWLV',
#  'MarinoAlessio': 'SMWLV',
#  'MarinoniSilvia': 'TVS',
#  'MarshallJennifer': 'AGN',
#  'MarshallPhil': 'SMWLV',
#  'Martanez-LombillaCristina': 'AGN',
#  'MartinGarreth': 'Galaxies',
#  'Martinez-GalarzaRafael': 'SS',
#  'MasonElena': 'DESC',
#  'MastersKaren': 'SMWLV',
#  'MathesonTom': 'SMWLV',
#  'MaundJustyn': 'AGN',
#  'MaureiraJuanCarlos': 'DESC',
#  'MauroFrancesco': 'DESC',
#  'MauronNicolas': 'SL',
#  'MayMorgan': 'IS',
#  'McClintockThomas': 'DESC',
#  'McCollumBruce': 'DESC',
#  'McEwenJason': 'DESC',
#  'McGeheePeregrine': 'SMWLV',
#  'McGreerIan': 'TVS',
#  'McMahonRichard': 'SS',
#  'MelandriAndrea': 'IS',
#  'MenardBrice': 'DESC',
#  'MennickentRonald': 'SS',
#  'MercurioAmata': 'DESC',
#  'MerlinEmiliano': 'Galaxies',
#  'MeurerGerhardt': 'AGN',
#  'MeyerDavid': 'AGN',
#  'MeyersJoshua': 'SS',
#  'MezaAndres': 'SMWLV',
#  'MilaniAndrea': 'SMWLV',
#  'MilisavljevicDanny': 'DESC',
#  'MillerAdam': 'DESC',
#  'MillerBryan': 'SMWLV',
#  'MillerChris': 'IS',
#  'MinnitiDante': 'TVS',
#  'ModjazMaryam': 'SL',
#  'MoeyensJoachim': 'IS',
#  'MommertMichael': 'Galaxies',
#  'MonacoLorenzo': 'SS',
#  'MonetDavid': 'Galaxies',
#  'MoniezMarc': 'Galaxies',
#  'MorettiAlberto': 'SMWLV',
#  'MorettiMariaIda': 'SMWLV',
#  'MorrisDave': 'TVS',
#  'MorrisGlenn': 'TVS',
#  'MorrisonChristopher': 'Galaxies',
#  'MortlockDaniel': 'DESC',
#  'MoskovitzNicholas': 'SMWLV',
#  'MottaVeronica': 'SMWLV',
#  'MuellerBeatrice': 'SMWLV',
#  'MukadamAnjum': 'SMWLV',
#  'MundellCarole': 'SMWLV',
#  'MunozRicardo': 'SMWLV',
#  'MunozRobertoPablo': 'AGN',
#  'MunozarArancibiaAlejandra': 'TVS',
#  'MuravevaTatiana': 'SMWLV',
#  'MurgiaSimona': 'SMWLV',
#  'MusellaIlaria': 'AGN',
#  'NaiduShantanu': 'SMWLV',
#  'NantaisJulieBeth': 'TVS',
#  'NapolitanoNicola': 'SMWLV',
#  'NarayanGautham': 'TVS',
#  'NaylorTim': 'IS',
#  'NeilsenEric': 'TVS',
#  'NeveuJeremy': 'TVS',
#  'NewmanJeffrey': 'SS',
#  'NeyrinckMark': 'IS',
#  'NiQingling': 'DESC',
#  'NicholBob': 'DESC',
#  'NiederhoferFlorian': 'TVS',
#  'NierenbergAnna': 'SMWLV',
#  'NightingaleJames': 'SMWLV',
#  'NikolaevSergei': 'Galaxies',
#  'NissankeSamaya': 'TVS',
#  'NomerotskiAndrei': 'TVS',
#  'NormanDara': 'TVS',
#  'NugentPeter': 'AGN',
#  'NussEric': 'IS',
#  "O'ConnorPaul": 'SMWLV',
#  'ObricMirela': 'SMWLV',
#  'OfekEranO.': 'Galaxies',
#  'OgandoRicardo': 'SL',
#  'OguriMasamune': 'Galaxies',
#  'OjalaElle': 'Galaxies',
#  'OlivierScot': 'TVS',
#  'OlkinCatherine': 'TVS',
#  'OlsenKnut': 'Galaxies',
#  'OlszewskiEdward': 'TVS',
#  'OluseyiHakeem': 'IS',
#  'PadillaNelson': 'IS',
#  'PageGary': 'TVS',
#  'PandaSwayamtrupta': 'DESC',
#  'PankowChris': 'DESC',
#  'PapovichCasey': 'IS',
#  'ParkHyeYun': 'IS',
#  'ParkerAlex': 'DESC',
#  'ParrentJerod': 'SMWLV',
#  'ParsonsSteven': 'SMWLV',
#  'PastorelloAndrea': 'AGN',
#  'PayneMatthew': 'AGN',
#  'PedersenEske': 'TVS',
#  'PeirisHiranya': 'DESC',
#  'Penna-LimaMariana': 'TVS',
#  'PepperJoshua': 'SMWLV',
#  'PerlmutterSaul': 'Galaxies',
#  'PerrefortDaniel': 'Galaxies',
#  'PesensonMisha': 'SMWLV',
#  'PetersChristina': 'SMWLV',
#  'PetersonJohn': 'SMWLV',
#  'PetitJean-Marc': 'SMWLV',
#  'PetryCathy': 'SS',
#  'PieresAdriano': 'TVS',
#  'PignataGiuliano': 'TVS',
#  'PiranomonteSilvia': 'Galaxies',
#  'PironFrederic': 'TVS',
#  'PlavchanPeter': 'IS',
#  'PlazasAndres': 'SMWLV',
#  'PonderKara': 'TVS',
#  'PopeAdrian': 'SS',
#  'PopovicLuka': 'SS',
#  'PowerChris': 'SMWLV',
#  'PrisinzanoLoredana': 'SMWLV',
#  'ProtopapasPavlos': 'SMWLV',
#  'ProuzaMichael': 'SMWLV',
#  'PrsaAndrej': 'DESC',
#  'PtakAndrew': 'AGN',
#  'PuckettAndy': 'AGN',
#  'PuziaThomas': 'TVS',
#  'QuataertEliot': 'DESC',
#  'QuinnTom': 'DESC',
#  'RabusMarkus': 'IS',
#  'RagozzineDarin': 'SS',
#  'RahmanMubdi': 'SL',
#  'RaiteriClaudiaM.': 'SS',
#  'RajMariaAngela': 'SMWLV',
#  'RajagopalJayadev': 'SMWLV',
#  'RamirezAmelia': 'TVS',
#  'RasmussenAndrew': 'AGN',
#  'RasmussenAndy': 'SMWLV',
#  'RattenburyNicholas': 'SMWLV',
#  'RauArne': 'IS',
#  'ReachWilliam': 'IS',
#  'RebbapragadaUmaa': 'TVS',
#  'ReddyNaveen': 'SMWLV',
#  'RegnaultNicolas': 'SMWLV',
#  'ReilKevin': 'TVS',
#  'ReissDavid': 'SS',
#  'RestArmin': 'Galaxies',
#  'RhoadsJamesE.': 'Galaxies',
#  'RhodesJason': 'SL',
#  'RichR.Michael': 'TVS',
#  'RichardsGordon': 'DESC',
#  'RichardsJoseph': 'SMWLV',
#  'RichardsMercedes': 'SMWLV',
#  'RichterMatt': 'DESC',
#  'RickerPaul': 'AGN',
#  'RicolJean-Stephane': 'Galaxies',
#  'RidgwayStephen': 'DESC',
#  'RiedelAdric': 'DESC',
#  'RighiChiara': 'AGN',
#  'RitzSteve': 'IS',
#  'RivkinAndy': 'TVS',
#  'RobertsonBrant': 'SMWLV',
#  'RobothamAaron': 'SMWLV',
#  'RockosiConstance': 'SL',
#  'RodriguezJoseph': 'SL',
#  'RojoPatricio': 'SMWLV',
#  'RomanAlexandre': 'SMWLV',
#  'RomaniRoger': 'DESC',
#  'RoncarelliMauro': 'Galaxies',
#  'RoodmanAaron': 'TVS',
#  'RosingWayne': 'DESC',
#  'RossiGustavoBenedetti': 'DESC',
#  'RoucelleCecile': 'Galaxies',
#  'RozoEduardo': 'TVS',
#  'RunnoeJessie': 'Galaxies',
#  'RuppertDavid': 'SL',
#  'RutkowskiMichael': 'TVS',
#  'RykoffEli': 'DESC',
#  'SaccoGiuseppe': 'SS',
#  'SahaAbi': 'SMWLV',
#  'SaintongeAmelie': 'SMWLV',
#  'SaitoRoberto': 'SMWLV',
#  'SakoMasao': 'TVS',
#  'SalafiaOmSharan': 'SS',
#  'SalimSamir': 'AGN',
#  'SamarasinhaNalin': 'TVS',
#  'SanchezJavier': 'Galaxies',
#  'SantiagoBasilio': 'DESC',
#  'SarajediniAta': 'SS',
#  'SaridGal': 'TVS',
#  'SasselovDimitar': 'SMWLV',
#  'ScargleJeffrey': 'SMWLV',
#  'SchaferChad': 'TVS',
#  'SchambeauCharles': 'SS',
#  'SchechterPaul': 'DESC',
#  'SchindlerJan-Torge': 'DESC',
#  'SchmidtEdward': 'SMWLV',
#  'SchmidtSam': 'SMWLV',
#  'SchmidtSamuel': 'DESC',
#  'SchneiderDon': 'IS',
#  'SchneiderMichael': 'DESC',
#  'SchwambMeg': 'DESC',
#  'ScowenPaul': 'IS',
#  'ScrantonRyan': 'DESC',
#  'ScudderJillian': 'AGN',
#  'SeamanRob': 'DESC',
#  'SeljakUros': 'SMWLV',
#  'SembroskiGlenn': 'SMWLV',
#  'SerenoMauro': 'IS',
#  'SesarBranimir': 'TVS',
#  'SethAnil': 'TVS',
#  'ShafterAllenW.': 'TVS',
#  'ShamirLior': 'SMWLV',
#  'SheldonErin': 'SMWLV',
#  'ShemmerOhad': 'DESC',
#  'ShenKen': 'DESC',
#  'SheppardScott': 'DESC',
#  'ShipseyIan': 'AGN',
#  'ShirleyRaphael': 'Galaxies',
#  'ShporerAvi': 'SMWLV',
#  'SickJonathan': 'SMWLV',
#  'SiemiginowskaAneta': 'Galaxies',
#  'SilvaDavid': 'SS',
#  'SilvestriNicole': 'Galaxies',
#  'SimetMelanie': 'SS',
#  'SimonJoshuaD.': 'TVS',
#  'SingerLeo': 'SS',
#  'SlaterColin': 'DESC',
#  'SlosarAnze': 'TVS',
#  'SmarttStephen': 'TVS',
#  'SmithChris': 'DESC',
#  'SmithGraham': 'TVS',
#  'SmithHoward': 'TVS',
#  'SmithJ.Allyn': 'SS',
#  'SmithKen': 'IS',
#  'SmithNathan': 'DESC',
#  'SmothermanHayden': 'TVS',
#  'SnodgrassColin': 'TVS',
#  'SnyderGreg': 'DESC',
#  'SobeckJennifer': 'SMWLV',
#  'SolarzAleksandra': 'SMWLV',
#  'SolontoiMike': 'TVS',
#  'SonnefeldAlessandro': 'IS',
#  'SoraisamMonika': 'AGN',
#  'SordoRosanna': 'SS',
#  'SpergelDavid': 'DESC',
#  'SpitzAnna': 'SS',
#  'StanfordAdam': 'TVS',
#  'StassunKeivan': 'SMWLV',
#  'SteckloffJordan': 'DESC',
#  'SteeghsDanny': 'SS',
#  'SteenbruggeKatrien': 'Galaxies',
#  'SternAlan': 'Galaxies',
#  'StottJohn': 'SMWLV',
#  'StraderJay': 'SMWLV',
#  'StrattaGiulia': 'TVS',
#  'StraussMichael': 'SMWLV',
#  'StreetRachel': 'DESC',
#  'StuartScott': 'AGN',
#  'StubbsChristopher': 'IS',
#  'SubasavageJohn': 'DESC',
#  'SullivanMark': 'SMWLV',
#  'SzaboRobert': 'TVS',
#  'SzkodyPaula': 'SMWLV',
#  'TakHyungsuk': 'SMWLV',
#  'TamayoDaniel': 'Galaxies',
#  'TaranuDan': 'TVS',
#  'TejosNicolas': 'DESC',
#  'TheilerJamesP.': 'TVS',
#  'ThirouinAudrey': 'SS',
#  'ThomasCristina': 'TVS',
#  'ThormanPaul': 'Galaxies',
#  'ThorstensenJohnRobert': 'SS',
#  'TisseraPatricia': 'DESC',
#  'TreisterEzequiel': 'SMWLV',
#  'TreuTommaso': 'SMWLV',
#  'TrillingDavid': 'SMWLV',
#  'TrimbleVirginia': 'SS',
#  'TrouilleLaura': 'TVS',
#  'TroxelMichael': 'IS',
#  'TrujilloChad': 'IS',
#  'TrujilloIgnacio': 'SS',
#  'TsaprasYiannis': 'SL',
#  'TsybychevDmitri': 'AGN',
#  'TysonTony': 'DESC',
#  'UrryMeg': 'Galaxies',
#  'ValentiStefano': 'AGN',
#  'VallenariAntonella': 'DESC',
#  'VandenBerkDan': 'SS',
#  'VenutiLaura': 'TVS',
#  'VeresPeter': 'Galaxies',
#  'VermaAprajita': 'Galaxies',
#  'VestrandTom': 'TVS',
#  'VianelloGiacomo': 'SS',
#  'VieiraJoaquin': 'DESC',
#  'VilaltaRicardo': 'DESC',
#  'VillarVictoriaAshley': 'Galaxies',
#  'VillarrealAntonio': 'SMWLV',
#  'VinkJorick': 'SMWLV',
#  'VivasKathy': 'AGN',
#  'VogeleyMichael': 'TVS',
#  'VolkKat': 'IS',
#  'VonDerLindenAnja': 'DESC',
#  'VrastilMichal': 'TVS',
#  'WainscoatRichard': 'SS',
#  'WalkerAlistair': 'DESC',
#  'WalkowiczLucianne': 'Galaxies',
#  'WallersteinGeorge': 'IS',
#  'WallinJohn': 'AGN',
#  'WalterChris': 'SL',
#  'WaltonNicholas': 'IS',
#  'WangYun': 'SMWLV',
#  'WassermanLarry': 'SMWLV',
#  'WeatherillDaniel': 'TVS',
#  'WebsterRachel': 'SMWLV',
#  'WechslerRisa': 'SMWLV',
#  'WeinbergMartin': 'SMWLV',
#  'WeinerBen': 'SMWLV',
#  'WellsMark': 'TVS',
#  'WenausTorre': 'Galaxies',
#  'WernerNorbert': 'SMWLV',
#  'WestAndrew': 'SMWLV',
#  'WiesnerMatthew': 'TVS',
#  'WildVivienne': 'AGN',
#  'WilliamsBen': 'SL',
#  'WilliamsRobert': 'DESC',
#  'WilligerGerard': 'TVS',
#  'WillmanBeth': 'SMWLV',
#  'WittmanDavid': 'SMWLV',
#  'WolpertRobert': 'Galaxies',
#  'WomackMaria': 'TVS',
#  'Wood-VaseyMichael': 'TVS',
#  'WoodroofeMichael': 'SS',
#  'WozniakPrzemek': 'Galaxies',
#  'Yanamandra-FisherPadma': 'SMWLV',
#  'YangGuang': 'SMWLV',
#  'YangSheng': 'IS',
#  'YeQuan-Zhi': 'SS',
#  'YoachimPeter': 'SL',
#  'YoungDavid': 'SMWLV',
#  'YoungLeslie': 'SMWLV',
#  'YuWeixiang': 'SMWLV',
#  'ZabludoffAnn': 'SMWLV',
#  'ZaudererAshley': 'DESC',
#  'ZehaviIdit': 'SS',
#  'ZentnerAndrew': 'Galaxies',
#  'ZhanHu': 'SS',
#  'ZhaoGong-Bo': 'TVS',
#  'ZhengZhenia': 'AGN',
#  'ZoccaliManuela': 'SS',
#  'ZolotovAdi': 'Galaxies',
#  'ZuntzJoe': 'SMWLV',
#  'daCostaLuiz': 'Galaxies',
#  'deAndradeQueirozAnnaBarbara': 'AGN',
#  'deJongRoelof': 'DESC',
#  'deVal-BorroMiguel': 'TVS',
#  'deVriesWim': 'TVS'}

# %%
nx.set_node_attributes(G, p, "SC")

# %%
nx.set_node_attributes(G, countrylabel, "Nationality")

# %%
G.nodes.data()
# Out:
# NodeDataView({'AbdullaGhaleb': {'SC': 'TVS', 'Nationality': 'US'}, 'AbellPaulAlexander': {'SC': 'SS', 'Nationality': 'US'}, 'AgolEric': {'SC': 'TVS', 'Nationality': 'US'}, 'AguenaMichel': {'SC': 'DESC', 'Nationality': 'BR'}, 'AguerosMarcel': {'SC': 'TVS', 'Nationality': 'US'}, 'AkhlaghiMohammad': {'SC': 'Galaxies', 'Nationality': 'ES'}, 'AlderingGreg': {'SC': 'DESC', 'Nationality': 'US'}, 'AllenMark': {'SC': 'SL', 'Nationality': 'US'}, 'AllenSteven': {'SC': 'DESC', 'Nationality': 'US'}, 'AlmeydaTriana': {'SC': 'AGN', 'Nationality': 'UK'}, 'Alonso-GarciaJavier': {'SC': 'TVS', 'Nationality': 'CL'}, 'AlonsoDavid': {'SC': 'DESC', 'Nationality': 'UK'}, 'AnderesEthan': {'SC': 'SMWLV', 'Nationality': 'US'}, 'AndersonScott': {'SC': 'IS', 'Nationality': 'US'}, 'AnguitaTimo': {'SC': 'AGN', 'Nationality': 'CL'}, 'AnsariReza': {'SC': 'Galaxies', 'Nationality': 'FR'}, 'AntilogusPierre': {'SC': 'DESC', 'Nationality': 'FR'}, 'AntoniucciSimone': {'SC': 'DESC', 'Nationality': 'IT'}, 'AravenaManuel': {'SC': 'TVS', 'Nationality': 'CL'}, 'ArcaviIair': {'SC': 'Galaxies', 'Nationality': 'IS'}, 'ArdilaDavid': {'SC': 'TVS', 'Nationality': 'US'}, 'ArgudoFernandezMariadelCarmen': {'SC': 'SMWLV', 'Nationality': 'CL'}, 'ArmusLee': {'SC': 'SMWLV', 'Nationality': 'US'}, 'ArnettW.David': {'SC': 'Galaxies', 'Nationality': 'US'}, 'AssefRoberto': {'SC': 'Galaxies', 'Nationality': 'CL'}, 'AstierPierre': {'SC': 'TVS', 'Nationality': 'FR'}, 'AubourgEric': {'SC': 'AGN', 'Nationality': 'FR'}, 'AvestruzCamille': {'SC': 'DESC', 'Nationality': 'US'}, 'AwanHumna': {'SC': 'SL', 'Nationality': 'US'}, 'AyeMichael': {'SC': 'DESC', 'Nationality': 'US'}, 'BabuJogesh': {'SC': 'DESC', 'Nationality': 'US'}, 'BaileyStephen': {'SC': 'SS', 'Nationality': 'US'}, 'BailynCharles': {'SC': 'IS', 'Nationality': 'US'}, 'BallandChristophe': {'SC': 'IS', 'Nationality': 'FR'}, 'BallantyneDavid': {'SC': 'TVS', 'Nationality': 'US'}, 'BalmaverdeBarbara': {'SC': 'DESC', 'Nationality': 'IT'}, 'BaloghMichael': {'SC': 'AGN', 'Nationality': 'CA'}, 'BaltzTed': {'SC': 'TVS', 'Nationality': 'US'}, 'BandaMartin': {'SC': 'Galaxies', 'Nationality': 'BR'}, 'BanerjiManda': {'SC': 'SL', 'Nationality': 'UK'}, 'BannisterMichele': {'SC': 'SS', 'Nationality': 'UK'}, 'BarbaRodolfo': {'SC': 'Galaxies', 'Nationality': 'CL'}, 'BarbieriMauro': {'SC': 'SS', 'Nationality': 'CL'}, 'BardDeborah': {'SC': 'SMWLV', 'Nationality': 'US'}, 'BarrauAurelien': {'SC': 'SMWLV', 'Nationality': 'FR'}, 'BarreraLuis': {'SC': 'SMWLV', 'Nationality': 'CL'}, 'BarrientosFelipe': {'SC': 'SMWLV', 'Nationality': 'CL'}, 'BarthAaron': {'SC': 'DESC', 'Nationality': 'US'}, 'BartlettJames': {'SC': 'DESC', 'Nationality': 'FR'}, 'BassGideon': {'SC': 'Galaxies', 'Nationality': 'US'}, 'BauerFranz': {'SC': 'AGN', 'Nationality': 'CL'}, 'BaumerMichael': {'SC': 'Galaxies', 'Nationality': 'US'}, 'BeanRachel': {'SC': 'DESC', 'Nationality': 'US'}, 'BechtolKeith': {'SC': 'TVS', 'Nationality': 'US'}, 'BeckerAndrew': {'SC': 'AGN', 'Nationality': 'US'}, 'BeclaJacek': {'SC': 'DESC', 'Nationality': 'US'}, 'BeersTimothyC.': {'SC': 'SS', 'Nationality': 'US'}, 'BellEric': {'SC': 'TVS', 'Nationality': 'US'}, 'BellKeaton': {'SC': 'DESC', 'Nationality': 'US'}, 'BellagambaFabio': {'SC': 'IS', 'Nationality': 'IT'}, 'BellmEric': {'SC': 'SMWLV', 'Nationality': 'US'}, 'BelokurovVasily': {'SC': 'SMWLV', 'Nationality': 'UK'}, 'BergerEdo': {'SC': 'SMWLV', 'Nationality': 'US'}, 'BernsteinGary': {'SC': 'SMWLV', 'Nationality': 'US'}, 'BersierDavid': {'SC': 'TVS', 'Nationality': 'UK'}, 'BetouleMarc': {'SC': 'Galaxies', 'Nationality': 'FR'}, 'BiancoFederica': {'SC': 'TVS', 'Nationality': 'US'}, 'BianconiMatteo': {'SC': 'SMWLV', 'Nationality': 'UK'}, 'BiswasRahul': {'SC': 'TVS', 'Nationality': 'SW'}, 'BivianoAndrea': {'SC': 'SS', 'Nationality': 'IT'}, 'BlancGuillaume': {'SC': 'TVS', 'Nationality': 'FR'}, 'BlandfordRoger': {'SC': 'DESC', 'Nationality': 'US'}, 'BlantonMichaelRogers': {'SC': 'IS', 'Nationality': 'US'}, 'BlazekJonathan': {'SC': 'TVS', 'Nationality': 'US'}, 'BloomJosh':  ...

# %%
pn = np.array(list(p[c] for c in affiliationsDF.index.values))

# %%
pn
# Out:
# array(['TVS', 'SS', 'TVS', 'DESC', 'TVS', 'Galaxies', 'DESC', 'SL',
#        'DESC', 'AGN', 'TVS', 'DESC', 'SMWLV', 'IS', 'AGN', 'Galaxies',
#        'DESC', 'DESC', 'TVS', 'Galaxies', 'TVS', 'SMWLV', 'SMWLV',
#        'Galaxies', 'Galaxies', 'TVS', 'AGN', 'DESC', 'SL', 'DESC', 'DESC',
#        'SS', 'IS', 'IS', 'TVS', 'DESC', 'AGN', 'TVS', 'Galaxies', 'SL',
#        'SS', 'Galaxies', 'SS', 'SMWLV', 'SMWLV', 'SMWLV', 'SMWLV', 'DESC',
#        'DESC', 'Galaxies', 'AGN', 'Galaxies', 'DESC', 'TVS', 'AGN',
#        'DESC', 'SS', 'TVS', 'DESC', 'IS', 'SMWLV', 'SMWLV', 'SMWLV',
#        'SMWLV', 'TVS', 'Galaxies', 'TVS', 'SMWLV', 'TVS', 'SS', 'TVS',
#        'DESC', 'IS', 'TVS', 'Galaxies', 'DESC', 'Galaxies', 'DESC', 'SL',
#        'Galaxies', 'DESC', 'TVS', 'SMWLV', 'SMWLV', 'SMWLV', 'SS',
#        'SMWLV', 'SS', 'TVS', 'DESC', 'SMWLV', 'SMWLV', 'TVS', 'TVS',
#        'Galaxies', 'DESC', 'IS', 'Galaxies', 'SS', 'SS', 'TVS', 'DESC',
#        'Galaxies', 'SL', 'DESC', 'TVS', 'Galaxies', 'AGN', 'IS',
#        'Galaxies', 'DESC', 'SMWLV', 'SMWLV', 'TVS', 'AGN', 'Galaxies',
#        'SS', 'TVS', 'SS', 'IS', 'AGN', 'IS', 'SS', 'SS', 'DESC', 'SMWLV',
#        'SMWLV', 'DESC', 'SL', 'SMWLV', 'SMWLV', 'DESC', 'IS', 'SMWLV',
#        'SMWLV', 'IS', 'TVS', 'DESC', 'SMWLV', 'SMWLV', 'DESC', 'SMWLV',
#        'SMWLV', 'SMWLV', 'SMWLV', 'SMWLV', 'TVS', 'DESC', 'SMWLV',
#        'SMWLV', 'Galaxies', 'SMWLV', 'SMWLV', 'TVS', 'TVS', 'Galaxies',
#        'SMWLV', 'SMWLV', 'DESC', 'SL', 'AGN', 'IS', 'TVS', 'IS', 'SS',
#        'DESC', 'TVS', 'DESC', 'TVS', 'SMWLV', 'SMWLV', 'TVS', 'SMWLV',
#        'AGN', 'TVS', 'SMWLV', 'SMWLV', 'IS', 'SMWLV', 'DESC', 'SMWLV',
#        'SMWLV', 'TVS', 'TVS', 'DESC', 'TVS', 'DESC', 'DESC', 'DESC',
#        'DESC', 'DESC', 'SS', 'Galaxies', 'SMWLV', 'SMWLV', 'Galaxies',
#        'TVS', 'SS', 'SS', 'TVS', 'IS', 'SMWLV', 'SMWLV', 'SL', 'AGN',
#        'TVS', 'SS', 'TVS', 'AGN', 'TVS', 'TVS', 'TVS', 'SMWLV', 'SS',
#        'DESC', 'SMWLV', 'SMWLV', 'TVS', 'DESC', 'SMWLV', 'SMWLV',
#        'Galaxies', 'Galaxies', 'Galaxies', 'DESC', 'DESC', 'SMWLV',
#        'SMWLV', 'Galaxies', 'SMWLV', 'SMWLV', 'SMWLV', 'SMWLV', 'TVS',
#        'SS', 'AGN', 'SMWLV', 'SMWLV', 'TVS', 'SMWLV', 'SMWLV', 'DESC',
#        'Galaxies', 'SS', 'SS', 'Galaxies', 'SL', 'SMWLV', 'Galaxies',
#        'Galaxies', 'DESC', 'SMWLV', 'TVS', 'IS', 'SL', 'TVS', 'DESC',
#        'SS', 'DESC', 'SMWLV', 'SMWLV', 'TVS', 'Galaxies', 'SMWLV',
#        'SMWLV', 'TVS', 'DESC', 'DESC', 'SS', 'TVS', 'SL', 'DESC', 'SS',
#        'AGN', 'IS', 'IS', 'TVS', 'SL', 'AGN', 'SMWLV', 'SS', 'DESC', 'SL',
#        'IS', 'DESC', 'Galaxies', 'SMWLV', 'SMWLV', 'Galaxies', 'DESC',
#        'SMWLV', 'Galaxies', 'DESC', 'TVS', 'SMWLV', 'DESC', 'DESC', 'TVS',
#        'DESC', 'TVS', 'TVS', 'TVS', 'SS', 'IS', 'TVS', 'SL', 'SMWLV',
#        'SMWLV', 'TVS', 'SS', 'Galaxies', 'TVS', 'DESC', 'TVS', 'DESC',
#        'TVS', 'DESC', 'Galaxies', 'SMWLV', 'SMWLV', 'SMWLV', 'SMWLV',
#        'TVS', 'IS', 'SS', 'TVS', 'TVS', 'SMWLV', 'TVS', 'SS', 'DESC',
#        'DESC', 'Galaxies', 'SMWLV', 'SMWLV', 'SMWLV', 'SMWLV', 'SMWLV',
#        'SMWLV', 'DESC', 'SL', 'Galaxies', 'SL', 'SL', 'TVS', 'SMWLV',
#        'SMWLV', 'IS', 'TVS', 'SS', 'SS', 'TVS', 'IS', 'AGN', 'Galaxies',
#        'IS', 'Galaxies', 'AGN', 'SS', 'TVS', 'SMWLV', 'TVS', 'DESC', 'IS',
#        'TVS', 'IS', 'TVS', 'SS', 'SMWLV', 'SS', 'Galaxies', 'Galaxies',
#        'SMWLV', 'SMWLV', 'DESC', 'TVS', 'SMWLV', 'SMWLV', 'DESC', 'SS',
#        'DESC', 'TVS', 'SS', 'AGN', 'SMWLV', 'SMWLV', 'SS', 'SS', 'TVS',
#        'TVS', 'SS', 'TVS', 'TVS', 'Galaxies', 'DESC', 'SMWLV', 'SMWLV',
#        'TVS', 'DESC', 'SL', 'DESC', 'DESC', 'SMWLV', 'SMWLV', 'Galaxies',
#        'IS', 'AGN', 'SS', 'SL', 'SMWLV', 'TVS', 'SMWLV', 'DESC', 'IS',
#        'TVS', 'Galaxies', 'IS', 'DESC', 'SMWLV', 'SMWLV', 'Galaxies',
#        'DESC', 'AGN', 'SS', 'DESC', 'IS', 'SL', 'TVS', 'DESC', 'TVS',
#        'Galaxies', 'AGN', 'DESC', 'TVS', 'DESC', 'TVS', 'SMWLV', 'SMWLV',
#        'SMWLV', 'SMWLV', 'TVS', 'Galaxies', 'DESC', 'SS', 'IS', 'SL',
#        'SMWLV', 'SMWLV', 'SMWLV', 'SMWLV', 'IS', 'DESC', 'SS', 'SMWLV',
#        'SMWLV', 'TVS', 'DESC', 'SS', 'SMWLV', 'SMWLV', 'SMWLV', 'DESC',
#        'SMWLV', 'TVS', 'DESC', 'TVS', 'TVS', 'Galaxies', 'IS', 'Galaxies',
#        'TVS', 'Galaxies', 'SL', 'SS', 'Galaxies', 'DESC', 'TVS', 'TVS',
#        'SMWLV', 'SMWLV', 'SL', 'AGN', 'DESC', 'SMWLV', 'DESC', 'SMWLV',
#        'SMWLV', 'Galaxies', 'SS', 'TVS', 'DESC', 'TVS', 'DESC', 'DESC',
#        'IS', 'TVS', 'DESC', 'Galaxies', 'TVS', 'SMWLV', 'SMWLV', 'TVS',
#        'AGN', 'SMWLV', 'AGN', 'Galaxies', 'SS', 'DESC', 'SMWLV', 'SMWLV',
#        'AGN', 'DESC', 'DESC', 'SL', 'IS', 'DESC', 'DESC', 'DESC', 'SMWLV',
#        'TVS', 'SS', 'IS', 'DESC', 'SS', 'DESC', 'Galaxies', 'AGN', 'AGN',
#        'SS', 'SMWLV', 'SMWLV', 'DESC', 'DESC', 'SMWLV', 'IS', 'TVS', 'SL',
#        'IS', 'Galaxies', 'SS', 'Galaxies', 'Galaxies', 'SMWLV', 'SMWLV',
#        'TVS', 'TVS', 'Galaxies', 'DESC', 'SMWLV', 'SMWLV', 'SMWLV',
#        'SMWLV', 'SMWLV', 'SMWLV', 'AGN', 'TVS', 'SMWLV', 'SMWLV', 'AGN',
#        'SMWLV', 'TVS', 'SMWLV', 'TVS', 'IS', 'TVS', 'TVS', 'SS', 'IS',
#        'DESC', 'DESC', 'TVS', 'SMWLV', 'SMWLV', 'Galaxies', 'TVS', 'TVS',
#        'TVS', 'AGN', 'IS', 'SMWLV', 'SMWLV', 'Galaxies', 'SL', 'Galaxies',
#        'Galaxies', 'TVS', 'TVS', 'Galaxies', 'TVS', 'IS', 'IS', 'TVS',
#        'DESC', 'DESC', 'IS', 'IS', 'DESC', 'SMWLV', 'SMWLV', 'AGN', 'AGN',
#        'TVS', 'DESC', 'TVS', 'SMWLV', 'Galaxies', 'Galaxies', 'SMWLV',
#        'SMWLV', 'SMWLV', 'SMWLV', 'SS', 'TVS', 'TVS', 'Galaxies', 'TVS',
#        'IS', 'SMWLV', 'TVS', 'SS', 'SS', 'SMWLV', 'SMWLV', 'SMWLV',
#        'SMWLV', 'DESC', 'AGN', 'AGN', 'TVS', 'DESC', 'DESC', 'IS', 'SS',
#        'SL', 'SS', 'SMWLV', 'SMWLV', 'TVS', 'AGN', 'SMWLV', 'SMWLV', 'IS',
#        'IS', 'TVS', 'SMWLV', 'SMWLV', 'TVS', 'SS', 'Galaxies', 'Galaxies',
#        'SL', 'TVS', 'DESC', 'SMWLV', 'SMWLV', 'DESC', 'AGN', 'Galaxies',
#        'DESC', 'DESC', 'AGN', 'IS', 'TVS', 'SMWLV', 'SMWLV', 'SL', 'SL',
#        'SMWLV', 'SMWLV', 'DESC', 'Galaxies', 'TVS', 'DESC', 'DESC',
#        'Galaxies', 'TVS', 'Galaxies', 'SL', 'TVS', 'DESC', 'SS', 'SMWLV',
#        'SMWLV', 'SMWLV', 'TVS', 'SS', 'AGN', 'TVS', 'Galaxies', 'DESC',
#        'SS', 'TVS', 'SMWLV', 'SMWLV', 'TVS', 'SS', 'DESC', 'DESC',
#        'SMWLV', 'SMWLV', 'DESC', 'IS', 'DESC', 'DESC', 'IS', 'DESC',
#        'AGN', 'DESC', 'SMWLV', 'SMWLV', 'IS', 'TVS', 'TVS', 'TVS',
#        'SMWLV', 'SMWLV', 'DESC', 'DESC', 'DESC', 'AGN', 'Galaxies',
#        'SMWLV', 'SMWLV', 'Galaxies', 'SS', 'Galaxies', 'SS', 'TVS', 'SS',
#        'DESC', 'TVS', 'TVS', 'DESC', 'TVS', 'TVS', 'SS', 'IS', 'DESC',
#        'TVS', 'TVS', 'DESC', 'SMWLV', 'SMWLV', 'TVS', 'IS', 'AGN', 'SS',
#        'DESC', 'SS', 'TVS', 'SMWLV', 'DESC', 'SS', 'Galaxies', 'Galaxies',
#        'SMWLV', 'SMWLV', 'TVS', 'SMWLV', 'DESC', 'AGN', 'IS', 'DESC',
#        'SMWLV', 'TVS', 'SMWLV', 'SMWLV', 'Galaxies', 'TVS', 'DESC', 'TVS',
#        'SS', 'TVS', 'Galaxies', 'SS', 'DESC', 'SMWLV', 'SMWLV', 'SMWLV',
#        'SS', 'TVS', 'IS', 'IS', 'SS', 'SL', 'AGN', 'DESC', 'Galaxies',
#        'AGN', 'DESC', 'SS', 'TVS', 'Galaxies', 'Galaxies', 'TVS', 'SS',
#        'DESC', 'DESC', 'Galaxies', 'SMWLV', 'SMWLV', 'AGN', 'TVS', 'IS',
#        'DESC', 'TVS', 'SS', 'DESC', 'Galaxies', 'IS', 'AGN', 'SL', 'IS',
#        'SMWLV', 'SMWLV', 'TVS', 'SMWLV', 'SMWLV', 'SMWLV', 'SMWLV', 'TVS',
#        'Galaxies', 'SMWLV', 'SMWLV', 'TVS', 'AGN', 'SL', 'DESC', 'TVS',
#        'SMWLV', 'SMWLV', 'Galaxies', 'TVS', 'TVS', 'SS', 'Galaxies',
#        'SMWLV', 'SMWLV', 'IS', 'SS', 'SL', 'SMWLV', 'SMWLV', 'SMWLV',
#        'SMWLV', 'DESC', 'SS', 'Galaxies', 'SS', 'TVS', 'AGN', 'SS',
#        'Galaxies', 'SMWLV', 'Galaxies', 'AGN', 'DESC', 'TVS', 'TVS'],
#       dtype='<U8')

# %%
G.nodes
# Out:
# NodeView(('AbdullaGhaleb', 'AbellPaulAlexander', 'AgolEric', 'AguenaMichel', 'AguerosMarcel', 'AkhlaghiMohammad', 'AlderingGreg', 'AllenMark', 'AllenSteven', 'AlmeydaTriana', 'Alonso-GarciaJavier', 'AlonsoDavid', 'AnderesEthan', 'AndersonScott', 'AnguitaTimo', 'AnsariReza', 'AntilogusPierre', 'AntoniucciSimone', 'AravenaManuel', 'ArcaviIair', 'ArdilaDavid', 'ArgudoFernandezMariadelCarmen', 'ArmusLee', 'ArnettW.David', 'AssefRoberto', 'AstierPierre', 'AubourgEric', 'AvestruzCamille', 'AwanHumna', 'AyeMichael', 'BabuJogesh', 'BaileyStephen', 'BailynCharles', 'BallandChristophe', 'BallantyneDavid', 'BalmaverdeBarbara', 'BaloghMichael', 'BaltzTed', 'BandaMartin', 'BanerjiManda', 'BannisterMichele', 'BarbaRodolfo', 'BarbieriMauro', 'BardDeborah', 'BarrauAurelien', 'BarreraLuis', 'BarrientosFelipe', 'BarthAaron', 'BartlettJames', 'BassGideon', 'BauerFranz', 'BaumerMichael', 'BeanRachel', 'BechtolKeith', 'BeckerAndrew', 'BeclaJacek', 'BeersTimothyC.', 'BellEric', 'BellKeaton', 'BellagambaFabio', 'BellmEric', 'BelokurovVasily', 'BergerEdo', 'BernsteinGary', 'BersierDavid', 'BetouleMarc', 'BiancoFederica', 'BianconiMatteo', 'BiswasRahul', 'BivianoAndrea', 'BlancGuillaume', 'BlandfordRoger', 'BlantonMichaelRogers', 'BlazekJonathan', 'BloomJosh', 'BlumBob', 'BochanskiJohn', 'BodewitsDennis', 'BoeshaarPatricia', 'BolinBryce', 'BondHoward', 'BongardSebastien', 'BonitoRosaria', 'BonoGiuseppe', 'BoquienMederic', 'BorglandAnders', 'BorneKirk', 'BorosonTodd', 'BoschJames', 'BoschJim', 'BoseMaitrayee', 'BoshAmanda', 'BotticellaMariaTeresa', 'BoutignyDominique', 'BowlerRebecca', 'BradacMarusa', 'BradshawAndrew', 'BrandtNiel', 'BremerMalcolm', 'BridgeCarrie', 'BridleSarah', 'BrittChristopher', 'BrocatoEnzo', 'BrothertonMichael', 'BroughSarah', 'BrownMichael', 'BrownPeter', 'BrownTim', 'BrozovicMarina', 'BrunnerRobert', 'BudavariTamas', 'BuenodeCamargoJulioIgnacio', 'BuieMarc', 'BullPhilip', 'BullockJames', 'BurchatPatricia', 'BurgasserAdam', 'BurkeDavid', 'BurkeDouglas', 'BurninghamBen', 'ButlerNathaniel', 'CabreraGuillermo', 'CaiYongzhi', 'CalabreseErminia', 'CalamidaAnnalisa', 'CampagneJean-Eric', 'Cantat-GaudinTristan', 'CargilePhillip', 'CariniRoberta', 'CarlinJeff', 'CarnereroMartinMariaIsabel', 'Carrasco-KindMatias', 'CasettiDanaIoana', 'CassataPaolo', 'CatelanMarcio', 'CavuotiStefano', 'CenkoStephen', 'ChambaNushkia', 'ChanameJulio', 'ChangChihway', 'ChartasGeorge', 'ChenXuelei', 'ChenYen-Chi', 'ChernoffDavid', 'ChesleySteve', 'CheuElliott', 'ChiangJim', 'ChiniRolf', 'ChisariElisa', 'ChomiukLaura', 'ChornockRyan', 'ChristensenEric', 'ChuYou-Hua', 'CiardiDavid', 'CiconeClaudia', 'CiezaLucas', 'CignoniMichele', 'CioniMaria-Rosa', 'CisewskiJessi', 'ClarksonWilliam', 'ClaverChuck', 'ClaytonGeoffrey', 'ClementiniGisella', 'CloweDouglas', 'Cohen-TanugiJohann', 'CohnJoanne', 'CollettThomas', 'CombetCeline', 'ConnollyAndrew', 'ConseliceChris', 'ContrerasHantkeSergio', 'CookKem', 'CooperMichael', 'CoorayAsantha', 'CoppejansDeanne', 'CoppiPaoloSevero', 'CordesJim', 'CoughlinMichael', 'CoveyKevin', 'CowanNick', 'CuadraJorge', 'CucchiaraAntonino', 'CuiWei', 'CukMatija', 'CusanoFelice', 'Cyr-RacineFrancis-Yan', 'CzernyBozena', "D'AmmandoFilippo", "D'AndreaChris", "D'AvanzoPaolo", 'DagoretSylvie', 'DalPonteMarina', "Dall'OraMassimo", 'DanielScott', 'DavenportJames', 'DaviesJon', 'DaviesLuke', 'DaviesRoger', 'DavisChristopher', 'DawsonWilliam', 'DeCiccoDemetra', 'DeLeeNathan', 'DeMarcoOrsola', 'DeMeoFrancesca', 'DeasonAlis', 'DebattistaVictor', 'DellAntonioIan', 'DemarcoRicardo', 'DenneauLarry', 'DevriendtJulien', 'DexterJason', 'DhitalSaurav', 'DiStefanoRosanne', 'DiazTanio', 'DickinsonMark', 'DigelSeth', 'DjorgovskiGeorge', 'DoblerGreg', 'DoctorZoheyr', 'DodelsonScott', 'DonachieMartin', 'DonesLuke', 'DoreOlivier', 'DotterAaron', 'DrakeJeremy', 'DriverSimon', 'Drlica-WagnerAlex', 'DroutMaria', 'DuboisRichard', 'DunkleyJo', 'DurechJosef', 'EgglSiegfried', 'EiflerTim', 'EliasJonathan', 'EliasdottirArdis', 'ElsnerFranz', 'ElvisMartin', 'EracleousMike', 'E ...

# %%
affiliationsDF.index.values
# Out:
# array(['AbdullaGhaleb', 'AbellPaulAlexander', 'AgolEric', 'AguenaMichel',
#        'AguerosMarcel', 'AkhlaghiMohammad', 'AlderingGreg', 'AllenMark',
#        'AllenSteven', 'AlmeydaTriana', 'Alonso-GarciaJavier',
#        'AlonsoDavid', 'AnderesEthan', 'AndersonScott', 'AnguitaTimo',
#        'AnsariReza', 'AntilogusPierre', 'AntoniucciSimone',
#        'AravenaManuel', 'ArcaviIair', 'ArdilaDavid',
#        'ArgudoFernandezMariadelCarmen', 'ArmusLee', 'ArnettW.David',
#        'AssefRoberto', 'AstierPierre', 'AubourgEric', 'AvestruzCamille',
#        'AwanHumna', 'AyeMichael', 'BabuJogesh', 'BaileyStephen',
#        'BailynCharles', 'BallandChristophe', 'BallantyneDavid',
#        'BalmaverdeBarbara', 'BaloghMichael', 'BaltzTed', 'BandaMartin',
#        'BanerjiManda', 'BannisterMichele', 'BarbaRodolfo',
#        'BarbieriMauro', 'BardDeborah', 'BarrauAurelien', 'BarreraLuis',
#        'BarrientosFelipe', 'BarthAaron', 'BartlettJames', 'BassGideon',
#        'BauerFranz', 'BaumerMichael', 'BeanRachel', 'BechtolKeith',
#        'BeckerAndrew', 'BeclaJacek', 'BeersTimothyC.', 'BellEric',
#        'BellKeaton', 'BellagambaFabio', 'BellmEric', 'BelokurovVasily',
#        'BergerEdo', 'BernsteinGary', 'BersierDavid', 'BetouleMarc',
#        'BiancoFederica', 'BianconiMatteo', 'BiswasRahul', 'BivianoAndrea',
#        'BlancGuillaume', 'BlandfordRoger', 'BlantonMichaelRogers',
#        'BlazekJonathan', 'BloomJosh', 'BlumBob', 'BochanskiJohn',
#        'BodewitsDennis', 'BoeshaarPatricia', 'BolinBryce', 'BondHoward',
#        'BongardSebastien', 'BonitoRosaria', 'BonoGiuseppe',
#        'BoquienMederic', 'BorglandAnders', 'BorneKirk', 'BorosonTodd',
#        'BoschJames', 'BoschJim', 'BoseMaitrayee', 'BoshAmanda',
#        'BotticellaMariaTeresa', 'BoutignyDominique', 'BowlerRebecca',
#        'BradacMarusa', 'BradshawAndrew', 'BrandtNiel', 'BremerMalcolm',
#        'BridgeCarrie', 'BridleSarah', 'BrittChristopher', 'BrocatoEnzo',
#        'BrothertonMichael', 'BroughSarah', 'BrownMichael', 'BrownPeter',
#        'BrownTim', 'BrozovicMarina', 'BrunnerRobert', 'BudavariTamas',
#        'BuenodeCamargoJulioIgnacio', 'BuieMarc', 'BullPhilip',
#        'BullockJames', 'BurchatPatricia', 'BurgasserAdam', 'BurkeDavid',
#        'BurkeDouglas', 'BurninghamBen', 'ButlerNathaniel',
#        'CabreraGuillermo', 'CaiYongzhi', 'CalabreseErminia',
#        'CalamidaAnnalisa', 'CampagneJean-Eric', 'Cantat-GaudinTristan',
#        'CargilePhillip', 'CariniRoberta', 'CarlinJeff',
#        'CarnereroMartinMariaIsabel', 'Carrasco-KindMatias',
#        'CasettiDanaIoana', 'CassataPaolo', 'CatelanMarcio',
#        'CavuotiStefano', 'CenkoStephen', 'ChambaNushkia', 'ChanameJulio',
#        'ChangChihway', 'ChartasGeorge', 'ChenXuelei', 'ChenYen-Chi',
#        'ChernoffDavid', 'ChesleySteve', 'CheuElliott', 'ChiangJim',
#        'ChiniRolf', 'ChisariElisa', 'ChomiukLaura', 'ChornockRyan',
#        'ChristensenEric', 'ChuYou-Hua', 'CiardiDavid', 'CiconeClaudia',
#        'CiezaLucas', 'CignoniMichele', 'CioniMaria-Rosa', 'CisewskiJessi',
#        'ClarksonWilliam', 'ClaverChuck', 'ClaytonGeoffrey',
#        'ClementiniGisella', 'CloweDouglas', 'Cohen-TanugiJohann',
#        'CohnJoanne', 'CollettThomas', 'CombetCeline', 'ConnollyAndrew',
#        'ConseliceChris', 'ContrerasHantkeSergio', 'CookKem',
#        'CooperMichael', 'CoorayAsantha', 'CoppejansDeanne',
#        'CoppiPaoloSevero', 'CordesJim', 'CoughlinMichael', 'CoveyKevin',
#        'CowanNick', 'CuadraJorge', 'CucchiaraAntonino', 'CuiWei',
#        'CukMatija', 'CusanoFelice', 'Cyr-RacineFrancis-Yan',
#        'CzernyBozena', "D'AmmandoFilippo", "D'AndreaChris",
#        "D'AvanzoPaolo", 'DagoretSylvie', 'DalPonteMarina',
#        "Dall'OraMassimo", 'DanielScott', 'DavenportJames', 'DaviesJon',
#        'DaviesLuke', 'DaviesRoger', 'DavisChristopher', 'DawsonWilliam',
#        'DeCiccoDemetra', 'DeLeeNathan', 'DeMarcoOrsola', 'DeMeoFrancesca',
#        'DeasonAlis', 'DebattistaVictor', 'DellAntonioIan',
#        'DemarcoRicardo', 'DenneauLarry', 'DevriendtJulien', 'DexterJason',
#        'DhitalSaurav', 'DiStefanoRosanne', 'DiazTanio', 'DickinsonMark',
#        'DigelSeth', 'DjorgovskiGeorge', 'DoblerGreg', 'DoctorZoheyr',
#        'DodelsonScott', 'DonachieMartin', 'DonesLuke', 'DoreOlivier',
#        'DotterAaron', 'DrakeJeremy', 'DriverSimon', 'Drlica-WagnerAlex',
#        'DroutMaria', 'DuboisRichard', 'DunkleyJo', 'DurechJosef',
#        'EgglSiegfried', 'EiflerTim', 'EliasJonathan', 'EliasdottirArdis',
#        'ElsnerFranz', 'ElvisMartin', 'EracleousMike', 'EscalaAndres',
#        'EscarateMonettaPedroAntonio', 'EyheramendySusana',
#        'FabrizioMichele', 'FadelyRoss', 'FalcoEmilio', 'FanXiaohui',
#        'FarihiJay', 'FarnocchiaDavide', 'FassnachtChris', 'FeigelsonEric',
#        'FeinsteinFabrice', 'FergusonAnnette', 'FergusonHenry',
#        'FerreiraPedro', 'FinchCharlie', 'FinkelsteinSteven',
#        'FinleyDavid', 'FiorentinoGiuliana', 'Fisher-LevineMerlin',
#        'FitzsimmonsAlan', 'FongMatthew', 'FongWen-fai',
#        'FouchezDominique', 'FoxDerek', 'FoxOri', 'FrankJuhan',
#        'FraserWesley', 'FreemanPeter', 'FreyLucille', 'FryeBrenda',
#        'FryerChris', 'FuentesCesar', 'GalazGaspar', 'GalbanyLluis',
#        'GandhiPoshak', 'GanglerEmmanuel', 'GarofaloAlessia',
#        'GawiserEric', 'GehaMarla', 'GeislerDoug', 'GellerAaron',
#        'GenoveseChristopher', 'GerdesDavid', 'GezariSuvi',
#        'GhirlandaGiancarlo', 'GianninasAlexandros', 'GianniniTeresa',
#        'GibbsAlex', 'GibsonRob', 'GilmanFred', 'GilmoreKirk',
#        'GirardTerrence', 'GirardiLeo', 'GizisJohn', 'GlanzmanTom',
#        'GlazebrookKarl', 'GoldsteinDaniel', 'GombocAndreja',
#        'GomezMatias', 'GrahamMatthew', 'GrahamMelissa', 'GranvikMikael',
#        'GrapsAmara', 'GraurOr', 'GrayAlexander', 'GrazianAndrea',
#        'GrazianiCarlo', 'GrecoJohnny', 'GreenRichard', 'GreenstreetSarah',
#        'GreggioLaura', 'GrillmairCarl', 'GrindlayJosh', 'GrisPhilippe',
#        'GschwendJulia', 'GuhathakurtaPuragra', 'GuillochonJames',
#        'GuyonnetAugustin', 'HabibSalman', 'HaimanZoltan', 'HakkilaJon',
#        'HambletonKelly', 'HammergrenMark', 'HargisJonathan', 'HarrisAl',
#        'HartiganPatrick', 'HartleyWilliam', 'HathiNimish',
#        'HawleySuzanne', 'HearinAndrew', 'HebbLeslie', 'HeeCharlotte',
#        'HeitmannKatrin', 'HelouGeorge', 'HendenArne', 'HendlerNathanial',
#        'HenryTodd', 'HerXiachang', 'HerstrofferDaniel', 'HiltonEric',
#        'HlozekRenee', 'HoShirley', 'HoenigSebastian', 'HolbergJayB.',
#        'HollerBryan', 'HolmanMatthew', 'HolwerdaBenne', 'HolzDaniel',
#        'HowellSteve', 'HsiehHenry', 'HuberMark', 'HundertmarkMarkus',
#        'InfanteLeopoldo', 'InnesWalter', 'InnoLaura', 'InserraCosimo',
#        'IrwinJohn', 'IshakMustapha', 'IshidaEmille',
#        'Itam-PasquetJohanna', 'IvansInese', 'IvezicZeljko',
#        'JacklinSavannah', 'JacksonRyan', 'JaffeAndrew', 'JainBhuvnesh',
#        'JaoWei-Chun', 'JarvisMatt', 'JarvisMike', 'JedickeRobert',
#        'JeeJames', 'JenningsElise', 'JerniganGarrett', 'JevremovicDarko',
#        'JhaSaurabh', 'JiInchan', 'JiangYan-Fei', 'JoachimiBenjamin',
#        'Johns-KrullChristopher', 'JohnsonAnthony', 'JohnsonChristian',
#        'JohnsonMichael', 'JohnstonKathryn', 'JonesLynne', 'JordanAndres',
#        'JuricMario', 'KaasalAinenMikko', 'KafkaStella', 'KahnSteven',
#        'KaibNathan', 'KaliraiJason', 'KallivayalilNityaJacob',
#        'KalmbachBryce', 'KalogeraVicky', 'KamathSowmya', 'KanburShashi',
#        'KaplanDavid', 'KartaltepeJeyhan', 'KashyapVinayL.',
#        'KasliwalMansi', 'KasliwalVishal', 'KavirajSugata',
#        'KeetonCharles', 'KelleyMichael', 'KelvinLee', 'KentStephen',
#        'KerinsEamonn', 'KhakpashSomayeh', 'KiesslingAlina',
#        'KilicMukremin', 'KimAlex', 'KimPeter', 'KimballAmy', 'KirbyEvan',
#        'KirkbyDavid', 'KirkpatrickDavy', 'KnapenJohan', 'KnezevicZoran',
#        'KnightMatthew', 'KnuthKevin', 'KoposovSergey', 'KovacsEve',
#        'KowalskiAdam', 'KrauseElisabeth', 'KrughoffKarl', 'KrughoffSimon',
#        'KuhlmannSteve', 'KulierAndrea', 'KulkarniShri',
#        'KuncarayaktiHanindyo', 'KunderAndrea', 'KurczynskiPeter',
#        'KurtevRadostin', 'LacernaIvan', 'LacyMark', 'LageCraig',
#        'LahavOfer', 'LandoniMarco', 'LangDustin', 'LarsenJeffreyArthur',
#        'LarsenPatricia', 'LauroeschJames', 'LawrenceAndy', 'LeBretonRemy',
#        'LeGuillouLaurent', 'LeeAnn', 'LeeChien-Hsiu',
#        'LegetPierre-Francois', 'LeistedtBoris', 'LeonardDanielle',
#        'LepineSebastien', 'LevanAndrew', 'LiGongjie', 'LimKian-Tat',
#        'LinHsing-Wen(Edward)', 'LinHuan', 'LinWeikang', 'LinderEric',
#        'LintottChris', 'LiodakisYannis', 'LiraPaulina', 'ListerTim',
#        'LiuBinyang', 'LiuMichael', 'LochnerMichelle', 'LoebmanSarah',
#        'LongJames', 'LongKnoxS.', 'LopezSebastian', 'LoredoTom',
#        'LotzJennifer', 'LoucksMike', 'LovedayJon', 'LubinLori',
#        'LucasPhilip', 'LuhmanKevin', 'LundMichael', 'LunnanRagnhild',
#        'LuptonRobert', 'LuqueElmer', 'LurieJohn', 'LutzJulie',
#        'MacLeodChelsea', 'MaccaroneThomas', 'MacriLucas',
#        'MadejskiGreg(Grzegorz)', 'MagriniLaura', 'MaguireKate',
#        'MagurnoDavide', 'MahabalAshish', 'MainettiDeborah',
#        'MalhotraRenu', 'MalzAlex', 'ManconeConorL.', 'MandelKaisey',
#        'MandelbaumRachel', 'MantzAdam', 'MaoYao-Yuan', 'MarconiMarcella',
#        'MargoninerVera', 'MarguttiRaffaella', 'MarinoAlessio',
#        'MarinoniSilvia', 'MarshallJennifer', 'MarshallPhil',
#        'Martanez-LombillaCristina', 'MartinGarreth',
#        'Martinez-GalarzaRafael', 'MasonElena', 'MastersKaren',
#        'MathesonTom', 'MaundJustyn', 'MaureiraJuanCarlos',
#        'MauroFrancesco', 'MauronNicolas', 'MayMorgan', 'McClintockThomas',
#        'McCollumBruce', 'McEwenJason', 'McGeheePeregrine', 'McGreerIan',
#        'McMahonRichard', 'MelandriAndrea', 'MenardBrice',
#        'MennickentRonald', 'MercurioAmata', 'MerlinEmiliano',
#        'MeurerGerhardt', 'MeyerDavid', 'MeyersJoshua', 'MezaAndres',
#        'MilaniAndrea', 'MilisavljevicDanny', 'MillerAdam', 'MillerBryan',
#        'MillerChris', 'MinnitiDante', 'ModjazMaryam', 'MoeyensJoachim',
#        'MommertMichael', 'MonacoLorenzo', 'MonetDavid', 'MoniezMarc',
#        'MorettiAlberto', 'MorettiMariaIda', 'MorrisDave', 'MorrisGlenn',
#        'MorrisonChristopher', 'MortlockDaniel', 'MoskovitzNicholas',
#        'MottaVeronica', 'MuellerBeatrice', 'MukadamAnjum',
#        'MundellCarole', 'MunozRicardo', 'MunozRobertoPablo',
#        'MunozarArancibiaAlejandra', 'MuravevaTatiana', 'MurgiaSimona',
#        'MusellaIlaria', 'NaiduShantanu', 'NantaisJulieBeth',
#        'NapolitanoNicola', 'NarayanGautham', 'NaylorTim', 'NeilsenEric',
#        'NeveuJeremy', 'NewmanJeffrey', 'NeyrinckMark', 'NiQingling',
#        'NicholBob', 'NiederhoferFlorian', 'NierenbergAnna',
#        'NightingaleJames', 'NikolaevSergei', 'NissankeSamaya',
#        'NomerotskiAndrei', 'NormanDara', 'NugentPeter', 'NussEric',
#        "O'ConnorPaul", 'ObricMirela', 'OfekEranO.', 'OgandoRicardo',
#        'OguriMasamune', 'OjalaElle', 'OlivierScot', 'OlkinCatherine',
#        'OlsenKnut', 'OlszewskiEdward', 'OluseyiHakeem', 'PadillaNelson',
#        'PageGary', 'PandaSwayamtrupta', 'PankowChris', 'PapovichCasey',
#        'ParkHyeYun', 'ParkerAlex', 'ParrentJerod', 'ParsonsSteven',
#        'PastorelloAndrea', 'PayneMatthew', 'PedersenEske',
#        'PeirisHiranya', 'Penna-LimaMariana', 'PepperJoshua',
#        'PerlmutterSaul', 'PerrefortDaniel', 'PesensonMisha',
#        'PetersChristina', 'PetersonJohn', 'PetitJean-Marc', 'PetryCathy',
#        'PieresAdriano', 'PignataGiuliano', 'PiranomonteSilvia',
#        'PironFrederic', 'PlavchanPeter', 'PlazasAndres', 'PonderKara',
#        'PopeAdrian', 'PopovicLuka', 'PowerChris', 'PrisinzanoLoredana',
#        'ProtopapasPavlos', 'ProuzaMichael', 'PrsaAndrej', 'PtakAndrew',
#        'PuckettAndy', 'PuziaThomas', 'QuataertEliot', 'QuinnTom',
#        'RabusMarkus', 'RagozzineDarin', 'RahmanMubdi', 'RaiteriClaudiaM.',
#        'RajMariaAngela', 'RajagopalJayadev', 'RamirezAmelia',
#        'RasmussenAndrew', 'RasmussenAndy', 'RattenburyNicholas',
#        'RauArne', 'ReachWilliam', 'RebbapragadaUmaa', 'ReddyNaveen',
#        'RegnaultNicolas', 'ReilKevin', 'ReissDavid', 'RestArmin',
#        'RhoadsJamesE.', 'RhodesJason', 'RichR.Michael', 'RichardsGordon',
#        'RichardsJoseph', 'RichardsMercedes', 'RichterMatt', 'RickerPaul',
#        'RicolJean-Stephane', 'RidgwayStephen', 'RiedelAdric',
#        'RighiChiara', 'RitzSteve', 'RivkinAndy', 'RobertsonBrant',
#        'RobothamAaron', 'RockosiConstance', 'RodriguezJoseph',
#        'RojoPatricio', 'RomanAlexandre', 'RomaniRoger', 'RoncarelliMauro',
#        'RoodmanAaron', 'RosingWayne', 'RossiGustavoBenedetti',
#        'RoucelleCecile', 'RozoEduardo', 'RunnoeJessie', 'RuppertDavid',
#        'RutkowskiMichael', 'RykoffEli', 'SaccoGiuseppe', 'SahaAbi',
#        'SaintongeAmelie', 'SaitoRoberto', 'SakoMasao', 'SalafiaOmSharan',
#        'SalimSamir', 'SamarasinhaNalin', 'SanchezJavier',
#        'SantiagoBasilio', 'SarajediniAta', 'SaridGal', 'SasselovDimitar',
#        'ScargleJeffrey', 'SchaferChad', 'SchambeauCharles',
#        'SchechterPaul', 'SchindlerJan-Torge', 'SchmidtEdward',
#        'SchmidtSam', 'SchmidtSamuel', 'SchneiderDon', 'SchneiderMichael',
#        'SchwambMeg', 'ScowenPaul', 'ScrantonRyan', 'ScudderJillian',
#        'SeamanRob', 'SeljakUros', 'SembroskiGlenn', 'SerenoMauro',
#        'SesarBranimir', 'SethAnil', 'ShafterAllenW.', 'ShamirLior',
#        'SheldonErin', 'ShemmerOhad', 'ShenKen', 'SheppardScott',
#        'ShipseyIan', 'ShirleyRaphael', 'ShporerAvi', 'SickJonathan',
#        'SiemiginowskaAneta', 'SilvaDavid', 'SilvestriNicole',
#        'SimetMelanie', 'SimonJoshuaD.', 'SingerLeo', 'SlaterColin',
#        'SlosarAnze', 'SmarttStephen', 'SmithChris', 'SmithGraham',
#        'SmithHoward', 'SmithJ.Allyn', 'SmithKen', 'SmithNathan',
#        'SmothermanHayden', 'SnodgrassColin', 'SnyderGreg',
#        'SobeckJennifer', 'SolarzAleksandra', 'SolontoiMike',
#        'SonnefeldAlessandro', 'SoraisamMonika', 'SordoRosanna',
#        'SpergelDavid', 'SpitzAnna', 'StanfordAdam', 'StassunKeivan',
#        'SteckloffJordan', 'SteeghsDanny', 'SteenbruggeKatrien',
#        'SternAlan', 'StottJohn', 'StraderJay', 'StrattaGiulia',
#        'StraussMichael', 'StreetRachel', 'StuartScott',
#        'StubbsChristopher', 'SubasavageJohn', 'SullivanMark',
#        'SzaboRobert', 'SzkodyPaula', 'TakHyungsuk', 'TamayoDaniel',
#        'TaranuDan', 'TejosNicolas', 'TheilerJamesP.', 'ThirouinAudrey',
#        'ThomasCristina', 'ThormanPaul', 'ThorstensenJohnRobert',
#        'TisseraPatricia', 'TreisterEzequiel', 'TreuTommaso',
#        'TrillingDavid', 'TrimbleVirginia', 'TrouilleLaura',
#        'TroxelMichael', 'TrujilloChad', 'TrujilloIgnacio',
#        'TsaprasYiannis', 'TsybychevDmitri', 'TysonTony', 'UrryMeg',
#        'ValentiStefano', 'VallenariAntonella', 'VandenBerkDan',
#        'VenutiLaura', 'VeresPeter', 'VermaAprajita', 'VestrandTom',
#        'VianelloGiacomo', 'VieiraJoaquin', 'VilaltaRicardo',
#        'VillarVictoriaAshley', 'VillarrealAntonio', 'VinkJorick',
#        'VivasKathy', 'VogeleyMichael', 'VolkKat', 'VonDerLindenAnja',
#        'VrastilMichal', 'WainscoatRichard', 'WalkerAlistair',
#        'WalkowiczLucianne', 'WallersteinGeorge', 'WallinJohn',
#        'WalterChris', 'WaltonNicholas', 'WangYun', 'WassermanLarry',
#        'WeatherillDaniel', 'WebsterRachel', 'WechslerRisa',
#        'WeinbergMartin', 'WeinerBen', 'WellsMark', 'WenausTorre',
#        'WernerNorbert', 'WestAndrew', 'WiesnerMatthew', 'WildVivienne',
#        'WilliamsBen', 'WilliamsRobert', 'WilligerGerard', 'WillmanBeth',
#        'WittmanDavid', 'WolpertRobert', 'WomackMaria',
#        'Wood-VaseyMichael', 'WoodroofeMichael', 'WozniakPrzemek',
#        'Yanamandra-FisherPadma', 'YangGuang', 'YangSheng', 'YeQuan-Zhi',
#        'YoachimPeter', 'YoungDavid', 'YoungLeslie', 'YuWeixiang',
#        'ZabludoffAnn', 'ZaudererAshley', 'ZehaviIdit', 'ZentnerAndrew',
#        'ZhanHu', 'ZhaoGong-Bo', 'ZhengZhenia', 'ZoccaliManuela',
#        'ZolotovAdi', 'ZuntzJoe', 'daCostaLuiz',
#        'deAndradeQueirozAnnaBarbara', 'deJongRoelof', 'deVal-BorroMiguel',
#        'deVriesWim'], dtype=object)

# %%
chairs = ['VermaAprajita','AnguitaTimo','KavirajSugata', 'BiancoFederica',
'StreetRachel', 'MandelbaumRachel', 'GizisJohn', 'BrandtNiel', 'McGeheePeregrine',
'SchaferChad']
sizes = [30] * len(affiliationsDF.index.values) 
for i,n in  enumerate(affiliationsDF.index.values):
    if n in chairs : 
        sizes[i] = 200

sizes = np.array(sizes)
alphas = np.array([0.5 if i not in chairs else 1 for i in  affiliationsDF.index.values])
alphas2 = np.array([0.5 #if not countrylabel[i] in ["US"] else 0.1 
           for i in  affiliationsDF.index.values ])
alphas2
# Out:
# array([0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5])

# %%
pos = nx.spring_layout(G, seed=123,  weight=0.2, dim=2, fixed=None)

# %%
import pylab as pl
pl.figure(figsize=(10,10))
#
pl.xlim(-1.2,1.2)
pl.ylim(-1,1.7);
for sc in properhexcolors.keys():
    scs = pn == sc
    nx.draw_networkx_nodes(G, pos=pos, nodelist=[x for x,y in G.nodes(data=True) if y['SC']==sc],
                      node_color=properhexcolors[sc], cmap='viridis', label=sc,
                      width=0.03, alpha=alphas[scs], node_size=sizes[scs])


nx.draw_networkx_edges(G,pos=pos,width=0.03, alpha=0.5)

#nx.draw(G, with_labels=False, width=0.03, alpha=0.5, node_color=p)
pl.legend();
pl.axis('off');

# %%
pl.figure(figsize=(10,10))
#
pl.xlim(-1.2,1.2)
pl.ylim(-1,1.7);
for sc in properhexcolors.keys():
    scs = pn == sc
    nx.draw_networkx_nodes(G, pos=pos, nodelist=[x for x,y in G.nodes(data=True) if y['SC']==sc],
                      node_color=properhexcolors[sc], cmap='viridis', label=sc,
                      width=0.03, alpha=alphas[scs], node_size=200)


nx.draw_networkx_edges(G,pos=pos,width=0.03, alpha=0.5)

#nx.draw(G, with_labels=False, width=0.03, alpha=0.5, node_color=p)
pl.legend();
pl.axis('off');

# %%
pl.figure(figsize=(10,10))
#
pl.xlim(-1.2,1.2)
pl.ylim(-1,1.7);
N = len(np.unique(np.array(list(countrylabel.values()))))
for i,n in enumerate(np.unique(np.array(list(countrylabel.values())))):
    #print (n)
    nat = np.array(list(countrylabel.values()))==n
    nx.draw_networkx_nodes(G, pos=pos, nodelist=[x for x,y in G.nodes(data=True) if y['Nationality']==n],
                      node_color=countrycolor[n],  label=n,
                      width=0.03, alpha=alphas2[nat], node_size=sizes[nat])



nx.draw_networkx_edges(G,pos=pos, width=0.02, alpha=0.5)

#nx.draw(G, with_labels=False, width=0.03, alpha=0.5, node_color=p)
pl.legend();
pl.axis('off');

# %%
pl.figure(figsize=(10,10))
#
pl.xlim(-1.2,1.2)
pl.ylim(-1,1.7);
N = len(np.unique(np.array(list(countrylabel.values()))))
for i,n in enumerate(np.unique(np.array(list(countrylabel.values())))):
    #print (n)
    nat = np.array(list(countrylabel.values()))==n
    nx.draw_networkx_nodes(G, pos=pos, nodelist=[x for x,y in G.nodes(data=True) if y['Nationality']==n],
                      node_color=countrycolor[n],  label=n,
                      width=0.03, alpha=alphas2[nat], node_size=30)



nx.draw_networkx_edges(G,pos=pos, width=0.02, alpha=0.5)

#nx.draw(G, with_labels=False, width=0.03, alpha=0.5, node_color=p)
pl.legend();
pl.axis('off');

# %%
import pylab as pl
nx.draw(G, pos=pos, with_labels=False, width=0.03, alpha=0.5, 
        node_color=[properhexcolors[p] for p in pn], 
        cmap='viridis', node_size=100)
pl.legend()
# Out:
# /Users/fbb/anaconda3/lib/python3.7/site-packages/networkx/drawing/nx_pylab.py:611: MatplotlibDeprecationWarning: isinstance(..., numbers.Number)
#   if cb.is_numlike(alpha):
# No handles with labels found to put in legend.

# %%
[properhexcolors[p] for p in pn]
# Out:
# ['#44aa99',
#  '#332288',
#  '#44aa99',
#  '#cc6677',
#  '#44aa99',
#  '#aa4499',
#  '#cc6677',
#  '#117733',
#  '#cc6677',
#  '#882255',
#  '#44aa99',
#  '#cc6677',
#  '#88ccee',
#  '#ddcc77',
#  '#882255',
#  '#aa4499',
#  '#cc6677',
#  '#cc6677',
#  '#44aa99',
#  '#aa4499',
#  '#44aa99',
#  '#88ccee',
#  '#88ccee',
#  '#aa4499',
#  '#aa4499',
#  '#44aa99',
#  '#882255',
#  '#cc6677',
#  '#117733',
#  '#cc6677',
#  '#cc6677',
#  '#332288',
#  '#ddcc77',
#  '#ddcc77',
#  '#44aa99',
#  '#cc6677',
#  '#882255',
#  '#44aa99',
#  '#aa4499',
#  '#117733',
#  '#332288',
#  '#aa4499',
#  '#332288',
#  '#88ccee',
#  '#88ccee',
#  '#88ccee',
#  '#88ccee',
#  '#cc6677',
#  '#cc6677',
#  '#aa4499',
#  '#882255',
#  '#aa4499',
#  '#cc6677',
#  '#44aa99',
#  '#882255',
#  '#cc6677',
#  '#332288',
#  '#44aa99',
#  '#cc6677',
#  '#ddcc77',
#  '#88ccee',
#  '#88ccee',
#  '#88ccee',
#  '#88ccee',
#  '#44aa99',
#  '#aa4499',
#  '#44aa99',
#  '#88ccee',
#  '#44aa99',
#  '#332288',
#  '#44aa99',
#  '#cc6677',
#  '#ddcc77',
#  '#44aa99',
#  '#aa4499',
#  '#cc6677',
#  '#aa4499',
#  '#cc6677',
#  '#117733',
#  '#aa4499',
#  '#cc6677',
#  '#44aa99',
#  '#88ccee',
#  '#88ccee',
#  '#88ccee',
#  '#332288',
#  '#88ccee',
#  '#332288',
#  '#44aa99',
#  '#cc6677',
#  '#88ccee',
#  '#88ccee',
#  '#44aa99',
#  '#44aa99',
#  '#aa4499',
#  '#cc6677',
#  '#ddcc77',
#  '#aa4499',
#  '#332288',
#  '#332288',
#  '#44aa99',
#  '#cc6677',
#  '#aa4499',
#  '#117733',
#  '#cc6677',
#  '#44aa99',
#  '#aa4499',
#  '#882255',
#  '#ddcc77',
#  '#aa4499',
#  '#cc6677',
#  '#88ccee',
#  '#88ccee',
#  '#44aa99',
#  '#882255',
#  '#aa4499',
#  '#332288',
#  '#44aa99',
#  '#332288',
#  '#ddcc77',
#  '#882255',
#  '#ddcc77',
#  '#332288',
#  '#332288',
#  '#cc6677',
#  '#88ccee',
#  '#88ccee',
#  '#cc6677',
#  '#117733',
#  '#88ccee',
#  '#88ccee',
#  '#cc6677',
#  '#ddcc77',
#  '#88ccee',
#  '#88ccee',
#  '#ddcc77',
#  '#44aa99',
#  '#cc6677',
#  '#88ccee',
#  '#88ccee',
#  '#cc6677',
#  '#88ccee',
#  '#88ccee',
#  '#88ccee',
#  '#88ccee',
#  '#88ccee',
#  '#44aa99',
#  '#cc6677',
#  '#88ccee',
#  '#88ccee',
#  '#aa4499',
#  '#88ccee',
#  '#88ccee',
#  '#44aa99',
#  '#44aa99',
#  '#aa4499',
#  '#88ccee',
#  '#88ccee',
#  '#cc6677',
#  '#117733',
#  '#882255',
#  '#ddcc77',
#  '#44aa99',
#  '#ddcc77',
#  '#332288',
#  '#cc6677',
#  '#44aa99',
#  '#cc6677',
#  '#44aa99',
#  '#88ccee',
#  '#88ccee',
#  '#44aa99',
#  '#88ccee',
#  '#882255',
#  '#44aa99',
#  '#88ccee',
#  '#88ccee',
#  '#ddcc77',
#  '#88ccee',
#  '#cc6677',
#  '#88ccee',
#  '#88ccee',
#  '#44aa99',
#  '#44aa99',
#  '#cc6677',
#  '#44aa99',
#  '#cc6677',
#  '#cc6677',
#  '#cc6677',
#  '#cc6677',
#  '#cc6677',
#  '#332288',
#  '#aa4499',
#  '#88ccee',
#  '#88ccee',
#  '#aa4499',
#  '#44aa99',
#  '#332288',
#  '#332288',
#  '#44aa99',
#  '#ddcc77',
#  '#88ccee',
#  '#88ccee',
#  '#117733',
#  '#882255',
#  '#44aa99',
#  '#332288',
#  '#44aa99',
#  '#882255',
#  '#44aa99',
#  '#44aa99',
#  '#44aa99',
#  '#88ccee',
#  '#332288',
#  '#cc6677',
#  '#88ccee',
#  '#88ccee',
#  '#44aa99',
#  '#cc6677',
#  '#88ccee',
#  '#88ccee',
#  '#aa4499',
#  '#aa4499',
#  '#aa4499',
#  '#cc6677',
#  '#cc6677',
#  '#88ccee',
#  '#88ccee',
#  '#aa4499',
#  '#88ccee',
#  '#88ccee',
#  '#88ccee',
#  '#88ccee',
#  '#44aa99',
#  '#332288',
#  '#882255',
#  '#88ccee',
#  '#88ccee',
#  '#44aa99',
#  '#88ccee',
#  '#88ccee',
#  '#cc6677',
#  '#aa4499',
#  '#332288',
#  '#332288',
#  '#aa4499',
#  '#117733',
#  '#88ccee',
#  '#aa4499',
#  '#aa4499',
#  '#cc6677',
#  '#88ccee',
#  '#44aa99',
#  '#ddcc77',
#  '#117733',
#  '#44aa99',
#  '#cc6677',
#  '#332288',
#  '#cc6677',
#  '#88ccee',
#  '#88ccee',
#  '#44aa99',
#  '#aa4499',
#  '#88ccee',
#  '#88ccee',
#  '#44aa99',
#  '#cc6677',
#  '#cc6677',
#  '#332288',
#  '#44aa99',
#  '#117733',
#  '#cc6677',
#  '#332288',
#  '#882255',
#  '#ddcc77',
#  '#ddcc77',
#  '#44aa99',
#  '#117733',
#  '#882255',
#  '#88ccee',
#  '#332288',
#  '#cc6677',
#  '#117733',
#  '#ddcc77',
#  '#cc6677',
#  '#aa4499',
#  '#88ccee',
#  '#88ccee',
#  '#aa4499',
#  '#cc6677',
#  '#88ccee',
#  '#aa4499',
#  '#cc6677',
#  '#44aa99',
#  '#88ccee',
#  '#cc6677',
#  '#cc6677',
#  '#44aa99',
#  '#cc6677',
#  '#44aa99',
#  '#44aa99',
#  '#44aa99',
#  '#332288',
#  '#ddcc77',
#  '#44aa99',
#  '#117733',
#  '#88ccee',
#  '#88ccee',
#  '#44aa99',
#  '#332288',
#  '#aa4499',
#  '#44aa99',
#  '#cc6677',
#  '#44aa99',
#  '#cc6677',
#  '#44aa99',
#  '#cc6677',
#  '#aa4499',
#  '#88ccee',
#  '#88ccee',
#  '#88ccee',
#  '#88ccee',
#  '#44aa99',
#  '#ddcc77',
#  '#332288',
#  '#44aa99',
#  '#44aa99',
#  '#88ccee',
#  '#44aa99',
#  '#332288',
#  '#cc6677',
#  '#cc6677',
#  '#aa4499',
#  '#88ccee',
#  '#88ccee',
#  '#88ccee',
#  '#88ccee',
#  '#88ccee',
#  '#88ccee',
#  '#cc6677',
#  '#117733',
#  '#aa4499',
#  '#117733',
#  '#117733',
#  '#44aa99',
#  '#88ccee',
#  '#88ccee',
#  '#ddcc77',
#  '#44aa99',
#  '#332288',
#  '#332288',
#  '#44aa99',
#  '#ddcc77',
#  '#882255',
#  '#aa4499',
#  '#ddcc77',
#  '#aa4499',
#  '#882255',
#  '#332288',
#  '#44aa99',
#  '#88ccee',
#  '#44aa99',
#  '#cc6677',
#  '#ddcc77',
#  '#44aa99',
#  '#ddcc77',
#  '#44aa99',
#  '#332288',
#  '#88ccee',
#  '#332288',
#  '#aa4499',
#  '#aa4499',
#  '#88ccee',
#  '#88ccee',
#  '#cc6677',
#  '#44aa99',
#  '#88ccee',
#  '#88ccee',
#  '#cc6677',
#  '#332288',
#  '#cc6677',
#  '#44aa99',
#  '#332288',
#  '#882255',
#  '#88ccee',
#  '#88ccee',
#  '#332288',
#  '#332288',
#  '#44aa99',
#  '#44aa99',
#  '#332288',
#  '#44aa99',
#  '#44aa99',
#  '#aa4499',
#  '#cc6677',
#  '#88ccee',
#  '#88ccee',
#  '#44aa99',
#  '#cc6677',
#  '#117733',
#  '#cc6677',
#  '#cc6677',
#  '#88ccee',
#  '#88ccee',
#  '#aa4499',
#  '#ddcc77',
#  '#882255',
#  '#332288',
#  '#117733',
#  '#88ccee',
#  '#44aa99',
#  '#88ccee',
#  '#cc6677',
#  '#ddcc77',
#  '#44aa99',
#  '#aa4499',
#  '#ddcc77',
#  '#cc6677',
#  '#88ccee',
#  '#88ccee',
#  '#aa4499',
#  '#cc6677',
#  '#882255',
#  '#332288',
#  '#cc6677',
#  '#ddcc77',
#  '#117733',
#  '#44aa99',
#  '#cc6677',
#  '#44aa99',
#  '#aa4499',
#  '#882255',
#  '#cc6677',
#  '#44aa99',
#  '#cc6677',
#  '#44aa99',
#  '#88ccee',
#  '#88ccee',
#  '#88ccee',
#  '#88ccee',
#  '#44aa99',
#  '#aa4499',
#  '#cc6677',
#  '#332288',
#  '#ddcc77',
#  '#117733',
#  '#88ccee',
#  '#88ccee',
#  '#88ccee',
#  '#88ccee',
#  '#ddcc77',
#  '#cc6677',
#  '#332288',
#  '#88ccee',
#  '#88ccee',
#  '#44aa99',
#  '#cc6677',
#  '#332288',
#  '#88ccee',
#  '#88ccee',
#  '#88ccee',
#  '#cc6677',
#  '#88ccee',
#  '#44aa99',
#  '#cc6677',
#  '#44aa99',
#  '#44aa99',
#  '#aa4499',
#  '#ddcc77',
#  '#aa4499',
#  '#44aa99',
#  '#aa4499',
#  '#117733',
#  '#332288',
#  '#aa4499',
#  '#cc6677',
#  '#44aa99',
#  '#44aa99',
#  '#88ccee',
#  '#88ccee',
#  '#117733',
#  '#882255',
#  '#cc6677',
#  '#88ccee',
#  '#cc6677',
#  '#88ccee',
#  '#88ccee',
#  '#aa4499',
#  '#332288',
#  '#44aa99',
#  '#cc6677',
#  '#44aa99',
#  '#cc6677',
#  '#cc6677',
#  '#ddcc77',
#  '#44aa99',
#  '#cc6677',
#  '#aa4499',
#  '#44aa99',
#  '#88ccee',
#  '#88ccee',
#  '#44aa99',
#  '#882255',
#  '#88ccee',
#  '#882255',
#  '#aa4499',
#  '#332288',
#  '#cc6677',
#  '#88ccee',
#  '#88ccee',
#  '#882255',
#  '#cc6677',
#  '#cc6677',
#  '#117733',
#  '#ddcc77',
#  '#cc6677',
#  '#cc6677',
#  '#cc6677',
#  '#88ccee',
#  '#44aa99',
#  '#332288',
#  '#ddcc77',
#  '#cc6677',
#  '#332288',
#  '#cc6677',
#  '#aa4499',
#  '#882255',
#  '#882255',
#  '#332288',
#  '#88ccee',
#  '#88ccee',
#  '#cc6677',
#  '#cc6677',
#  '#88ccee',
#  '#ddcc77',
#  '#44aa99',
#  '#117733',
#  '#ddcc77',
#  '#aa4499',
#  '#332288',
#  '#aa4499',
#  '#aa4499',
#  '#88ccee',
#  '#88ccee',
#  '#44aa99',
#  '#44aa99',
#  '#aa4499',
#  '#cc6677',
#  '#88ccee',
#  '#88ccee',
#  '#88ccee',
#  '#88ccee',
#  '#88ccee',
#  '#88ccee',
#  '#882255',
#  '#44aa99',
#  '#88ccee',
#  '#88ccee',
#  '#882255',
#  '#88ccee',
#  '#44aa99',
#  '#88ccee',
#  '#44aa99',
#  '#ddcc77',
#  '#44aa99',
#  '#44aa99',
#  '#332288',
#  '#ddcc77',
#  '#cc6677',
#  '#cc6677',
#  '#44aa99',
#  '#88ccee',
#  '#88ccee',
#  '#aa4499',
#  '#44aa99',
#  '#44aa99',
#  '#44aa99',
#  '#882255',
#  '#ddcc77',
#  '#88ccee',
#  '#88ccee',
#  '#aa4499',
#  '#117733',
#  '#aa4499',
#  '#aa4499',
#  '#44aa99',
#  '#44aa99',
#  '#aa4499',
#  '#44aa99',
#  '#ddcc77',
#  '#ddcc77',
#  '#44aa99',
#  '#cc6677',
#  '#cc6677',
#  '#ddcc77',
#  '#ddcc77',
#  '#cc6677',
#  '#88ccee',
#  '#88ccee',
#  '#882255',
#  '#882255',
#  '#44aa99',
#  '#cc6677',
#  '#44aa99',
#  '#88ccee',
#  '#aa4499',
#  '#aa4499',
#  '#88ccee',
#  '#88ccee',
#  '#88ccee',
#  '#88ccee',
#  '#332288',
#  '#44aa99',
#  '#44aa99',
#  '#aa4499',
#  '#44aa99',
#  '#ddcc77',
#  '#88ccee',
#  '#44aa99',
#  '#332288',
#  '#332288',
#  '#88ccee',
#  '#88ccee',
#  '#88ccee',
#  '#88ccee',
#  '#cc6677',
#  '#882255',
#  '#882255',
#  '#44aa99',
#  '#cc6677',
#  '#cc6677',
#  '#ddcc77',
#  '#332288',
#  '#117733',
#  '#332288',
#  '#88ccee',
#  '#88ccee',
#  '#44aa99',
#  '#882255',
#  '#88ccee',
#  '#88ccee',
#  '#ddcc77',
#  '#ddcc77',
#  '#44aa99',
#  '#88ccee',
#  '#88ccee',
#  '#44aa99',
#  '#332288',
#  '#aa4499',
#  '#aa4499',
#  '#117733',
#  '#44aa99',
#  '#cc6677',
#  '#88ccee',
#  '#88ccee',
#  '#cc6677',
#  '#882255',
#  '#aa4499',
#  '#cc6677',
#  '#cc6677',
#  '#882255',
#  '#ddcc77',
#  '#44aa99',
#  '#88ccee',
#  '#88ccee',
#  '#117733',
#  '#117733',
#  '#88ccee',
#  '#88ccee',
#  '#cc6677',
#  '#aa4499',
#  '#44aa99',
#  '#cc6677',
#  '#cc6677',
#  '#aa4499',
#  '#44aa99',
#  '#aa4499',
#  '#117733',
#  '#44aa99',
#  '#cc6677',
#  '#332288',
#  '#88ccee',
#  '#88ccee',
#  '#88ccee',
#  '#44aa99',
#  '#332288',
#  '#882255',
#  '#44aa99',
#  '#aa4499',
#  '#cc6677',
#  '#332288',
#  '#44aa99',
#  '#88ccee',
#  '#88ccee',
#  '#44aa99',
#  '#332288',
#  '#cc6677',
#  '#cc6677',
#  '#88ccee',
#  '#88ccee',
#  '#cc6677',
#  '#ddcc77',
#  '#cc6677',
#  '#cc6677',
#  '#ddcc77',
#  '#cc6677',
#  '#882255',
#  '#cc6677',
#  '#88ccee',
#  '#88ccee',
#  '#ddcc77',
#  '#44aa99',
#  '#44aa99',
#  '#44aa99',
#  '#88ccee',
#  '#88ccee',
#  '#cc6677',
#  '#cc6677',
#  '#cc6677',
#  '#882255',
#  '#aa4499',
#  '#88ccee',
#  '#88ccee',
#  '#aa4499',
#  '#332288',
#  '#aa4499',
#  '#332288',
#  '#44aa99',
#  '#332288',
#  '#cc6677',
#  '#44aa99',
#  '#44aa99',
#  '#cc6677',
#  '#44aa99',
#  '#44aa99',
#  '#332288',
#  '#ddcc77',
#  '#cc6677',
#  '#44aa99',
#  '#44aa99',
#  '#cc6677',
#  '#88ccee',
#  '#88ccee',
#  '#44aa99',
#  '#ddcc77',
#  '#882255',
#  '#332288',
#  '#cc6677',
#  '#332288',
#  '#44aa99',
#  '#88ccee',
#  '#cc6677',
#  '#332288',
#  '#aa4499',
#  '#aa4499',
#  '#88ccee',
#  '#88ccee',
#  '#44aa99',
#  '#88ccee',
#  '#cc6677',
#  '#882255',
#  '#ddcc77',
#  '#cc6677',
#  '#88ccee',
#  '#44aa99',
#  '#88ccee',
#  '#88ccee',
#  '#aa4499',
#  '#44aa99',
#  '#cc6677',
#  '#44aa99',
#  '#332288',
#  '#44aa99',
#  '#aa4499',
#  '#332288',
#  '#cc6677',
#  '#88ccee',
#  '#88ccee',
#  '#88ccee',
#  '#332288',
#  '#44aa99',
#  '#ddcc77',
#  '#ddcc77',
#  '#332288',
#  '#117733',
#  '#882255',
#  '#cc6677',
#  '#aa4499',
#  '#882255',
#  '#cc6677',
#  '#332288',
#  '#44aa99',
#  '#aa4499',
#  '#aa4499',
#  '#44aa99',
#  '#332288',
#  '#cc6677',
#  '#cc6677',
#  '#aa4499',
#  '#88ccee',
#  '#88ccee',
#  '#882255',
#  '#44aa99',
#  '#ddcc77',
#  '#cc6677',
#  '#44aa99',
#  '#332288',
#  '#cc6677',
#  '#aa4499',
#  '#ddcc77',
#  '#882255',
#  '#117733',
#  '#ddcc77',
#  '#88ccee',
#  '#88ccee',
#  '#44aa99',
#  '#88ccee',
#  '#88ccee',
#  '#88ccee',
#  '#88ccee',
#  '#44aa99',
#  '#aa4499',
#  '#88ccee',
#  '#88ccee',
#  '#44aa99',
#  '#882255',
#  '#117733',
#  '#cc6677',
#  '#44aa99',
#  '#88ccee',
#  '#88ccee',
#  '#aa4499',
#  '#44aa99',
#  '#44aa99',
#  '#332288',
#  '#aa4499',
#  '#88ccee',
#  '#88ccee',
#  '#ddcc77',
#  '#332288',
#  '#117733',
#  '#88ccee',
#  '#88ccee',
#  '#88ccee',
#  '#88ccee',
#  '#cc6677',
#  '#332288',
#  '#aa4499',
#  '#332288',
#  '#44aa99',
#  '#882255',
#  '#332288',
#  '#aa4499',
#  '#88ccee',
#  '#aa4499',
#  '#882255',
#  '#cc6677',
#  '#44aa99',
#  '#44aa99']

# %%
nx.draw_circular(G, alpha=0.1, width=0.02, 
                 node_color=[properhexcolors[p] for p in pn])

# %%
import matplotlib.pyplot as plt
import networkx as nx

try:
    import pygraphviz
    from networkx.drawing.nx_agraph import graphviz_layout
except ImportError:
    try:
        import pydot
        from networkx.drawing.nx_pydot import graphviz_layout
    except ImportError:
        raise ImportError("This example needs Graphviz and either "
                          "PyGraphviz or pydot")

        
pos = graphviz_layout(G, prog='twopi', args='')
plt.figure(figsize=(8, 8))
nx.draw(G, pos, node_size=20, alpha=0.2, width=0.2,
        node_color="blue", with_labels=False)
plt.axis('equal')
plt.show()
# Out:
# /Users/fbb/anaconda3/lib/python3.7/site-packages/networkx/drawing/nx_pylab.py:611: MatplotlibDeprecationWarning: isinstance(..., numbers.Number)
#   if cb.is_numlike(alpha):

# %%
p
my_graph.add_edges_from(edges.edges())
my_graph.add_nodes_from(nodes)
nx.apply_alpha(p, 0.5, my_graph.edges, cmap=None, vmin=None, vmax=None)
    
nx.draw(my_graph, with_labels=False, font_weight='bold')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-182-3e4328d2bc48> in <module>
#       2 my_graph.add_edges_from(edges.edges())
#       3 my_graph.add_nodes_from(nodes)
# ----> 4 nx.apply_alpha(p, 0.5, my_graph.edges, cmap=None, vmin=None, vmax=None)
#       5
#       6 nx.draw(my_graph, with_labels=False, font_weight='bold')
#
# AttributeError: module 'networkx' has no attribute 'apply_alpha'

# %%
my_graph.
# Out:
# dict

# %%
nx.draw_networkx_edges(my_graph,  alpha=0.4)
nx.draw_networkx_nodes(my_graph,  nodelist=list(p.keys()),
                       node_size=80,
                       node_color=list(p.values()),
                       cmap=plt.cm.Reds_r)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-144-07b1b18dfede> in <module>
# ----> 1 nx.draw_networkx_edges(my_graph,  alpha=0.4)
#       2 nx.draw_networkx_nodes(my_graph,  nodelist=list(p.keys()),
#       3                        node_size=80,
#       4                        node_color=list(p.values()),
#       5                        cmap=plt.cm.Reds_r)
#
# TypeError: draw_networkx_edges() missing 1 required positional argument: 'pos'

# %%
d = {0: {1: {'weight':5}, 2: {"weight":200}},
    2: {1: {'weight':10}}} # dict-of-dicts single edge (0,1)
d
# Out:
# {0: {1: {'weight': 5}, 2: {'weight': 200}}, 2: {1: {'weight': 10}}}

# %%
G = nx.Graph(d, multigraph_input =True)
nx.draw(G, with_labels=False, font_weight='bold')

# %%
properhexcolors
# Out:
# {'TVS': '#44aa99',
#  'SS': '#332288',
#  'SL': '#117733',
#  'DESC': '#cc6677',
#  'Galaxies': '#aa4499',
#  'AGN': '#882255',
#  'SMWLV': '#88ccee',
#  'IS': '#ddcc77'}

# %%
# SC sensitive to time domain
pl.figure(figsize=(10,10))
#
pl.xlim(-1.2,1.2)
pl.ylim(-1,1.7);


for sc in properhexcolors.keys():
    scs = pn == sc
    thisalpha = 0.7 if sc in ['TVS', 'AGN', 'SS', 'DESC', 'SMWLV']  else 0.1# Gal IS SL
    nx.draw_networkx_nodes(G, pos=pos, nodelist=[x for x,y in G.nodes(data=True) if y['SC']==sc],
                      node_color=properhexcolors[sc], cmap='viridis', label=sc,
                      width=0.03, alpha=thisalpha, node_size=sizes[scs])


nx.draw_networkx_edges(G,pos=pos,width=0.03, alpha=0.5)

#nx.draw(G, with_labels=False, width=0.03, alpha=0.5, node_color=p)
pl.legend();
pl.axis('off');

# %%
# SC EG
pl.figure(figsize=(10,10))
#
pl.xlim(-1.2,1.2)
pl.ylim(-1,1.7);


for sc in properhexcolors.keys():
    scs = pn == sc
    thisalpha = 0.7 if sc in ['AGN', 'DESC', "Galaxies", 'SL', 'TVS']  else 0.1#  IS SL 'SS', 'SMWLV'
    nx.draw_networkx_nodes(G, pos=pos, nodelist=[x for x,y in G.nodes(data=True) if y['SC']==sc],
                      node_color=properhexcolors[sc], cmap='viridis', label=sc,
                      width=0.03, alpha=thisalpha, node_size=sizes[scs])


nx.draw_networkx_edges(G,pos=pos,width=0.03, alpha=0.5)

#nx.draw(G, with_labels=False, width=0.03, alpha=0.5, node_color=p)
pl.legend();
pl.axis('off');

# %%
# SC Galactic
pl.figure(figsize=(10,10))
#
pl.xlim(-1.2,1.2)
pl.ylim(-1,1.7);


for sc in properhexcolors.keys():
    scs = pn == sc
    thisalpha = 0.7 if sc in ['TVS', 'SMWLV']  else 0.1#  IS SL 'SS', 'SMWLV'
    nx.draw_networkx_nodes(G, pos=pos, nodelist=[x for x,y in G.nodes(data=True) if y['SC']==sc],
                      node_color=properhexcolors[sc], cmap='viridis', label=sc,
                      width=0.03, alpha=thisalpha, node_size=sizes[scs])


nx.draw_networkx_edges(G,pos=pos,width=0.03, alpha=0.5)

#nx.draw(G, with_labels=False, width=0.03, alpha=0.5, node_color=p)
pl.legend();
pl.axis('off');
